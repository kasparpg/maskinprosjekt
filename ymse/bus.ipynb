# %%
import pandas as pd
import geopandas as gp
import os

from shapely import wkt
from shapely.geometry import Point
from tqdm import tqdm

tqdm.pandas()

busstops = pd.read_csv('data/busstops_norway.csv')
busstops = gp.GeoDataFrame(busstops, geometry=busstops.geometry.apply(wkt.loads))

train = pd.read_csv('data/stores_train.csv')[['store_id', 'lon','lat']]
train = gp.GeoDataFrame(train, geometry=gp.points_from_xy(train.lon, train.lat)).drop(columns=['lon', 'lat'])
train = train.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

train_extra = pd.read_csv('data/stores_extra.csv')[['store_id', 'lon','lat']]
train_extra = gp.GeoDataFrame(train_extra, geometry=gp.points_from_xy(train_extra.lon, train_extra.lat)).drop(columns=['lon', 'lat'])
train_extra = train_extra.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

test = pd.read_csv('data/stores_test.csv')[['store_id', 'lon', 'lat']]
test = gp.GeoDataFrame(test, geometry=gp.points_from_xy(test.lon, test.lat)).drop(columns=['lon', 'lat'])
test = test.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

# %%
busstops = busstops.set_crs('epsg:4326', allow_override=True)
busstops = busstops.to_crs('epsg:3857')
print(busstops.crs)
# busstops.plot()
busstops
# Out:
# epsg:3857
#                                  busstop_id                  stopplace_type  \
# 0      853cb081-cc32-4880-aa3e-26e96870d874              Plattform og lomme
# 1      156b052b-2771-497a-b4f4-97fed59e1aca  Lomme og skilt, ikke plattform
# 2      7312a280-e14f-4b09-a421-02e8fe1bc63e                             NaN
# 3      d9cda2c7-355a-49c1-b56c-a33180d2a82e                             NaN
# 4      f803bcd3-182d-450b-bbb4-113c6ca885c2                             NaN
# ...                                     ...                             ...
# 68390  12edd887-a122-44e2-896b-a5f663917f88  Lomme og skilt, ikke plattform
# 68391  38dd0aee-b497-43c2-943b-51ab5c6d0eb7  Lomme og skilt, ikke plattform
# 68392  3803f0fe-d6dc-4211-a44d-bbc3453af289  Lomme og skilt, ikke plattform
# 68393  5b177625-d0dc-40ae-b554-e97f7d400e24              Plattform og lomme
# 68394  e44dd70c-b571-475b-8bc0-9c9119858c34              Plattform og lomme
#
#              importance_level  side_placement                         geometry
# 0      Mangler viktighetsnivå  LEFT_AND_RIGHT   POINT (728101.520 8640047.651)
# 1      Mangler viktighetsnivå  LEFT_AND_RIGHT   POINT (656762.828 8431462.584)
# 2      Mangler viktighetsnivå     MIDDLE_LEFT  POINT (1199816.247 8384169.375)
# 3      Mangler viktighetsnivå     MIDDLE_LEFT  POINT (1199818.130 8384192.832)
# 4      Mangler viktighetsnivå    MIDDLE_RIGHT  POINT (1199820.134 8384216.279)
# ...                       ...             ...                              ...
# 68390  Mangler viktighetsnivå          MIDDLE   POINT (651699.196 8445068.826)
# 68391  Mangler viktighetsnivå          MIDDLE   POINT (651650.730 8445056.162)
# 68392  Mangler viktighetsnivå          MIDDLE  POINT (1185500.476 9086180.311)
# 68393       Lokalt knutepunkt          MIDDLE  POINT (1020155.419 8640402.161)
# 68394       Lokalt knutepunkt          MIDDLE  POINT (1020152.400 8640395.686)
#
# [68395 rows x 5 columns]

# %%
# train = train.drop(columns=['bus_stops_count', *busstops.importance_level.unique()])

# %%
def cond_merge(row: pd.Series):
    output_dict = {}
    gp.options.use_pygeos = True
    
    stops_with_dist = busstops[busstops.distance(row.geometry) < 1000]
    output_dict['bus_stops_count'] = len(stops_with_dist)
    
    output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
        busstops.importance_level.unique(), fill_value=0
    ).to_dict())
    
    return output_dict

data = pd.concat([train, train_extra], ignore_index=True)

data = data.join(data.progress_apply(lambda row: cond_merge(row), axis=1, result_type='expand'))
data.to_parquet('derived_data/stores_bus_stops_lt_1km_train_with_extras')

# test = test.join(test.progress_apply(lambda row: cond_merge(row), axis=1, result_type='expand'))
# test.to_parquet('derived_data/stores_bus_stops_lt_1km_test')
# Out:
#   1%|          | 258/41543 [00:05<15:39, 43.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 16
#      12     return output_dict
#      14 data = pd.concat([train, train_extra], ignore_index=True)
# ---> 16 data = data.join(data.progress_apply(lambda row: cond_merge(row), axis=1, result_type='expand'))
#      17 data.to_parquet('derived_data/stores_bus_stops_lt_1km_train_with_extras')
#      19 # test = test.join(test.progress_apply(lambda row: cond_merge(row), axis=1, result_type='expand'))
#      20 # test.to_parquet('derived_data/stores_bus_stops_lt_1km_test')
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/geodataframe.py:1482, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1480 @doc(pd.DataFrame)
#    1481 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1482     result = super().apply(
#    1483         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1484     )
#    1485     # Reconstruct gdf if it was lost by apply
#    1486     if (
#    1487         isinstance(result, DataFrame)
#    1488         and self._geometry_column_name in result.columns
#    1489     ):
#    1490         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/frame.py:9555, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9544 from pandas.core.apply import frame_apply
#    9546 op = frame_apply(
#    9547     self,
#    9548     func=func,
#    (...)
#    9553     kwargs=kwargs,
#    9554 )
# -> 9555 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/apply.py:889, in FrameApply.apply_series_generator(self)
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# Cell In [4], line 16, in <lambda>(row)
#      12     return output_dict
#      14 data = pd.concat([train, train_extra], ignore_index=True)
# ---> 16 data = data.join(data.progress_apply(lambda row: cond_merge(row), axis=1, result_type='expand'))
#      17 data.to_parquet('derived_data/stores_bus_stops_lt_1km_train_with_extras')
#      19 # test = test.join(test.progress_apply(lambda row: cond_merge(row), axis=1, result_type='expand'))
#      20 # test.to_parquet('derived_data/stores_bus_stops_lt_1km_test')
#
# Cell In [4], line 5, in cond_merge(row)
#       2 output_dict = {}
#       3 gp.options.use_pygeos = True
# ----> 5 stops_with_dist = busstops[busstops.distance(row.geometry) < 1000]
#       6 output_dict['bus_stops_count'] = len(stops_with_dist)
#       8 output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
#       9     busstops.importance_level.unique(), fill_value=0
#      10 ).to_dict())
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/base.py:2153, in GeoPandasBase.distance(self, other, align)
#    2059 def distance(self, other, align=True):
#    2060     """Returns a ``Series`` containing the distance to aligned `other`.
#    2061
#    2062     The operation works on a 1-to-1 row-wise manner:
#    (...)
#    2151     dtype: float64
#    2152     """
# -> 2153     return _binary_op("distance", self, other, align)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/base.py:59, in _binary_op(op, this, other, align, *args, **kwargs)
#      56 def _binary_op(op, this, other, align, *args, **kwargs):
#      57     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      58     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 59     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      60     return Series(data, index=index)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/base.py:43, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      40 else:
#      41     raise TypeError(type(this), type(other))
# ---> 43 data = getattr(a_this, op)(other, *args, **kwargs)
#      44 return data, this.index
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/array.py:608, in GeometryArray.distance(self, other)
#     606 def distance(self, other):
#     607     self.check_geographic_crs(stacklevel=6)
# --> 608     return self._binary_method("distance", self, other)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/array.py:536, in GeometryArray._binary_method(op, left, right, **kwargs)
#     533         _crs_mismatch_warn(left, right, stacklevel=7)
#     534     right = right.data
# --> 536 return getattr(vectorized, op)(left.data, right, **kwargs)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/_vectorized.py:855, in distance(data, other)
#     853     return shapely.distance(data, other)
#     854 elif compat.USE_PYGEOS:
# --> 855     return _binary_method("distance", data, other)
#     856 else:
#     857     return _binary_op_float("distance", data, other)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/_vectorized.py:282, in _binary_method(op, left, right, **kwargs)
#     280 if isinstance(right, BaseGeometry):
#     281     right = from_shapely([right])[0]
# --> 282 return getattr(pygeos, op)(left, right, **kwargs)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pygeos/decorators.py:80, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      78     for arr in array_args:
#      79         arr.flags.writeable = False
# ---> 80     return func(*args, **kwargs)
#      81 finally:
#      82     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pygeos/measurement.py:72, in distance(a, b, **kwargs)
#      47 @multithreading_enabled
#      48 def distance(a, b, **kwargs):
#      49     """Computes the Cartesian distance between two geometries.
#      50
#      51     Parameters
#    (...)
#      70     nan
#      71     """
# ---> 72     return lib.distance(a, b, **kwargs)
#
# KeyboardInterrupt:

# %%
data
# Out:
#                          store_id                          geometry  \
# 0       983540538-974187930-44774   POINT (1136007.376 8342763.593)
# 1       987074191-973117734-44755   POINT (1194906.839 8380562.352)
# 2       984890265-981157303-64491   POINT (1141543.072 8436509.485)
# 3      914057442-992924179-126912  POINT (1600751.595 10237351.427)
# 4      913018583-913063538-668469   POINT (1154921.068 9188593.406)
# ...                           ...                               ...
# 41538   931186744-982303729-41793   POINT (1139514.362 8207041.705)
# 41539    931186744-983814964-6308   POINT (1162461.103 9205008.601)
# 41540  931186744-990018995-100187    POINT (592250.550 8492500.004)
# 41541   931186744-971707283-20794    POINT (829508.323 7972078.436)
# 41542   931186744-973116711-40587   POINT (1200374.617 8390831.794)
#
#        bus_stops_count  Mangler viktighetsnivå  Standard holdeplass  \
# 0                    2                       2                    0
# 1                   25                      15                    0
# 2                    9                       9                    0
# 3                    7                       1                    0
# 4                   19                       4                   11
# ...                ...                     ...                  ...
# 41538                7                       5                    1
# 41539                8                       5                    3
# 41540                5                       4                    1
# 41541                3                       3                    0
# 41542                6                       6                    0
#
#        Lokalt knutepunkt  Nasjonalt knutepunkt  Regionalt knutepunkt  \
# 0                      0                     0                     0
# 1                      9                     0                     1
# 2                      0                     0                     0
# 3                      0                     0                     6
# 4                      2                     0                     0
# ...                  ...                   ...                   ...
# 41538                  0                     0                     0
# 41539                  0                     0                     0
# 41540                  0                     0                     0
# 41541                  0                     0                     0
# 41542                  0                     0                     0
#
#        Annen viktig holdeplass
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            2
# ...                        ...
# 41538                        1
# 41539                        0
# 41540                        0
# 41541                        0
# 41542                        0
#
# [41543 rows x 9 columns]

# %%
bus_data_train = gp.read_parquet('derived_data/stores_bus_stops_lt_1km_train')
print(bus_data_train.bus_stops_count.sum())
len(bus_data_train)
# Out:
# 117446
# 12859

# %%
bus_data_train = gp.read_parquet('derived_data/stores_bus_stops_lt_1km_train_with_extras')[:12859]
print(bus_data_train.bus_stops_count.sum())
len(bus_data_train)
# Out:
# 117446
# 12859
