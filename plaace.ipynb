# %%
import pandas as pd

plaace = pd.read_csv('data/plaace_hierarchy.csv')

# %%
plaace
# Out:
#     plaace_hierarchy_id         sales_channel_name  lv1  \
# 0               1.1.1.0      Hamburger restaurants    1
# 1               1.1.2.0  Sushi and wok restaurants    1
# 2               1.1.3.0           Thai restaurants    1
# 3               1.1.4.0        Chinese restaurants    1
# 4               1.1.5.0          Pizza restaurants    1
# ..                  ...                        ...  ...
# 104             3.5.2.0             Tour operators    3
# 105             3.5.3.0       Advertising agencies    3
# 106             3.5.4.0              Funeral homes    3
# 107             3.5.5.0       Real estate agencies    3
# 108             3.6.1.0                       Gyms    3
#
#                    lv1_desc  lv2    lv2_desc    lv3  \
# 0    Dining and Experiences  1.1  Restaurant  1.1.1
# 1    Dining and Experiences  1.1  Restaurant  1.1.2
# 2    Dining and Experiences  1.1  Restaurant  1.1.3
# 3    Dining and Experiences  1.1  Restaurant  1.1.4
# ...

# %%
plaace.lv2_desc.unique().size
# Out:
# 20
