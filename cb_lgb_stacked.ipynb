# %% [markdown]
# # 1. Initial setup

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.1 Install required packages
#
# We ran into some issues with some of the geo related packages, such as geopandas, on certain machines. If the code does not run on your machine, you can comment out the lines commented with "# GEO PROBLEM HERE", and it will hopefully allow the code to run. This may of course impact the final score.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: attrs==22.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: autopep8==2.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: backcall==0.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: catboost==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: certifi==2022.9.24 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2022.9.24)
# Requirement already satisfied: click==8.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (8.1.3)
# Requirement already satisfied: click-plugins==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: cligj==0.7.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: colorama==0.4.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: contourpy==1.0.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (0.11.0)
# Requirement already satisfied: Cython==0.29.28 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.29.28)
# Requirement already satisfied: debugpy==1.6.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.4)
# Requirement already satisfied: executing==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: Fiona==1.8.22 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.8.22)
# Requirement already satisfied: fonttools==4.38.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (4.38.0)
# Requirement already satisfied: gensim==4.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (4.2.0)
# Requirement already satisfied: geographiclib==1.52 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (1.52)
# Requirement already satisfied: geopandas==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: geopy==2.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (2.2.0)
# Requirement already satisfied: graphviz==0.20.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (0.20.1)
# Requirement already satisfied: ipykernel==6.17.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (6.17.0)
# Requirement already satisfied: ipython==8.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (8.6.0)
# Requirement already satisfied: jedi==0.18.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (0.18.1)
# Requirement already satisfied: joblib==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: jupyter_client==7.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (7.4.4)
# Requirement already satisfied: jupyter_core==4.11.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (4.11.2)
# Requirement already satisfied: kiwisolver==1.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (1.4.4)
# Requirement already satisfied: matplotlib==3.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (3.6.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (0.1.6)
# Requirement already satisfied: munch==2.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (2.5.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (1.5.6)
# Requirement already satisfied: numpy==1.23.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (1.23.4)
# Requirement already satisfied: packaging==21.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (21.3)
# Requirement already satisfied: pandas==1.5.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (1.5.1)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (0.7.5)
# Requirement already satisfied: Pillow==9.3.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (9.3.0)
# Requirement already satisfied: plotly==5.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (5.11.0)
# Requirement already satisfied: prompt-toolkit==3.0.31 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (3.0.31)
# Requirement already satisfied: psutil==5.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (5.9.3)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (0.2.2)
# Requirement already satisfied: pyarrow==10.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (10.0.0)
# Requirement already satisfied: pycodestyle==2.9.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.9.1)
# Requirement already satisfied: pygeos==0.13 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.13)
# Requirement already satisfied: Pygments==2.13.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (2.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (3.0.9)
# Requirement already satisfied: pyproj==3.4.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (3.4.0)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2.8.2)
# Requirement already satisfied: pytz==2022.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (2022.6)
# Requirement already satisfied: pyzmq==24.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (24.0.1)
# Requirement already satisfied: scikit-learn==1.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (1.1.3)
# Requirement already satisfied: scipy==1.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (0.12.1)
# Requirement already satisfied: Shapely==1.8.5.post1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (1.8.5.post1)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (1.16.0)
# Requirement already satisfied: sklearn==0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (0.0)
# Requirement already satisfied: smart-open==6.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.2.0)
# Requirement already satisfied: stack-data==0.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (0.6.0)
# Requirement already satisfied: tenacity==8.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (8.1.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (3.1.0)
# Requirement already satisfied: tomli==2.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (2.0.1)
# Requirement already satisfied: tornado==6.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (6.2)
# Requirement already satisfied: tqdm==4.64.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (4.64.1)
# Requirement already satisfied: traitlets==5.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (5.5.0)
# Requirement already satisfied: wcwidth==0.2.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 69)) (0.2.5)
# Requirement already satisfied: xgboost==1.7.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (1.7.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from Fiona==1.8.22->-r requirements.txt (line 18)) (44.0.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./venv/lib/python3.8/site-packages (from ipython==8.6.0->-r requirements.txt (line 26)) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython==8.6.0->-r requirements.txt (line 26)) (0.7.0)

# %% [markdown]
# ## 1.2 Import packages and data

# %%
# %autoreload

import warnings
import os.path
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import geopy
import os
import shutil
import geopandas as gpd
import catboost as cb
import optuna
import lightgbm as lgb
import geopandas as gpd

from pyproj import Geod
from shapely import wkt
from shapely.geometry import Point, LineString
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_log_error
from typing import Callable, Dict, List, Tuple
from catboost.utils import get_gpu_device_count
from tqdm import tqdm

tqdm.pandas()

warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None  # default='warn'

SEED = 23

spatial = pd.read_csv('data/grunnkrets_norway_stripped.csv')
age = pd.read_csv('data/grunnkrets_age_distribution.csv')
income = pd.read_csv('data/grunnkrets_income_households.csv').set_index(['grunnkrets_id', 'year']).add_prefix('income_').reset_index()
households = pd.read_csv('data/grunnkrets_households_num_persons.csv')
submission = pd.read_csv('data/sample_submission.csv')
plaace = pd.read_csv('data/plaace_hierarchy.csv')
busstops = pd.read_csv('data/busstops_norway.csv')

train = pd.read_csv('data/stores_train.csv')
train_extra = pd.read_csv('data/stores_extra.csv')
test = pd.read_csv('data/stores_test.csv') 

submission = pd.read_csv('data/sample_submission.csv')  # Please do not delete this file

# %% [markdown]
# Create geopandas version of some of the datasets:

# %%
busstops_geo = gpd.GeoDataFrame(busstops, geometry=busstops.geometry.apply(wkt.loads))

train_geo = gpd.GeoDataFrame(train[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train.lon, train.lat)).drop(columns=['lon', 'lat'])
train_geo = train_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

train_geo_extra = gpd.GeoDataFrame(train_extra[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train_extra.lon, train_extra.lat)).drop(columns=['lon', 'lat'])
train_geo_extra = train_geo_extra.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

test_geo = gpd.GeoDataFrame(test[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(test.lon, test.lat)).drop(columns=['lon', 'lat'])
test_geo = test_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

# %% [markdown]
# ## 1.2 Helper functions

# %%
def rmsle(y_true, y_pred):
    y_pred[y_pred < 0] = 0 + 1e-6
    y_true[y_true < 0] = 0 + 1e-6
    return np.sqrt(mean_squared_log_error(y_true, y_pred))


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def to_categorical(df: pd.DataFrame):
    for cat_col in df.select_dtypes(include=[object]).columns:
        df[cat_col] = df[cat_col].astype('category')
    return df


def object_encoder(df: pd.DataFrame):
    enc = OrdinalEncoder()
    obj_cols = df.select_dtypes(include=[object]).columns
    df[obj_cols] = enc.fit_transform(df[obj_cols])
    return df


def nan_to_string(df: pd.DataFrame):
    nan = '#N/A'
    cols = df[df.columns[df.isna().any()]].columns
    df[cols] = df[cols].fillna(nan)
    return df


def meter_distance(lat1, lon1, lat2, lon2):
    line_string = LineString([Point(lon1, lat1), Point(lon2, lat2)])
    geod = Geod(ellps="WGS84")
    return geod.geometry_length(line_string)


def add_city_centre_dist(X: pd.DataFrame):
    old_shape = X.shape

    city_centres = X.groupby(['municipality_name'])[['lat', 'lon']].apply(lambda x: x.sum() / (x.count()))[['lat', 'lon']]
    X = X.merge(city_centres, on=['municipality_name'], how='left', suffixes=(None, '_center'))
    assert X.shape[0] == old_shape[0]

    X.fillna(value={'lat_center': X.lat, 'lon_center': X.lon}, inplace=True)

    X['dist_to_center'] = X.apply(lambda row: meter_distance(row.lat, row.lon, row.lat_center, row.lon_center), axis=1)
    assert X.shape[0] == old_shape[0]

    return X


def group_ages(age: pd.DataFrame, age_ranges: List[Tuple[int, int]]):
    age_new = age[['grunnkrets_id', 'year']].drop_duplicates(subset=['grunnkrets_id'], keep='last')

    for rng in age_ranges:
        cols = [f'age_{age}' for age in range(rng[0], rng[1] + 1)]
        rng_sum = age[cols].sum(axis=1).astype(int)
        age_new[f'age_{rng[0]}_{rng[-1]}'] = rng_sum

    age = age.drop_duplicates(subset='grunnkrets_id').drop(columns=['year', *(f'age_{age}' for age in range(0, 91))], axis=1)
    age = age.merge(age_new.drop(columns=['year']), on='grunnkrets_id')

    return age


def only_latest_data(df: pd.DataFrame):
    df = df.sort_values(by='year', ascending=False)
    df = df.drop_duplicates(subset='grunnkrets_id', keep='first')
    return df


def clean_out_nan_heavy_rows(df: pd.DataFrame, age, age_ranges, spatial_2016, income_2016, households_2016):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_2016.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df2[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna()) # df2.age_0_19.isna() | 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


def create_busstops_files():
    """
    Creates a .parquet file that stores info aboute the number of busstops within a 1 kilometer
    radius of a given store, as well as the number of stops within the different importance categories.  
    """

    def bus_fields(row: pd.Series):
        output_dict = {}
        gpd.options.use_pygeos = True
        
        stops_with_dist = busstops[busstops_geo.distance(row.geometry) < 1000]
        output_dict['bus_stops_count'] = len(stops_with_dist)
        
        output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
            busstops_geo.importance_level.unique(), fill_value=0
        ).to_dict())
        
        return output_dict

    train_with_extras_bus = pd.concat([train_geo, train_geo_extra], ignore_index=True)

    train_with_extras_bus = train_with_extras_bus.join(train_with_extras_bus.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    train_with_extras_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_train.parquet')

    test_bus = test_geo.join(test_geo.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    test_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_test.parquet')


def create_stores_in_vicinity_files():
    """
    Creates a .parquet file that stores info aboute the number of other stores within a 1 kilometer
    radius of a given store.
    """

    train_with_extras = pd.concat([train_geo, train_geo_extra], ignore_index=True)[['store_id', 'geometry']]

    def store_count_in_vicinity(row: pd.Series):
        stores_in_vicinity = train_with_extras[train_with_extras.distance(row.geometry) < 1000]
        return {'stores_count_lt_1km': len(stores_in_vicinity)}

    train_with_extras_vicinity = train_with_extras.join(train_with_extras.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    train_with_extras_vicinity.to_parquet('derived_data/stores_count_lt_1km_train.parquet')

    test_vicinity = test_geo.join(test_geo.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    test_vicinity.to_parquet('derived_data/stores_count_lt_1km_test.parquet')

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# The train and test data only contains data from 2016, so for the other datasets with an age column
# we only use the values from 2016, where possible.

# %%
age_ranges = [
    (0, 19),
    (20, 39),
    (40, 59),
    (60, 79),
    (80, 90),
]

spatial_latest = only_latest_data(spatial)
income_latest = only_latest_data(income)
households_latest = only_latest_data(households)

train_spatial = train.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
muni_avg_revenue = train_spatial.groupby(by='municipality_name', as_index=False)['revenue'].mean()

# %% [markdown]
# Futhermore, we noticed that a number of rows in the train and test datasets didn't have

# %%
def clean(df: pd.DataFrame, min_val=0, max_val=100):
    print('Length of data frame:', len(df))
    df = df[(df.revenue > min_val) & (df.revenue < max_val)]
    print('Length after removing extreme values and zero revenue retail stores:',  len(df))
    return df.drop(columns=['revenue']), df.revenue


def clean_out_nan_heavy_rows(df: pd.DataFrame):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_latest.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna())  # | df2.age_0_19.isna() 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


train = clean_out_nan_heavy_rows(train)
label_name = 'revenue'
X = train.drop(columns=[label_name])
y = train[label_name]

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=.8, random_state=SEED)
X_train, y_train = clean(pd.merge(X_train, y_train, left_index=True, right_index=True))

y_train = np.log1p(y_train)
y_val = np.log1p(y_val)
# Out:
# Cleaned out 127 out of 12859 rows.
# Length of data frame: 10185
# Length after removing extreme values and zero revenue retail stores: 9947

# %% [markdown]
# # 3. Feature generation

# %% [markdown]
# Create files for busstops and stores in vicinity of each store:

# %%
# !mkdir -p derived_data

create_busstops_files()
create_stores_in_vicinity_files()

# %%
def generate_features(df: pd.DataFrame, data_origin: str, predictor: str = ''):
    # Define datasets to be merged
    age_groups_merge = group_ages(age, age_ranges)
    spatial_merge = spatial_latest.drop(columns=['year'])
    income_merge = income_latest.drop(columns=['year'])
    households_merge = households_latest.drop(columns=['year'])
    plaace_merge = plaace.drop_duplicates(subset='plaace_hierarchy_id')
    bus_data_train_merge = gpd.read_parquet(f'derived_data/stores_bus_stops_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])
    stores_vicinity_merge = gpd.read_parquet(f'derived_data/stores_count_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])

    # Merge datasets
    df = df.merge(age_groups_merge, on='grunnkrets_id', how='left')
    df = df.merge(spatial_merge, on='grunnkrets_id', how='left')
    df = df.merge(income_merge, on='grunnkrets_id', how='left')
    df = df.merge(households_merge, on='grunnkrets_id', how='left')
    df = df.merge(plaace_merge, how='left')
    df = df.merge(bus_data_train_merge, on='store_id', how='left')
    df = df.merge(stores_vicinity_merge, on='store_id', how='left')
    df = add_city_centre_dist(df).drop(columns=['lon_center', 'lat_center'])

    # Transformations and some post-merge cleaning
    df.stores_count_lt_1km = np.log(df.stores_count_lt_1km)
    df[age_groups_merge.columns] = df[age_groups_merge.columns].fillna(0)
    
    # Handle categories for different predictors
    if predictor == 'xgb':
        df = object_encoder(df)
    elif predictor == 'cb':
        df = nan_to_string(df)
    elif predictor == 'lgb':
        df = to_categorical(df)
    else: 
        raise ValueError('Invalid predictor')

    features = [
        'store_name', 
        'mall_name', 
        'chain_name',
        'address', 
        'lat', 'lon',
        
        *age_groups_merge.drop(columns=['grunnkrets_id']).columns,
        *income_merge.drop(columns=['grunnkrets_id']).columns,
        *households_merge.drop(columns=['grunnkrets_id']).columns,
        'lv1_desc', 'lv2_desc', 'sales_channel_name', 
        *bus_data_train_merge.drop(columns=['store_id']).columns,
        *stores_vicinity_merge.drop(columns=['store_id']).columns,
        'dist_to_center'
    ]

    return df[features]

# %%
# Features adapted to Catboost
X_train_cb = generate_features(X_train, data_origin='train', predictor='cb')
X_val_cb = generate_features(X_val, data_origin='train', predictor='cb')
X_test_cb = generate_features(test, data_origin='test', predictor='cb')

# Features adapted to LightGBM
X_train_lgb = generate_features(X_train, data_origin='train', predictor='lgb')
X_val_lgb = generate_features(X_val, data_origin='train', predictor='lgb')
X_test_lgb = generate_features(test, data_origin='test', predictor='lgb')

# %% [markdown]
# # 4. Hyper parameter tuning

# %% [markdown]
# ### Preparing pools and parameter grid for Catboost

# %%
def get_cb_pools():
    text_features = ['store_name', 'address', 'sales_channel_name'] 
    cat_features = ['mall_name', 'chain_name', 'lv1_desc', 'lv2_desc']

    train_pool = cb.Pool(
        X_train_cb,
        y_train,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    valid_pool = cb.Pool(
        X_val_cb,
        y_val,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    return train_pool, valid_pool


def get_cb_params(trial: optuna.Trial = None):
    gpu_count = get_gpu_device_count()
    non_tunable_cb_params = {
        'objective': 'RMSE',
        'eval_metric': 'RMSE',
        'task_type': 'GPU' if gpu_count else 'CPU', 
        'devices': f'0:{gpu_count}',
        'random_seed': SEED
    }

    if trial is None:
        return 'cb', non_tunable_cb_params
    
    tunable_params = {
        'depth': trial.suggest_int('depth', 4, 9),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 2, 6),
        # 'iterations': trial.suggest_int('iterations', 1000, 2000),
        # 'learning_rate': trial.suggest_categorical('learning_rate', 0.1, 0.5)
    }

    return 'cb', non_tunable_cb_params, tunable_params

# %% [markdown]
# ### Preparing DMatrices and parameter grid for LightGBM

# %%
def get_lgb_dmatrices():
    dtrain = lgb.Dataset(X_train_lgb, y_train, params={'verbose': -1}, free_raw_data=False)
    dvalid = lgb.Dataset(X_val_lgb, y_val, params={'verbose': -1}, free_raw_data=False)
    return dtrain, dvalid


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def get_lgb_params(trial: optuna.Trial = None):
    non_tunable_lgb_params = {
        'objective': 'rmse',
        'verbose': -1,
        'seed': 1
    }

    if trial is None:
        return 'lgb', non_tunable_lgb_params

    tunable_params = {
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'goss', 'dart']),
    }

    if tunable_params['boosting_type'] != 'goss':
        tunable_params["bagging_fraction"]: trial.suggest_float("bagging_fraction", 0.4, 1.0)
        tunable_params["bagging_freq"]: trial.suggest_int("bagging_freq", 1, 7)

    return 'lgb', non_tunable_lgb_params, tunable_params

# %% [markdown]
# ### Hyper parameter tuning with Optuna

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def objective(trial: optuna.Trial, param_grid_fn: Callable) -> float:
    model_name, non_tunable_params, tunable_params = param_grid_fn(trial)
  
    if model_name == 'cb':
        if tunable_params['bootstrap_type'] == 'Bayesian': 
            tunable_params['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)
        elif tunable_params['bootstrap_type'] == 'Bernoulli':
            tunable_params['subsample'] = trial.suggest_float('subsample', 0.1, 1, log=True)

        cbr = cb.CatBoostRegressor(**non_tunable_params, **tunable_params) 
        train_pool, valid_pool = get_cb_pools()
        cbr.fit(
            train_pool,
            eval_set=[(X_val_cb, y_val)],
            verbose=0,
            early_stopping_rounds=100,
        )
        y_pred = cbr.predict(X_val_cb)
    
    elif model_name == 'lgb':
        dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
        lgbr = lgb.train(
            params={**non_tunable_params, **tunable_params},
            train_set=dtrain_lgb,
            valid_sets=dvalid_lgb,
            verbose_eval=False,
        )
        y_pred = lgbr.predict(X_val_lgb)

    score = rmsle(np.expm1(y_val), np.expm1(y_pred))

    return score


def get_hyper_parameters(param_grid_fn: Callable, n_trials=100):
    study = optuna.create_study(
        study_name='hyperparam-tuning',
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), 
        direction='minimize'
    )
    objective_fn = lambda trial: objective(trial, param_grid_fn)
    study.optimize(objective_fn, n_trials=n_trials, timeout=900) 

    print('Number of finished trials: {}'.format(len(study.trials)))
    
    trial = study.best_trial
    print(f'Best trial ({trial.number}):')
    print('Value:', trial.value)
    print('Params:')
    print(trial.params)

    return param_grid_fn()[1], trial.params

# %% [markdown]
# # 5. Training step

# %% [markdown]
# ### Making predictions with Catboost

# %%
non_tunable_cb_params, tuned_params = get_hyper_parameters(get_cb_params, n_trials=30)
train_pool, valid_pool = get_cb_pools()
cbm = cb.CatBoostRegressor(**non_tunable_cb_params, **tuned_params, iterations=1000) 
cbm.fit(train_pool, eval_set=valid_pool, verbose=50, plot=True, early_stopping_rounds=50)
# Out:
# [I 2022-11-12 19:59:38,554] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-12 19:59:45,953] Trial 0 finished with value: 0.7330940682447403 and parameters: {'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.338363206347648, 'subsample': 0.26080466400437363}. Best is trial 0 with value: 0.7330940682447403.
# [I 2022-11-12 19:59:52,616] Trial 1 finished with value: 0.7588572815696333 and parameters: {'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 5.880584597973565}. Best is trial 0 with value: 0.7330940682447403.
# [I 2022-11-12 20:00:05,941] Trial 2 finished with value: 0.8036763419770735 and parameters: {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.520235165666794, 'bagging_temperature': 9.78424759900321}. Best is trial 0 with value: 0.7330940682447403.
# [I 2022-11-12 20:00:43,551] Trial 3 finished with value: 0.7286395361537851 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.6094950730333135, 'subsample': 0.30825353478499606}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:00:51,675] Trial 4 finished with value: 0.7420675397765005 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 4.576098391637873}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:01:06,146] Trial 5 finished with value: 0.7394252774202595 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.4905866860410057}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:01:18,293] Trial 6 finished with value: 0.7441617739876557 and parameters: {'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.324006683115458, 'bagging_temperature': 4.085221856966878}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:01:25,870] Trial 7 finished with value: 0.7423735883004541 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.979635388328743, 'bagging_temperature': 2.726712106250353}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:01:31,808] Trial 8 finished with value: 0.7854099381467872 and parameters: {'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.3776118459292213, 'bagging_temperature': 9.34608289150557}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:01:35,777] Trial 9 finished with value: 0.7622753308844821 and parameters: {'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 5.686523964604659}. Best is trial 3 with value: 0.7286395361537851.
# [I 2022-11-12 20:02:12,865] Trial 10 finished with value: 0.7248696766813314 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.374199112207169, 'subsample': 0.8010781225972985}. Best is trial 10 with value: 0.7248696766813314.
# [I 2022-11-12 20:02:50,172] Trial 11 finished with value: 0.7243537494624922 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.304356702223779, 'subsample': 0.893806281538314}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:03:13,200] Trial 12 finished with value: 0.726777553986363 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.200529059122581, 'subsample': 0.9686146284368797}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:03:50,554] Trial 13 finished with value: 0.7249950263178593 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.721889284927254, 'subsample': 0.9125553088794294}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:04:06,447] Trial 14 finished with value: 0.726970343569366 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.842371459617742, 'subsample': 0.6122663181774676}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:04:44,584] Trial 15 finished with value: 0.7351078812772586 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.349194478348334, 'subsample': 0.10852463003281218}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:05:08,043] Trial 16 finished with value: 0.7272975733260808 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.803547114734411, 'subsample': 0.5429603648527412}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:05:19,705] Trial 17 finished with value: 0.7279895275113932 and parameters: {'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.060060191033943, 'subsample': 0.5450714634100978}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:05:35,472] Trial 18 finished with value: 0.7267561346113152 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.104121281055059, 'subsample': 0.7781312972191955}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:06:13,005] Trial 19 finished with value: 0.7281645685703955 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.021740687169739, 'subsample': 0.3993289609491206}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:06:36,706] Trial 20 finished with value: 0.7320401815128581 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.8372816545424553, 'subsample': 0.19641734268235897}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:07:13,597] Trial 21 finished with value: 0.7267453591638395 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.7397507957280376, 'subsample': 0.9693714202622785}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:07:50,839] Trial 22 finished with value: 0.7246571197731615 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.47652434307294, 'subsample': 0.7360455645212104}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:08:14,200] Trial 23 finished with value: 0.7253317087427118 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.540062267224509, 'subsample': 0.6926850068154549}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:08:52,267] Trial 24 finished with value: 0.7265520652594166 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.781356577567179, 'subsample': 0.4401820909471841}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:09:15,677] Trial 25 finished with value: 0.7262009822396708 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.30237518769066, 'subsample': 0.6877319464383406}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:09:26,825] Trial 26 finished with value: 0.7302309628809995 and parameters: {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.208646731162811, 'subsample': 0.4441382595282324}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:09:42,637] Trial 27 finished with value: 0.7261912749123263 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.552236191637109, 'subsample': 0.7712320982114484}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:10:19,485] Trial 28 finished with value: 0.7260235962000635 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.01764688659609, 'bagging_temperature': 0.10579299426329758}. Best is trial 11 with value: 0.7243537494624922.
# [I 2022-11-12 20:10:23,970] Trial 29 finished with value: 0.7605086153393396 and parameters: {'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.279614233209937}. Best is trial 11 with value: 0.7243537494624922.
# Number of finished trials: 30
# Best trial (11):
# Value: 0.7243537494624922
# Params:
# {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.304356702223779, 'subsample': 0.893806281538314}
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.9763973	test: 0.9981485	best: 0.9981485 (0)	total: 46.8ms	remaining: 46.8s
# 50:	learn: 0.7429537	test: 0.7771055	best: 0.7771055 (50)	total: 2.4s	remaining: 44.7s
# 100:	learn: 0.7090352	test: 0.7502924	best: 0.7502924 (100)	total: 4.74s	remaining: 42.2s
# 150:	learn: 0.6958025	test: 0.7417209	best: 0.7417209 (150)	total: 6.83s	remaining: 38.4s
# 200:	learn: 0.6877736	test: 0.7371772	best: 0.7371772 (200)	total: 8.82s	remaining: 35.1s
# 250:	learn: 0.6816462	test: 0.7341655	best: 0.7341622 (249)	total: 10.8s	remaining: 32.1s
# 300:	learn: 0.6770744	test: 0.7323245	best: 0.7323245 (300)	total: 12.6s	remaining: 29.3s
# 350:	learn: 0.6728623	test: 0.7307130	best: 0.7307130 (350)	total: 14.4s	remaining: 26.7s
# 400:	learn: 0.6685938	test: 0.7289777	best: 0.7289777 (400)	total: 16.1s	remaining: 24.1s
# 450:	learn: 0.6653335	test: 0.7279988	best: 0.7279988 (450)	total: 17.8s	remaining: 21.7s
# 500:	learn: 0.6618104	test: 0.7272364	best: 0.7272364 (500)	total: 19.6s	remaining: 19.5s
# 550:	learn: 0.6589330	test: 0.7268483	best: 0.7267874 (540)	total: 21.3s	remaining: 17.4s
# 600:	learn: 0.6563629	test: 0.7262719	best: 0.7262639 (599)	total: 23.1s	remaining: 15.3s
# 650:	learn: 0.6541942	test: 0.7259703	best: 0.7259619 (646)	total: 24.8s	remaining: 13.3s
# 700:	learn: 0.6522681	test: 0.7257292	best: 0.7257074 (681)	total: 26.5s	remaining: 11.3s
# 750:	learn: 0.6505842	test: 0.7254877	best: 0.7254852 (749)	total: 28.2s	remaining: 9.35s
# 800:	learn: 0.6486904	test: 0.7253148	best: 0.7252979 (795)	total: 29.9s	remaining: 7.43s
# 850:	learn: 0.6464666	test: 0.7249890	best: 0.7249890 (850)	total: 31.6s	remaining: 5.54s
# 900:	learn: 0.6444129	test: 0.7245788	best: 0.7245727 (898)	total: 33.4s	remaining: 3.67s
# 950:	learn: 0.6427900	test: 0.7244812	best: 0.7244506 (944)	total: 35.1s	remaining: 1.81s
# 999:	learn: 0.6413089	test: 0.7243612	best: 0.7243537 (997)	total: 36.7s	remaining: 0us
# bestTest = 0.7243537459
# bestIteration = 997
# Shrink model to first 998 iterations.

# %% [markdown]
# ### Making predictions with LightGBM

# %%
non_tunable_lgb_params, tunable_lgb_params = get_hyper_parameters(get_lgb_params, n_trials=400)
dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
lgbm = lgb.train(
    params={**non_tunable_lgb_params, **tunable_lgb_params},
    train_set=dtrain_lgb,
    valid_sets=dvalid_lgb,
    verbose_eval=False
)
# Out:
# [I 2022-11-12 20:11:01,546] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-12 20:11:03,075] Trial 0 finished with value: 0.7734736984135481 and parameters: {'lambda_l1': 5.937657937159587e-06, 'lambda_l2': 0.0006106056250766662, 'num_leaves': 161, 'feature_fraction': 0.6019866309070614, 'min_child_samples': 24, 'boosting_type': 'goss'}. Best is trial 0 with value: 0.7734736984135481.
# [I 2022-11-12 20:11:03,358] Trial 1 finished with value: 0.7493501530898367 and parameters: {'lambda_l1': 2.949662399517019e-07, 'lambda_l2': 3.799111792555383, 'num_leaves': 35, 'feature_fraction': 0.682627468554158, 'min_child_samples': 29, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:03,931] Trial 2 finished with value: 0.7637019665235887 and parameters: {'lambda_l1': 0.0001987042217025302, 'lambda_l2': 1.0669235114828269e-07, 'num_leaves': 119, 'feature_fraction': 0.46773910628246157, 'min_child_samples': 60, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:04,242] Trial 3 finished with value: 0.7719690317591917 and parameters: {'lambda_l1': 2.063276500046728e-08, 'lambda_l2': 0.0003653183952423071, 'num_leaves': 214, 'feature_fraction': 0.8052885489598067, 'min_child_samples': 35, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:04,651] Trial 4 finished with value: 0.7534478163430243 and parameters: {'lambda_l1': 6.355366127934589e-06, 'lambda_l2': 4.455894199979579, 'num_leaves': 135, 'feature_fraction': 0.7093156668189432, 'min_child_samples': 57, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:04,896] Trial 5 finished with value: 0.7704039908330759 and parameters: {'lambda_l1': 0.00020089240964625037, 'lambda_l2': 1.0321062058446605e-08, 'num_leaves': 108, 'feature_fraction': 0.7426163235494558, 'min_child_samples': 35, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:05,065] Trial 6 finished with value: 0.762729452559605 and parameters: {'lambda_l1': 2.508490773166587e-07, 'lambda_l2': 0.029278840249938324, 'num_leaves': 24, 'feature_fraction': 0.9119953776855333, 'min_child_samples': 5, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:05,479] Trial 7 finished with value: 0.7559137034046031 and parameters: {'lambda_l1': 0.15077797056800188, 'lambda_l2': 0.1582092351212596, 'num_leaves': 125, 'feature_fraction': 0.5830927968026854, 'min_child_samples': 5, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.7493501530898367.
# [I 2022-11-12 20:11:05,615] Trial 8 finished with value: 0.7385126197877816 and parameters: {'lambda_l1': 0.0014706669202683503, 'lambda_l2': 7.23292244400957e-06, 'num_leaves': 12, 'feature_fraction': 0.4950160443564041, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 0.7385126197877816.
# [I 2022-11-12 20:11:06,243] Trial 9 finished with value: 0.7569704877561592 and parameters: {'lambda_l1': 1.507907133615683e-07, 'lambda_l2': 1.1875723909443345, 'num_leaves': 87, 'feature_fraction': 0.973877853538739, 'min_child_samples': 21, 'boosting_type': 'dart'}. Best is trial 8 with value: 0.7385126197877816.
# [I 2022-11-12 20:11:06,633] Trial 10 finished with value: 0.7445143347720315 and parameters: {'lambda_l1': 0.9133843576853387, 'lambda_l2': 1.0595462431970528e-06, 'num_leaves': 253, 'feature_fraction': 0.41953725642234163, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 0.7385126197877816.
# [I 2022-11-12 20:11:06,880] Trial 11 finished with value: 0.7407685402219601 and parameters: {'lambda_l1': 6.574897346158516, 'lambda_l2': 1.9979681273614796e-06, 'num_leaves': 253, 'feature_fraction': 0.41453674104564914, 'min_child_samples': 99, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 0.7385126197877816.
# [I 2022-11-12 20:11:07,471] Trial 12 finished with value: 0.7489508693722906 and parameters: {'lambda_l1': 0.037101218842619306, 'lambda_l2': 3.487436943195552e-06, 'num_leaves': 187, 'feature_fraction': 0.5186230698993571, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 0.7385126197877816.
# [I 2022-11-12 20:11:07,850] Trial 13 finished with value: 0.7414352024075633 and parameters: {'lambda_l1': 4.850606882053834, 'lambda_l2': 7.38487345686362e-06, 'num_leaves': 67, 'feature_fraction': 0.40656020663840065, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 8 with value: 0.7385126197877816.
# [I 2022-11-12 20:11:08,005] Trial 14 finished with value: 0.736164515068141 and parameters: {'lambda_l1': 0.012962962059921779, 'lambda_l2': 3.5275170979839604e-05, 'num_leaves': 7, 'feature_fraction': 0.5250385735207617, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 14 with value: 0.736164515068141.
# [I 2022-11-12 20:11:08,380] Trial 15 finished with value: 0.7375664098247975 and parameters: {'lambda_l1': 0.005873545969139579, 'lambda_l2': 2.3057552311645088e-05, 'num_leaves': 19, 'feature_fraction': 0.5420804880301502, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 14 with value: 0.736164515068141.
# [I 2022-11-12 20:11:09,139] Trial 16 finished with value: 0.743255742723679 and parameters: {'lambda_l1': 0.005552963462534757, 'lambda_l2': 0.004135780985411188, 'num_leaves': 49, 'feature_fraction': 0.5833743472685013, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 14 with value: 0.736164515068141.
# [I 2022-11-12 20:11:09,341] Trial 17 finished with value: 0.7356907020917274 and parameters: {'lambda_l1': 0.018504868029048868, 'lambda_l2': 8.417983000121573e-05, 'num_leaves': 6, 'feature_fraction': 0.6325127596470947, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:10,357] Trial 18 finished with value: 0.7496255326739409 and parameters: {'lambda_l1': 0.18636309855876038, 'lambda_l2': 7.643141889961473e-05, 'num_leaves': 63, 'feature_fraction': 0.6473184324799293, 'min_child_samples': 47, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:11,022] Trial 19 finished with value: 0.7397823971392327 and parameters: {'lambda_l1': 2.2801536492723504e-05, 'lambda_l2': 0.0036979270780022064, 'num_leaves': 3, 'feature_fraction': 0.7749208812168025, 'min_child_samples': 65, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:11,799] Trial 20 finished with value: 0.752465158061149 and parameters: {'lambda_l1': 0.02122193068521499, 'lambda_l2': 2.470496508367449e-07, 'num_leaves': 93, 'feature_fraction': 0.8599565597472791, 'min_child_samples': 86, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:11,945] Trial 21 finished with value: 0.7468912386246277 and parameters: {'lambda_l1': 0.0011251347849900364, 'lambda_l2': 4.8586243952198136e-05, 'num_leaves': 2, 'feature_fraction': 0.5657251364304053, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:12,359] Trial 22 finished with value: 0.7395082836207744 and parameters: {'lambda_l1': 0.00803141833957495, 'lambda_l2': 8.310065703343444e-05, 'num_leaves': 32, 'feature_fraction': 0.6447035814306845, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:13,020] Trial 23 finished with value: 0.74443154552697 and parameters: {'lambda_l1': 0.1376509558970871, 'lambda_l2': 2.1505106185935324e-05, 'num_leaves': 51, 'feature_fraction': 0.5304452794866941, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:13,267] Trial 24 finished with value: 0.7363836651404363 and parameters: {'lambda_l1': 0.001440945042994286, 'lambda_l2': 0.0015648740906364115, 'num_leaves': 26, 'feature_fraction': 0.47028419408349015, 'min_child_samples': 65, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:19,575] Trial 25 finished with value: 0.7512181749960599 and parameters: {'lambda_l1': 0.0008593337391420258, 'lambda_l2': 0.002948253710408684, 'num_leaves': 79, 'feature_fraction': 0.6219111477320541, 'min_child_samples': 48, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:19,871] Trial 26 finished with value: 0.7390569272776192 and parameters: {'lambda_l1': 5.71046935571315e-05, 'lambda_l2': 0.023431966102783086, 'num_leaves': 37, 'feature_fraction': 0.45992317101407537, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:20,248] Trial 27 finished with value: 0.7410151338830213 and parameters: {'lambda_l1': 0.862022084928795, 'lambda_l2': 0.0009714349487555475, 'num_leaves': 44, 'feature_fraction': 0.4845778542785169, 'min_child_samples': 55, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:20,489] Trial 28 finished with value: 0.7382877948538935 and parameters: {'lambda_l1': 0.03406744015299466, 'lambda_l2': 0.00019205245160888582, 'num_leaves': 20, 'feature_fraction': 0.6785604370842205, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:21,152] Trial 29 finished with value: 0.7534222723779636 and parameters: {'lambda_l1': 0.0031217328874130045, 'lambda_l2': 0.0008963880725817896, 'num_leaves': 154, 'feature_fraction': 0.6229607533750473, 'min_child_samples': 65, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:21,427] Trial 30 finished with value: 0.763363887356732 and parameters: {'lambda_l1': 0.00034922167566913824, 'lambda_l2': 0.01704677223529165, 'num_leaves': 66, 'feature_fraction': 0.4484237299557983, 'min_child_samples': 49, 'boosting_type': 'goss'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:21,630] Trial 31 finished with value: 0.7374434099357756 and parameters: {'lambda_l1': 0.01038994270987332, 'lambda_l2': 1.1240179681417993e-05, 'num_leaves': 21, 'feature_fraction': 0.5456334874412503, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:21,730] Trial 32 finished with value: 0.7380673965057277 and parameters: {'lambda_l1': 0.014224805247039073, 'lambda_l2': 0.00023847991414367164, 'num_leaves': 4, 'feature_fraction': 0.5534739789782694, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:21,983] Trial 33 finished with value: 0.7404931692998022 and parameters: {'lambda_l1': 0.06447624900799467, 'lambda_l2': 1.5036526184313534e-05, 'num_leaves': 31, 'feature_fraction': 0.4961336927287074, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:22,280] Trial 34 finished with value: 0.7432596046560593 and parameters: {'lambda_l1': 5.5470187638388465e-05, 'lambda_l2': 2.2288581356015452e-07, 'num_leaves': 51, 'feature_fraction': 0.6011898870748321, 'min_child_samples': 63, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:22,630] Trial 35 finished with value: 0.7490738230623915 and parameters: {'lambda_l1': 0.5697636292009671, 'lambda_l2': 8.959717545768208e-07, 'num_leaves': 18, 'feature_fraction': 0.7046342345881165, 'min_child_samples': 81, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:22,898] Trial 36 finished with value: 0.7613205335852249 and parameters: {'lambda_l1': 0.0004475409974671152, 'lambda_l2': 0.00046908387187537, 'num_leaves': 34, 'feature_fraction': 0.5179542476920411, 'min_child_samples': 59, 'boosting_type': 'goss'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:23,878] Trial 37 finished with value: 0.7376554744980278 and parameters: {'lambda_l1': 0.0021258232225542274, 'lambda_l2': 2.983067330567802e-08, 'num_leaves': 13, 'feature_fraction': 0.4464269918460984, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:25,815] Trial 38 finished with value: 0.7540525812424768 and parameters: {'lambda_l1': 2.435532840868241e-06, 'lambda_l2': 0.0001229613424192818, 'num_leaves': 57, 'feature_fraction': 0.6623086752449248, 'min_child_samples': 70, 'boosting_type': 'goss'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:26,434] Trial 39 finished with value: 0.7591096935070792 and parameters: {'lambda_l1': 8.924002433494219e-05, 'lambda_l2': 0.15371147098997884, 'num_leaves': 105, 'feature_fraction': 0.7469082474199767, 'min_child_samples': 41, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:26,846] Trial 40 finished with value: 0.7517632388073483 and parameters: {'lambda_l1': 0.31486956371152053, 'lambda_l2': 3.6405250622207044e-05, 'num_leaves': 74, 'feature_fraction': 0.5763968168187061, 'min_child_samples': 84, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7356907020917274.
# [I 2022-11-12 20:11:27,015] Trial 41 finished with value: 0.7352469750934642 and parameters: {'lambda_l1': 0.005627227678093487, 'lambda_l2': 1.0240186786104877e-05, 'num_leaves': 23, 'feature_fraction': 0.5342677127520855, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:27,219] Trial 42 finished with value: 0.7407297847005522 and parameters: {'lambda_l1': 0.014284439158785685, 'lambda_l2': 5.833307428389599e-06, 'num_leaves': 28, 'feature_fraction': 0.49003436589683197, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:27,433] Trial 43 finished with value: 0.7419789734030506 and parameters: {'lambda_l1': 0.0031945176914940543, 'lambda_l2': 1.6214862373033325e-06, 'num_leaves': 40, 'feature_fraction': 0.6080730778550401, 'min_child_samples': 60, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:27,564] Trial 44 finished with value: 0.7384561304241157 and parameters: {'lambda_l1': 0.07402922920061307, 'lambda_l2': 5.20472897311271e-07, 'num_leaves': 13, 'feature_fraction': 0.5189930258282961, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:27,912] Trial 45 finished with value: 0.751688780826831 and parameters: {'lambda_l1': 0.0006406387164905128, 'lambda_l2': 1.3137280336584243e-05, 'num_leaves': 143, 'feature_fraction': 0.5498402663327674, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:28,343] Trial 46 finished with value: 0.7572048240101628 and parameters: {'lambda_l1': 0.009823030637616548, 'lambda_l2': 0.0014284271503432367, 'num_leaves': 178, 'feature_fraction': 0.46675033418230616, 'min_child_samples': 54, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:28,714] Trial 47 finished with value: 0.7817229850571873 and parameters: {'lambda_l1': 1.8670023974819479, 'lambda_l2': 3.4408257199372593e-06, 'num_leaves': 219, 'feature_fraction': 0.43299441582725295, 'min_child_samples': 19, 'boosting_type': 'goss'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:28,878] Trial 48 finished with value: 0.7375634864827721 and parameters: {'lambda_l1': 0.00023049241333568437, 'lambda_l2': 0.00030324208696592275, 'num_leaves': 24, 'feature_fraction': 0.5935118223378683, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,000] Trial 49 finished with value: 0.7359792165306195 and parameters: {'lambda_l1': 0.05416736904654924, 'lambda_l2': 0.009022159803030219, 'num_leaves': 9, 'feature_fraction': 0.5076588894031121, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,102] Trial 50 finished with value: 0.7355268552396735 and parameters: {'lambda_l1': 0.05644020797529981, 'lambda_l2': 0.09603173193535448, 'num_leaves': 8, 'feature_fraction': 0.5009553745697728, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,194] Trial 51 finished with value: 0.7475546910757263 and parameters: {'lambda_l1': 0.051277822546675865, 'lambda_l2': 0.15529643529567122, 'num_leaves': 2, 'feature_fraction': 0.5032956606469466, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,298] Trial 52 finished with value: 0.736054827966663 and parameters: {'lambda_l1': 0.12523643136697735, 'lambda_l2': 0.011153843136981352, 'num_leaves': 10, 'feature_fraction': 0.4789454633707597, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,434] Trial 53 finished with value: 0.7362504550525116 and parameters: {'lambda_l1': 0.19484666613404403, 'lambda_l2': 0.7167434429196191, 'num_leaves': 11, 'feature_fraction': 0.4042921447116214, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,551] Trial 54 finished with value: 0.735366452233397 and parameters: {'lambda_l1': 0.028667251559744165, 'lambda_l2': 0.00925885462959584, 'num_leaves': 9, 'feature_fraction': 0.5086120338778388, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,668] Trial 55 finished with value: 0.7369086179915235 and parameters: {'lambda_l1': 0.09566789120258981, 'lambda_l2': 0.009972656381872684, 'num_leaves': 13, 'feature_fraction': 0.4821413758042723, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,880] Trial 56 finished with value: 0.7413492991819017 and parameters: {'lambda_l1': 0.03208091606378795, 'lambda_l2': 0.07248352502106091, 'num_leaves': 41, 'feature_fraction': 0.435332146016021, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:29,981] Trial 57 finished with value: 0.7833337628006906 and parameters: {'lambda_l1': 0.31562879863770604, 'lambda_l2': 9.588397709108667, 'num_leaves': 2, 'feature_fraction': 0.5659708607237073, 'min_child_samples': 96, 'boosting_type': 'dart'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:30,160] Trial 58 finished with value: 0.7382412708184627 and parameters: {'lambda_l1': 1.6496587423357982, 'lambda_l2': 0.062395647292568135, 'num_leaves': 29, 'feature_fraction': 0.5109247504639364, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:30,303] Trial 59 finished with value: 0.7403059346474349 and parameters: {'lambda_l1': 0.0044302981366658575, 'lambda_l2': 0.4606779857382581, 'num_leaves': 16, 'feature_fraction': 0.8315554676755995, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:30,537] Trial 60 finished with value: 0.7430688965834219 and parameters: {'lambda_l1': 0.022153967081529113, 'lambda_l2': 0.006237617762061874, 'num_leaves': 48, 'feature_fraction': 0.5322774329095917, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:30,653] Trial 61 finished with value: 0.7361808591038363 and parameters: {'lambda_l1': 0.11964943694942283, 'lambda_l2': 0.047387030489291784, 'num_leaves': 9, 'feature_fraction': 0.46841435126265973, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:30,802] Trial 62 finished with value: 0.7378334265097886 and parameters: {'lambda_l1': 0.0276290204489671, 'lambda_l2': 0.01360818465977819, 'num_leaves': 22, 'feature_fraction': 0.5315715058813001, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:30,917] Trial 63 finished with value: 0.7359354021013874 and parameters: {'lambda_l1': 0.39717172021803315, 'lambda_l2': 0.03425113233380232, 'num_leaves': 9, 'feature_fraction': 0.42616864170945856, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:31,098] Trial 64 finished with value: 0.7380677519679845 and parameters: {'lambda_l1': 2.6303238070819934, 'lambda_l2': 0.03383034392668587, 'num_leaves': 33, 'feature_fraction': 0.4254629096905713, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:31,217] Trial 65 finished with value: 0.7377570013556728 and parameters: {'lambda_l1': 0.42001468052609886, 'lambda_l2': 2.3956228573016185, 'num_leaves': 12, 'feature_fraction': 0.48285046658124237, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.7352469750934642.
# [I 2022-11-12 20:11:31,370] Trial 66 finished with value: 0.734706191622769 and parameters: {'lambda_l1': 0.1919989263178372, 'lambda_l2': 0.27390455202618347, 'num_leaves': 22, 'feature_fraction': 0.44750476610005463, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:31,537] Trial 67 finished with value: 0.7550036614793968 and parameters: {'lambda_l1': 0.7830270756306001, 'lambda_l2': 0.4639681841664643, 'num_leaves': 61, 'feature_fraction': 0.4444954469444508, 'min_child_samples': 95, 'boosting_type': 'goss'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:31,720] Trial 68 finished with value: 0.7400677673708782 and parameters: {'lambda_l1': 0.22660051689272037, 'lambda_l2': 0.26813207720443694, 'num_leaves': 40, 'feature_fraction': 0.40539730585781, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:31,878] Trial 69 finished with value: 0.7351891532319056 and parameters: {'lambda_l1': 0.05089552834538754, 'lambda_l2': 1.2546934213459227, 'num_leaves': 25, 'feature_fraction': 0.45845946082376254, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:32,139] Trial 70 finished with value: 0.7501876917361959 and parameters: {'lambda_l1': 3.336520673647065, 'lambda_l2': 1.4838162442415914, 'num_leaves': 54, 'feature_fraction': 0.9923633480123115, 'min_child_samples': 76, 'boosting_type': 'dart'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:32,286] Trial 71 finished with value: 0.7399227887865735 and parameters: {'lambda_l1': 0.06797749220920286, 'lambda_l2': 0.305497453087492, 'num_leaves': 23, 'feature_fraction': 0.45699717059886413, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:32,460] Trial 72 finished with value: 0.7363241738780788 and parameters: {'lambda_l1': 1.3484770947631147e-08, 'lambda_l2': 0.0878800790382462, 'num_leaves': 18, 'feature_fraction': 0.5057022701657222, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:32,633] Trial 73 finished with value: 0.739103700573596 and parameters: {'lambda_l1': 0.044014959676325384, 'lambda_l2': 1.0418114371703713, 'num_leaves': 29, 'feature_fraction': 0.42113330258706305, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:32,716] Trial 74 finished with value: 0.7425110109063533 and parameters: {'lambda_l1': 0.01924293245868319, 'lambda_l2': 3.6550481399823713, 'num_leaves': 3, 'feature_fraction': 0.45781592394262643, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:32,950] Trial 75 finished with value: 0.7475955461825929 and parameters: {'lambda_l1': 0.006401747127417158, 'lambda_l2': 0.02742312852428385, 'num_leaves': 44, 'feature_fraction': 0.9463581943750095, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:33,140] Trial 76 finished with value: 0.7393529271815859 and parameters: {'lambda_l1': 1.4556819534087202, 'lambda_l2': 0.0021184026022309805, 'num_leaves': 35, 'feature_fraction': 0.5652828927126665, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:33,369] Trial 77 finished with value: 0.7383592078145108 and parameters: {'lambda_l1': 9.495838785006157, 'lambda_l2': 0.10380447770034856, 'num_leaves': 119, 'feature_fraction': 0.4965641145228971, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:33,519] Trial 78 finished with value: 0.7375848594370801 and parameters: {'lambda_l1': 0.4256297224663304, 'lambda_l2': 0.008101547597842982, 'num_leaves': 19, 'feature_fraction': 0.6366266289426519, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:33,682] Trial 79 finished with value: 0.7360840116801161 and parameters: {'lambda_l1': 0.1626768095502116, 'lambda_l2': 0.004589929638501995, 'num_leaves': 25, 'feature_fraction': 0.43901166176556533, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:33,804] Trial 80 finished with value: 0.7498556619046095 and parameters: {'lambda_l1': 0.0470565023653641, 'lambda_l2': 7.435596652868052e-05, 'num_leaves': 9, 'feature_fraction': 0.42200399148808976, 'min_child_samples': 28, 'boosting_type': 'goss'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:33,939] Trial 81 finished with value: 0.7379685846571441 and parameters: {'lambda_l1': 0.1008227124155261, 'lambda_l2': 0.014290048920140094, 'num_leaves': 15, 'feature_fraction': 0.48325221051578143, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:34,055] Trial 82 finished with value: 0.7370502542617383 and parameters: {'lambda_l1': 0.014927481619857307, 'lambda_l2': 0.04183389826250745, 'num_leaves': 8, 'feature_fraction': 0.47270396257516833, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:34,155] Trial 83 finished with value: 0.7371350780877592 and parameters: {'lambda_l1': 0.7073752214543885, 'lambda_l2': 0.22289721744161545, 'num_leaves': 7, 'feature_fraction': 0.5149172659015412, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:34,318] Trial 84 finished with value: 0.7378315883445739 and parameters: {'lambda_l1': 0.0018673886217914276, 'lambda_l2': 0.11603479987937752, 'num_leaves': 28, 'feature_fraction': 0.5396655445026517, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:34,458] Trial 85 finished with value: 0.7359491729179943 and parameters: {'lambda_l1': 0.19664558801292953, 'lambda_l2': 0.0008105458606191279, 'num_leaves': 19, 'feature_fraction': 0.4487447691034543, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:34,653] Trial 86 finished with value: 0.7391159458666825 and parameters: {'lambda_l1': 0.22121286565657033, 'lambda_l2': 0.00043292689994926846, 'num_leaves': 36, 'feature_fraction': 0.44619275627784905, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:34,801] Trial 87 finished with value: 0.7348723992215945 and parameters: {'lambda_l1': 0.06517382181756137, 'lambda_l2': 0.0001251762967697692, 'num_leaves': 17, 'feature_fraction': 0.74496071883507, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:35,204] Trial 88 finished with value: 0.7509484122838068 and parameters: {'lambda_l1': 4.355366010248129e-08, 'lambda_l2': 0.00014268787682566927, 'num_leaves': 227, 'feature_fraction': 0.7298113383989568, 'min_child_samples': 97, 'boosting_type': 'dart'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:35,434] Trial 89 finished with value: 0.7420308007541442 and parameters: {'lambda_l1': 0.009677504253695166, 'lambda_l2': 0.0008557704499961735, 'num_leaves': 46, 'feature_fraction': 0.6923942606566245, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:35,607] Trial 90 finished with value: 0.7401559229505942 and parameters: {'lambda_l1': 1.10004385317387, 'lambda_l2': 2.6654938651509522e-05, 'num_leaves': 22, 'feature_fraction': 0.7595458553111553, 'min_child_samples': 68, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:35,756] Trial 91 finished with value: 0.7373610053500942 and parameters: {'lambda_l1': 0.06131655043727355, 'lambda_l2': 4.621120300660568e-05, 'num_leaves': 17, 'feature_fraction': 0.7816085942508934, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:35,835] Trial 92 finished with value: 0.7471238891445822 and parameters: {'lambda_l1': 0.03597875748109133, 'lambda_l2': 0.01916671169353458, 'num_leaves': 2, 'feature_fraction': 0.6696013621102659, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:36,013] Trial 93 finished with value: 0.7395247763060486 and parameters: {'lambda_l1': 0.3813846179513929, 'lambda_l2': 0.0022262573387647608, 'num_leaves': 25, 'feature_fraction': 0.7332282615528919, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:36,332] Trial 94 finished with value: 0.7541667078823625 and parameters: {'lambda_l1': 0.08183892411501376, 'lambda_l2': 0.0006462583457081889, 'num_leaves': 95, 'feature_fraction': 0.4620462227092844, 'min_child_samples': 14, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:36,477] Trial 95 finished with value: 0.7364775140165032 and parameters: {'lambda_l1': 0.020798079439328918, 'lambda_l2': 7.113182789845913e-05, 'num_leaves': 14, 'feature_fraction': 0.7148988447653154, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:36,586] Trial 96 finished with value: 0.7355095107748603 and parameters: {'lambda_l1': 0.0032760874884886107, 'lambda_l2': 0.00022955300099379518, 'num_leaves': 7, 'feature_fraction': 0.8021082773138202, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:36,793] Trial 97 finished with value: 0.745258176304688 and parameters: {'lambda_l1': 0.0058139981648484, 'lambda_l2': 0.00016834646672131786, 'num_leaves': 38, 'feature_fraction': 0.8337953640489751, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:36,971] Trial 98 finished with value: 0.7511058445437176 and parameters: {'lambda_l1': 0.002557804863367403, 'lambda_l2': 0.000101908316400301, 'num_leaves': 31, 'feature_fraction': 0.8017366599566753, 'min_child_samples': 72, 'boosting_type': 'goss'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:37,091] Trial 99 finished with value: 0.7365820883103417 and parameters: {'lambda_l1': 0.0010391903797528962, 'lambda_l2': 0.00022970331505859254, 'num_leaves': 7, 'feature_fraction': 0.8897327745322642, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:37,247] Trial 100 finished with value: 0.7390838621516806 and parameters: {'lambda_l1': 0.003839505523786214, 'lambda_l2': 8.052495042658488e-06, 'num_leaves': 21, 'feature_fraction': 0.7919414480016248, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:37,345] Trial 101 finished with value: 0.737027513604015 and parameters: {'lambda_l1': 0.027226029226796417, 'lambda_l2': 0.00030408057140974686, 'num_leaves': 8, 'feature_fraction': 0.4956965585920617, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:37,478] Trial 102 finished with value: 0.7394887117890462 and parameters: {'lambda_l1': 0.136375371127863, 'lambda_l2': 0.0012916876632687413, 'num_leaves': 14, 'feature_fraction': 0.8161386646366183, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 66 with value: 0.734706191622769.
# [I 2022-11-12 20:11:37,608] Trial 103 finished with value: 0.733872823380692 and parameters: {'lambda_l1': 0.012573873429018093, 'lambda_l2': 0.005571728927243623, 'num_leaves': 17, 'feature_fraction': 0.410689366363474, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:37,745] Trial 104 finished with value: 0.7356150822385247 and parameters: {'lambda_l1': 0.01324486125399562, 'lambda_l2': 0.005166036959400366, 'num_leaves': 19, 'feature_fraction': 0.40261558828604027, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:37,896] Trial 105 finished with value: 0.7369387997137955 and parameters: {'lambda_l1': 0.008285784373200107, 'lambda_l2': 0.0028689219049125394, 'num_leaves': 26, 'feature_fraction': 0.4153676879091103, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:38,071] Trial 106 finished with value: 0.7397933012221238 and parameters: {'lambda_l1': 0.010597662677665194, 'lambda_l2': 0.0049880255058469105, 'num_leaves': 31, 'feature_fraction': 0.4260315688170414, 'min_child_samples': 68, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:38,169] Trial 107 finished with value: 0.7834635405522368 and parameters: {'lambda_l1': 0.01657437164429013, 'lambda_l2': 0.4800094297977303, 'num_leaves': 2, 'feature_fraction': 0.4007815262592801, 'min_child_samples': 77, 'boosting_type': 'dart'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:38,295] Trial 108 finished with value: 0.7359533924642991 and parameters: {'lambda_l1': 0.0006497264684571056, 'lambda_l2': 0.02450742843341621, 'num_leaves': 14, 'feature_fraction': 0.4122705074442837, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:38,394] Trial 109 finished with value: 0.7363227156731061 and parameters: {'lambda_l1': 0.003799003297970482, 'lambda_l2': 0.7336722189240489, 'num_leaves': 6, 'feature_fraction': 0.7650788131074813, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:38,530] Trial 110 finished with value: 0.7355690142813689 and parameters: {'lambda_l1': 3.309237262783228e-06, 'lambda_l2': 2.0697513381193068e-05, 'num_leaves': 17, 'feature_fraction': 0.42683673358878915, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:38,889] Trial 111 finished with value: 0.753473527008706 and parameters: {'lambda_l1': 1.1419426028129843e-06, 'lambda_l2': 3.940037892601256e-06, 'num_leaves': 178, 'feature_fraction': 0.4554954999657792, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,033] Trial 112 finished with value: 0.7359754430097857 and parameters: {'lambda_l1': 0.03414068197398663, 'lambda_l2': 1.7558527195734788e-05, 'num_leaves': 19, 'feature_fraction': 0.43318662228089216, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,193] Trial 113 finished with value: 0.7371740455328833 and parameters: {'lambda_l1': 0.0014667925350686495, 'lambda_l2': 4.298536852902285e-05, 'num_leaves': 25, 'feature_fraction': 0.43850131297200995, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,309] Trial 114 finished with value: 0.7381663541110169 and parameters: {'lambda_l1': 1.2439871298394133e-06, 'lambda_l2': 0.05762602478151567, 'num_leaves': 12, 'feature_fraction': 0.40005498156135977, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,505] Trial 115 finished with value: 0.7394949554687851 and parameters: {'lambda_l1': 0.0054125507008258005, 'lambda_l2': 2.6430725565717763e-05, 'num_leaves': 37, 'feature_fraction': 0.47212254694891875, 'min_child_samples': 62, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,638] Trial 116 finished with value: 0.7356857388061359 and parameters: {'lambda_l1': 1.4942457884622465e-07, 'lambda_l2': 1.904009935741314, 'num_leaves': 18, 'feature_fraction': 0.41255852277517246, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,807] Trial 117 finished with value: 0.7377225932653224 and parameters: {'lambda_l1': 1.0662860057370954e-05, 'lambda_l2': 1.9037596723387527, 'num_leaves': 32, 'feature_fraction': 0.4133439118507819, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:39,939] Trial 118 finished with value: 0.7367252773940213 and parameters: {'lambda_l1': 7.520848347736158e-08, 'lambda_l2': 0.9736423165299869, 'num_leaves': 16, 'feature_fraction': 0.43364004462522765, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:40,176] Trial 119 finished with value: 0.7558008887996781 and parameters: {'lambda_l1': 0.014344895492328867, 'lambda_l2': 9.58036932590545, 'num_leaves': 41, 'feature_fraction': 0.4531718026980876, 'min_child_samples': 51, 'boosting_type': 'goss'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:40,493] Trial 120 finished with value: 0.7519073182760251 and parameters: {'lambda_l1': 5.796959766962987e-06, 'lambda_l2': 4.516390473870619, 'num_leaves': 73, 'feature_fraction': 0.8543081505370824, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:40,641] Trial 121 finished with value: 0.7351329650228559 and parameters: {'lambda_l1': 0.08172862185818473, 'lambda_l2': 1.1468185942625862e-05, 'num_leaves': 21, 'feature_fraction': 0.4206155270211418, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:40,789] Trial 122 finished with value: 0.7366549890902124 and parameters: {'lambda_l1': 2.675369615816172e-07, 'lambda_l2': 2.1118354712936433e-06, 'num_leaves': 21, 'feature_fraction': 0.4203539954576571, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:40,961] Trial 123 finished with value: 0.739826664347109 and parameters: {'lambda_l1': 8.364066412519035e-07, 'lambda_l2': 5.578089653720729e-05, 'num_leaves': 29, 'feature_fraction': 0.4108121355878055, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:41,105] Trial 124 finished with value: 0.7356672698945745 and parameters: {'lambda_l1': 0.00015607770373835266, 'lambda_l2': 6.888598015232263e-06, 'num_leaves': 19, 'feature_fraction': 0.4408923977341597, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:41,430] Trial 125 finished with value: 0.7495463860689435 and parameters: {'lambda_l1': 0.00010136083539564312, 'lambda_l2': 1.1325518171187474e-05, 'num_leaves': 131, 'feature_fraction': 0.44383584976483786, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:41,589] Trial 126 finished with value: 0.7365368259199021 and parameters: {'lambda_l1': 0.09800926036166867, 'lambda_l2': 5.075134359008689e-06, 'num_leaves': 25, 'feature_fraction': 0.4668931781981497, 'min_child_samples': 63, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:41,723] Trial 127 finished with value: 0.7360881685313702 and parameters: {'lambda_l1': 1.3076995057115572e-07, 'lambda_l2': 7.950322967780058e-06, 'num_leaves': 16, 'feature_fraction': 0.43018935307689843, 'min_child_samples': 45, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:41,907] Trial 128 finished with value: 0.7368162602921974 and parameters: {'lambda_l1': 0.052042608714779795, 'lambda_l2': 1.572781477055194e-06, 'num_leaves': 33, 'feature_fraction': 0.49070379545763954, 'min_child_samples': 58, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,061] Trial 129 finished with value: 0.7386694348278547 and parameters: {'lambda_l1': 4.896719758511694e-06, 'lambda_l2': 6.313544791493047e-07, 'num_leaves': 22, 'feature_fraction': 0.40109673409471247, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,221] Trial 130 finished with value: 0.7520228944630555 and parameters: {'lambda_l1': 2.390892506023629e-05, 'lambda_l2': 2.4361711616499333, 'num_leaves': 10, 'feature_fraction': 0.41723648063377955, 'min_child_samples': 68, 'boosting_type': 'dart'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,315] Trial 131 finished with value: 0.736511555120767 and parameters: {'lambda_l1': 0.028469652467888046, 'lambda_l2': 2.4877260125010405e-05, 'num_leaves': 6, 'feature_fraction': 0.5271100529520145, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,458] Trial 132 finished with value: 0.7360244011024435 and parameters: {'lambda_l1': 5.445134632480601e-07, 'lambda_l2': 9.275274800253924e-05, 'num_leaves': 19, 'feature_fraction': 0.4410615806966578, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,583] Trial 133 finished with value: 0.7366678879632769 and parameters: {'lambda_l1': 0.019686166843539216, 'lambda_l2': 1.1473346797571055e-05, 'num_leaves': 12, 'feature_fraction': 0.4779174664534221, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,662] Trial 134 finished with value: 0.7414331490555024 and parameters: {'lambda_l1': 0.007223151871332249, 'lambda_l2': 1.9308788605251808e-05, 'num_leaves': 3, 'feature_fraction': 0.5578835509659545, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,829] Trial 135 finished with value: 0.7361215664714333 and parameters: {'lambda_l1': 0.07139657244825183, 'lambda_l2': 4.980094257591945, 'num_leaves': 27, 'feature_fraction': 0.5821159572816789, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:42,962] Trial 136 finished with value: 0.7362971223272251 and parameters: {'lambda_l1': 2.4633104422519334e-08, 'lambda_l2': 3.3243352156012515e-05, 'num_leaves': 16, 'feature_fraction': 0.45920981446985115, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:43,083] Trial 137 finished with value: 0.7367150338849464 and parameters: {'lambda_l1': 3.0050676755029076e-06, 'lambda_l2': 2.4103975653265755e-06, 'num_leaves': 11, 'feature_fraction': 0.42775363639687425, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:43,232] Trial 138 finished with value: 0.7355761461402979 and parameters: {'lambda_l1': 0.043417445225208684, 'lambda_l2': 0.21662757421684165, 'num_leaves': 22, 'feature_fraction': 0.5020478363022118, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:43,429] Trial 139 finished with value: 0.741155781238419 and parameters: {'lambda_l1': 0.04056807817378917, 'lambda_l2': 0.11926147583214455, 'num_leaves': 42, 'feature_fraction': 0.5164149197819409, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:43,644] Trial 140 finished with value: 0.7450105948008428 and parameters: {'lambda_l1': 0.011754824593338459, 'lambda_l2': 0.17494687406136758, 'num_leaves': 50, 'feature_fraction': 0.4505253054206481, 'min_child_samples': 35, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:43,807] Trial 141 finished with value: 0.736949599579882 and parameters: {'lambda_l1': 0.023421394755405545, 'lambda_l2': 0.2901591621918622, 'num_leaves': 23, 'feature_fraction': 0.4878920541322486, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:43,948] Trial 142 finished with value: 0.7365304125807676 and parameters: {'lambda_l1': 0.05058852190075564, 'lambda_l2': 0.5054510296293768, 'num_leaves': 17, 'feature_fraction': 0.5024952756960326, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:44,043] Trial 143 finished with value: 0.7362703060059164 and parameters: {'lambda_l1': 0.10247681964546364, 'lambda_l2': 0.0004708541505973097, 'num_leaves': 6, 'feature_fraction': 0.5402161356382201, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:44,224] Trial 144 finished with value: 0.7423024028644521 and parameters: {'lambda_l1': 0.27210144381276447, 'lambda_l2': 6.802953620165371e-06, 'num_leaves': 28, 'feature_fraction': 0.653786276809109, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:44,415] Trial 145 finished with value: 0.7425141844912687 and parameters: {'lambda_l1': 0.16138342386553142, 'lambda_l2': 0.00015972461273859988, 'num_leaves': 34, 'feature_fraction': 0.747088415075119, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:44,565] Trial 146 finished with value: 0.7369329365688925 and parameters: {'lambda_l1': 0.002356908230698894, 'lambda_l2': 0.6593105108880956, 'num_leaves': 20, 'feature_fraction': 0.622052919158078, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:11:44,692] Trial 147 finished with value: 0.7525381444577895 and parameters: {'lambda_l1': 0.034924088047955326, 'lambda_l2': 3.467581217796158e-06, 'num_leaves': 11, 'feature_fraction': 0.4146765758316359, 'min_child_samples': 95, 'boosting_type': 'goss'}. Best is trial 103 with value: 0.733872823380692.
# ...
# [I 2022-11-12 20:12:15,121] Trial 352 finished with value: 0.736710755293217 and parameters: {'lambda_l1': 0.00011514335687899693, 'lambda_l2': 3.465883055387748e-07, 'num_leaves': 13, 'feature_fraction': 0.4005184819053757, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:15,251] Trial 353 finished with value: 0.7363944950050806 and parameters: {'lambda_l1': 0.00020053017526335565, 'lambda_l2': 0.012927334741821332, 'num_leaves': 8, 'feature_fraction': 0.7828645000336444, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:15,411] Trial 354 finished with value: 0.7370298342779978 and parameters: {'lambda_l1': 0.09504044584049529, 'lambda_l2': 0.007548008884575197, 'num_leaves': 18, 'feature_fraction': 0.5805712948437869, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:15,600] Trial 355 finished with value: 0.7370700960898121 and parameters: {'lambda_l1': 0.0022783022086988185, 'lambda_l2': 0.0007820170683012004, 'num_leaves': 27, 'feature_fraction': 0.768079205066232, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:15,736] Trial 356 finished with value: 0.7361016820151027 and parameters: {'lambda_l1': 0.0477358143097574, 'lambda_l2': 0.0003707207208361424, 'num_leaves': 11, 'feature_fraction': 0.8536422601675928, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:15,813] Trial 357 finished with value: 0.7471678402134679 and parameters: {'lambda_l1': 8.060881233747766e-05, 'lambda_l2': 0.024666503401148444, 'num_leaves': 2, 'feature_fraction': 0.6740077151696858, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:15,957] Trial 358 finished with value: 0.7378223479772213 and parameters: {'lambda_l1': 0.004990769883295479, 'lambda_l2': 0.001580008652435685, 'num_leaves': 21, 'feature_fraction': 0.5312392805967476, 'min_child_samples': 45, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,068] Trial 359 finished with value: 0.7355351208581627 and parameters: {'lambda_l1': 2.7605852593152333e-05, 'lambda_l2': 0.04340154554686853, 'num_leaves': 7, 'feature_fraction': 0.8102913702634001, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,196] Trial 360 finished with value: 0.7357859382832954 and parameters: {'lambda_l1': 0.0002926554511516858, 'lambda_l2': 1.0469534915111887, 'num_leaves': 14, 'feature_fraction': 0.4134569794519731, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,390] Trial 361 finished with value: 0.7408050625702375 and parameters: {'lambda_l1': 0.00014865806898603008, 'lambda_l2': 0.004331530502396635, 'num_leaves': 33, 'feature_fraction': 0.6926896253658413, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,510] Trial 362 finished with value: 0.7358305094382706 and parameters: {'lambda_l1': 0.0007471536764682675, 'lambda_l2': 0.01589941031218777, 'num_leaves': 9, 'feature_fraction': 0.4379146906233671, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,656] Trial 363 finished with value: 0.7366151133736069 and parameters: {'lambda_l1': 0.020984907748815305, 'lambda_l2': 0.0006144505898410966, 'num_leaves': 16, 'feature_fraction': 0.6637296965485293, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,815] Trial 364 finished with value: 0.7368084884438855 and parameters: {'lambda_l1': 4.6427906384736045e-05, 'lambda_l2': 0.105213718224464, 'num_leaves': 23, 'feature_fraction': 0.556581764547103, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:16,927] Trial 365 finished with value: 0.7441109996227908 and parameters: {'lambda_l1': 0.0004140948996213712, 'lambda_l2': 0.00025494576425199146, 'num_leaves': 7, 'feature_fraction': 0.7315336757436377, 'min_child_samples': 79, 'boosting_type': 'goss'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:17,285] Trial 366 finished with value: 0.7506923491235082 and parameters: {'lambda_l1': 0.037230755847873095, 'lambda_l2': 0.06021284549660661, 'num_leaves': 150, 'feature_fraction': 0.6114387398003541, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:17,588] Trial 367 finished with value: 0.7463078187815049 and parameters: {'lambda_l1': 0.05570735637667625, 'lambda_l2': 0.009545067409417731, 'num_leaves': 232, 'feature_fraction': 0.42712528500100627, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:17,715] Trial 368 finished with value: 0.7372420007838304 and parameters: {'lambda_l1': 0.013870676585985066, 'lambda_l2': 0.0001328940198905324, 'num_leaves': 12, 'feature_fraction': 0.705823043642769, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:17,797] Trial 369 finished with value: 0.7473563544372902 and parameters: {'lambda_l1': 0.00011478385052178504, 'lambda_l2': 0.003140354382863646, 'num_leaves': 2, 'feature_fraction': 0.40825352823798583, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:17,947] Trial 370 finished with value: 0.7371212262165254 and parameters: {'lambda_l1': 0.09740554680403171, 'lambda_l2': 1.8724571063946867, 'num_leaves': 19, 'feature_fraction': 0.6406330576599034, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:18,086] Trial 371 finished with value: 0.735844867434273 and parameters: {'lambda_l1': 0.00025425678074157633, 'lambda_l2': 0.1362191352338365, 'num_leaves': 14, 'feature_fraction': 0.6766318165596892, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:18,255] Trial 372 finished with value: 0.7380151556741963 and parameters: {'lambda_l1': 0.00392344775213853, 'lambda_l2': 0.413515331580055, 'num_leaves': 26, 'feature_fraction': 0.4464377594643205, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:18,356] Trial 373 finished with value: 0.7373799786640213 and parameters: {'lambda_l1': 0.007451747799578652, 'lambda_l2': 0.0023014703419037643, 'num_leaves': 6, 'feature_fraction': 0.5180719870250678, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:18,656] Trial 374 finished with value: 0.7466237065135395 and parameters: {'lambda_l1': 0.0012493013540919454, 'lambda_l2': 0.00613029422767325, 'num_leaves': 90, 'feature_fraction': 0.42178786872133034, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:18,808] Trial 375 finished with value: 0.7379156861013859 and parameters: {'lambda_l1': 0.00020927491936517952, 'lambda_l2': 0.028559208160308353, 'num_leaves': 19, 'feature_fraction': 0.7575790750098463, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:18,935] Trial 376 finished with value: 0.7354810164597355 and parameters: {'lambda_l1': 9.503459347542646e-05, 'lambda_l2': 0.00018781731482254234, 'num_leaves': 12, 'feature_fraction': 0.6870335533187604, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:19,071] Trial 377 finished with value: 0.7354810146241638 and parameters: {'lambda_l1': 8.269370662046002e-05, 'lambda_l2': 0.00032555593050701464, 'num_leaves': 12, 'feature_fraction': 0.6877370142124601, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:19,506] Trial 378 finished with value: 0.7501439597318482 and parameters: {'lambda_l1': 5.729950141783998e-05, 'lambda_l2': 0.0001513550775381564, 'num_leaves': 205, 'feature_fraction': 0.6887592503096185, 'min_child_samples': 82, 'boosting_type': 'dart'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:19,693] Trial 379 finished with value: 0.7418796019152011 and parameters: {'lambda_l1': 8.034631567591127e-05, 'lambda_l2': 0.0007460742323823729, 'num_leaves': 30, 'feature_fraction': 0.6941670244738009, 'min_child_samples': 51, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:19,859] Trial 380 finished with value: 0.7382966048580365 and parameters: {'lambda_l1': 0.00010316383726631208, 'lambda_l2': 0.0003973770546310178, 'num_leaves': 23, 'feature_fraction': 0.7052858561980536, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,003] Trial 381 finished with value: 0.7356195394992446 and parameters: {'lambda_l1': 4.466593629998591e-05, 'lambda_l2': 0.0010846970444682448, 'num_leaves': 15, 'feature_fraction': 0.6786699299264182, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,128] Trial 382 finished with value: 0.735724431414157 and parameters: {'lambda_l1': 0.0001489993699315633, 'lambda_l2': 0.00018644910083268684, 'num_leaves': 12, 'feature_fraction': 0.6647117338997472, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,285] Trial 383 finished with value: 0.7375228516825487 and parameters: {'lambda_l1': 6.976198373015335e-05, 'lambda_l2': 0.00029421352592020987, 'num_leaves': 19, 'feature_fraction': 0.689291734172577, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,491] Trial 384 finished with value: 0.7423691534600643 and parameters: {'lambda_l1': 9.72515550294117e-05, 'lambda_l2': 6.750600467632197e-05, 'num_leaves': 36, 'feature_fraction': 0.7020756915247566, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,660] Trial 385 finished with value: 0.7395566100688685 and parameters: {'lambda_l1': 0.00015950079472597714, 'lambda_l2': 0.0005397412773332743, 'num_leaves': 26, 'feature_fraction': 0.6507970517222139, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,810] Trial 386 finished with value: 0.7358608550001 and parameters: {'lambda_l1': 3.355875487340028e-05, 'lambda_l2': 0.00021356374612914298, 'num_leaves': 16, 'feature_fraction': 0.7164497640877004, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:20,926] Trial 387 finished with value: 0.7360438684273842 and parameters: {'lambda_l1': 6.960881431041654e-05, 'lambda_l2': 0.00011053066962160438, 'num_leaves': 10, 'feature_fraction': 0.68116021728452, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:21,124] Trial 388 finished with value: 0.752415210282542 and parameters: {'lambda_l1': 1.909820651945938e-05, 'lambda_l2': 9.351675510346254e-06, 'num_leaves': 21, 'feature_fraction': 0.6709738425593965, 'min_child_samples': 84, 'boosting_type': 'goss'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:21,297] Trial 389 finished with value: 0.7365556450689287 and parameters: {'lambda_l1': 0.0001367440483267311, 'lambda_l2': 4.680894038926869e-06, 'num_leaves': 11, 'feature_fraction': 0.7252164485341781, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:21,457] Trial 390 finished with value: 0.7376090284082877 and parameters: {'lambda_l1': 0.00023432100054361998, 'lambda_l2': 0.0003960386799432018, 'num_leaves': 16, 'feature_fraction': 0.6962137590066129, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:21,559] Trial 391 finished with value: 0.7355483651221175 and parameters: {'lambda_l1': 4.148865979371732e-05, 'lambda_l2': 5.057955397541331, 'num_leaves': 6, 'feature_fraction': 0.684406382413102, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:21,710] Trial 392 finished with value: 0.7384173913713443 and parameters: {'lambda_l1': 0.0005203543429443358, 'lambda_l2': 0.009293881276998294, 'num_leaves': 22, 'feature_fraction': 0.4154625242768356, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:21,830] Trial 393 finished with value: 0.7376421496191081 and parameters: {'lambda_l1': 0.00010826802583700007, 'lambda_l2': 1.6739989502588174e-05, 'num_leaves': 11, 'feature_fraction': 0.6599587939340299, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:22,008] Trial 394 finished with value: 0.7383003004596957 and parameters: {'lambda_l1': 0.00019340773712610783, 'lambda_l2': 0.014169609888552072, 'num_leaves': 28, 'feature_fraction': 0.42993870106670473, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:22,138] Trial 395 finished with value: 0.7356035325516344 and parameters: {'lambda_l1': 0.00037506095582690924, 'lambda_l2': 0.006207829732839603, 'num_leaves': 16, 'feature_fraction': 0.40013220334159944, 'min_child_samples': 65, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:22,224] Trial 396 finished with value: 0.7473598496349767 and parameters: {'lambda_l1': 6.868386771483075e-05, 'lambda_l2': 8.401852114391813e-05, 'num_leaves': 2, 'feature_fraction': 0.7147689337136264, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:22,377] Trial 397 finished with value: 0.7527278273831226 and parameters: {'lambda_l1': 0.00010218024359419446, 'lambda_l2': 0.7625635905078844, 'num_leaves': 8, 'feature_fraction': 0.4530508925248465, 'min_child_samples': 84, 'boosting_type': 'dart'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:22,533] Trial 398 finished with value: 0.7371687674122682 and parameters: {'lambda_l1': 0.0002980852065167854, 'lambda_l2': 0.0002926744801452002, 'num_leaves': 19, 'feature_fraction': 0.6738265293364195, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# [I 2022-11-12 20:12:22,661] Trial 399 finished with value: 0.7368483723888759 and parameters: {'lambda_l1': 0.34869229812046554, 'lambda_l2': 0.00017725272575106022, 'num_leaves': 13, 'feature_fraction': 0.43728578087255016, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.733872823380692.
# Number of finished trials: 400
# Best trial (103):
# Value: 0.733872823380692
# Params:
# {'lambda_l1': 0.012573873429018093, 'lambda_l2': 0.005571728927243623, 'num_leaves': 17, 'feature_fraction': 0.410689366363474, 'min_child_samples': 75, 'boosting_type': 'gbdt'}

# %%
# Catboost validation prediction
y_pred_val_cb = np.expm1(cbm.predict(X_val_cb))
print('Catboost validation score:', rmsle(np.expm1(y_val), y_pred_val_cb))

# LightGBM validation prediction
y_val_pred_lgb = np.expm1(lgbm.predict(X_val_lgb))
print('LightGBM validation score:', rmsle(np.expm1(y_val), y_val_pred_lgb))
# Out:
# Catboost validation score: 0.7243537494624922
# LightGBM validation score: 0.733872823380692

# %%
y_pred_test_cb = np.expm1(cbm.predict(X_test_cb))
y_pred_test_lgb = np.expm1(lgbm.predict(X_test_lgb))

test_stack = np.array([y_pred_test_cb, y_pred_test_lgb])
stack_test_avg = np.mean(test_stack, axis=0)

submission = pd.read_csv('data/sample_submission.csv')
submission['predicted'] = stack_test_avg
submission.to_csv('submissions/cb_lgb_automl_stacked2.csv', index=False)
