# %% [markdown]
# # TDT4173 - Group 53: Short notebook for 'cb_lgb_stacked.csv' submission
#
# `Group members`:
# - Kaspar Paus Græsdal, 493880
# - Oskar Holm, 527085
# - Vegard Følstad Kolaas, 767941
#
# `Disclaimer`:
# We experience some difference in between each run in terms of the final score, even though it appeares that we have provided seeds to all the functions that require it in order to reproduce the result. The score should be about 0.686, but expect values in the range [0.685, 0.687]. We are not certain about what the reason behind this is, but we did notice that LightGBM suddenly (and weirdly) took a lot longer to train, just hours before the deadline (not to say that this is the sole reason).

# %% [markdown]
# # 1. Initial setup

# %%
# %load_ext autoreload

# %% [markdown]
# ## 1.1 Install required packages
#
# We ran into some issues with some of the geo related packages, such as geopandas, on certain machines. If the code does not run on your machine, you can comment out the lines commented with "# GEO PROBLEM HERE", and it will hopefully allow the code to run. This may of course impact the final score.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: alembic==1.8.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: asttokens==2.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: attrs==22.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: autopage==0.5.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: autopep8==2.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: backcall==0.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: catboost==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: certifi==2022.9.24 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2022.9.24)
# Requirement already satisfied: charset-normalizer==2.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: click==8.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (8.1.3)
# Requirement already satisfied: click-plugins==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: cliff==4.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: cligj==0.7.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.7.2)
# Requirement already satisfied: cmaes==0.8.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (0.8.2)
# Requirement already satisfied: cmd2==2.4.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (2.4.2)
# Requirement already satisfied: colorama==0.4.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: colorlog==6.7.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (6.7.0)
# Requirement already satisfied: contourpy==1.0.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (0.11.0)
# Requirement already satisfied: Cython==0.29.28 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (0.29.28)
# Requirement already satisfied: debugpy==1.6.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (1.6.3)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (0.4)
# Requirement already satisfied: executing==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (1.2.0)
# Requirement already satisfied: Fiona==1.8.22 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (1.8.22)
# Requirement already satisfied: fonttools==4.38.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (4.38.0)
# Requirement already satisfied: future==0.18.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (0.18.2)
# Requirement already satisfied: gensim==4.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (4.2.0)
# Requirement already satisfied: geographiclib==1.52 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (1.52)
# Requirement already satisfied: geopandas==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (0.12.1)
# Requirement already satisfied: geopy==2.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (2.2.0)
# Requirement already satisfied: graphviz==0.20.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (0.20.1)
# Requirement already satisfied: greenlet==2.0.0.post0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (2.0.0.post0)
# Requirement already satisfied: h2o==3.38.0.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (3.38.0.2)
# Requirement already satisfied: idna==3.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (3.4)
# Requirement already satisfied: importlib-metadata==4.13.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (4.13.0)
# Requirement already satisfied: importlib-resources==5.10.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (5.10.0)
# Requirement already satisfied: ipykernel==6.17.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (6.17.0)
# Requirement already satisfied: ipython==8.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (8.6.0)
# Requirement already satisfied: ipywidgets==8.0.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (8.0.2)
# Requirement already satisfied: jedi==0.18.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (0.18.1)
# Requirement already satisfied: joblib==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (1.2.0)
# Requirement already satisfied: jupyter-client==7.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (7.4.4)
# Requirement already satisfied: jupyter-core==4.11.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (4.11.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (3.0.3)
# Requirement already satisfied: kiwisolver==1.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (1.4.4)
# Requirement already satisfied: lightgbm==3.3.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (3.3.3)
# Requirement already satisfied: Mako==1.2.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (1.2.3)
# Requirement already satisfied: MarkupSafe==2.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (2.1.1)
# Requirement already satisfied: matplotlib==3.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (3.6.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (0.1.6)
# Requirement already satisfied: munch==2.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2.5.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (1.5.6)
# Requirement already satisfied: numpy==1.23.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (1.23.4)
# Requirement already satisfied: optuna==3.0.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (3.0.3)
# Requirement already satisfied: packaging==21.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (21.3)
# Requirement already satisfied: pandas==1.5.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (1.5.1)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (0.8.3)
# Requirement already satisfied: pbr==5.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (5.11.0)
# Requirement already satisfied: pexpect==4.8.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (0.7.5)
# Requirement already satisfied: Pillow==9.3.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (9.3.0)
# Requirement already satisfied: plotly==5.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (5.11.0)
# Requirement already satisfied: prettytable==3.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (3.5.0)
# Requirement already satisfied: prompt-toolkit==3.0.31 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (3.0.31)
# Requirement already satisfied: psutil==5.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (5.9.3)
# Requirement already satisfied: ptyprocess==0.7.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (0.2.2)
# Requirement already satisfied: pyarrow==10.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 69)) (10.0.0)
# Requirement already satisfied: pycodestyle==2.9.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (2.9.1)
# Requirement already satisfied: pygeos==0.13 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 71)) (0.13)
# Requirement already satisfied: Pygments==2.13.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 72)) (2.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 73)) (3.0.9)
# Requirement already satisfied: pyperclip==1.8.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 74)) (1.8.2)
# Requirement already satisfied: pyproj==3.4.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 75)) (3.4.0)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 76)) (2.8.2)
# Requirement already satisfied: pytz==2022.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 77)) (2022.6)
# Requirement already satisfied: PyYAML==6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 78)) (6.0)
# Requirement already satisfied: pyzmq==24.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 79)) (24.0.1)
# Requirement already satisfied: requests==2.28.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 80)) (2.28.1)
# Requirement already satisfied: scikit-learn==1.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 81)) (1.1.3)
# Requirement already satisfied: scipy==1.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 82)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 83)) (0.12.1)
# Requirement already satisfied: Shapely==1.8.5.post1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 84)) (1.8.5.post1)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 85)) (1.16.0)
# Requirement already satisfied: sklearn==0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 86)) (0.0)
# Requirement already satisfied: smart-open==6.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 87)) (6.2.0)
# Requirement already satisfied: SQLAlchemy==1.4.43 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 88)) (1.4.43)
# Requirement already satisfied: stack-data==0.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 89)) (0.6.0)
# Requirement already satisfied: stevedore==4.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 90)) (4.1.0)
# Requirement already satisfied: tabulate==0.9.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 91)) (0.9.0)
# Requirement already satisfied: tenacity==8.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 92)) (8.1.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 93)) (3.1.0)
# Requirement already satisfied: tomli==2.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 94)) (2.0.1)
# Requirement already satisfied: tornado==6.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 95)) (6.2)
# Requirement already satisfied: tqdm==4.64.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 96)) (4.64.1)
# Requirement already satisfied: traitlets==5.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 97)) (5.5.0)
# Requirement already satisfied: urllib3==1.26.12 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 98)) (1.26.12)
# Requirement already satisfied: wcwidth==0.2.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 99)) (0.2.5)
# Requirement already satisfied: widgetsnbextension==4.0.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 100)) (4.0.3)
# Requirement already satisfied: xgboost==1.7.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 101)) (1.7.0)
# Requirement already satisfied: zipp==3.10.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 102)) (3.10.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from Fiona==1.8.22->-r requirements.txt (line 25)) (44.0.0)
# Requirement already satisfied: wheel in ./venv/lib/python3.8/site-packages (from lightgbm==3.3.3->-r requirements.txt (line 47)) (0.38.4)

# %% [markdown]
# ## 1.2 Import packages and data

# %%
# %autoreload

import warnings
import os.path
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import geopy
import os
import shutil
import geopandas as gpd
import catboost as cb
import optuna
import lightgbm as lgb
import geopandas as gpd

from pyproj import Geod
from shapely import wkt
from shapely.geometry import Point, LineString
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_log_error
from typing import Callable, Dict, List, Tuple
from catboost.utils import get_gpu_device_count
from tqdm import tqdm

tqdm.pandas()

warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None  # default='warn'

SEED = 23

spatial = pd.read_csv('data/grunnkrets_norway_stripped.csv')
age = pd.read_csv('data/grunnkrets_age_distribution.csv')
income = pd.read_csv('data/grunnkrets_income_households.csv').set_index(['grunnkrets_id', 'year']).add_prefix('income_').reset_index()
households = pd.read_csv('data/grunnkrets_households_num_persons.csv')
submission = pd.read_csv('data/sample_submission.csv')
plaace = pd.read_csv('data/plaace_hierarchy.csv')
busstops = pd.read_csv('data/busstops_norway.csv')

train = pd.read_csv('data/stores_train.csv')
train_extra = pd.read_csv('data/stores_extra.csv')
test = pd.read_csv('data/stores_test.csv') 

submission = pd.read_csv('data/sample_submission.csv')  # Please do not delete this file

# %% [markdown]
# Create geopandas version of some of the datasets:

# %%
busstops_geo = gpd.GeoDataFrame(busstops, geometry=busstops.geometry.apply(wkt.loads))

train_geo = gpd.GeoDataFrame(train[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train.lon, train.lat)).drop(columns=['lon', 'lat'])
train_geo = train_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

train_geo_extra = gpd.GeoDataFrame(train_extra[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train_extra.lon, train_extra.lat)).drop(columns=['lon', 'lat'])
train_geo_extra = train_geo_extra.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

test_geo = gpd.GeoDataFrame(test[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(test.lon, test.lat)).drop(columns=['lon', 'lat'])
test_geo = test_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

# %% [markdown]
# ## 1.3 Helper functions

# %%
def rmsle(y_true, y_pred):
    y_pred[y_pred < 0] = 0 + 1e-6
    y_true[y_true < 0] = 0 + 1e-6
    return np.sqrt(mean_squared_log_error(y_true, y_pred))


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def to_categorical(df: pd.DataFrame):
    for cat_col in df.select_dtypes(include=[object]).columns:
        df[cat_col] = df[cat_col].astype('category')
    return df


def object_encoder(df: pd.DataFrame):
    enc = OrdinalEncoder()
    obj_cols = df.select_dtypes(include=[object]).columns
    df[obj_cols] = enc.fit_transform(df[obj_cols])
    return df


def nan_to_string(df: pd.DataFrame):
    nan = '#N/A'
    cols = df[df.columns[df.isna().any()]].columns
    df[cols] = df[cols].fillna(nan)
    return df


def meter_distance(lat1, lon1, lat2, lon2):
    line_string = LineString([Point(lon1, lat1), Point(lon2, lat2)])
    geod = Geod(ellps="WGS84")
    return geod.geometry_length(line_string)


def add_city_centre_dist(X: pd.DataFrame):
    old_shape = X.shape

    city_centres = X.groupby(['municipality_name'])[['lat', 'lon']].apply(lambda x: x.sum() / (x.count()))[['lat', 'lon']]
    X = X.merge(city_centres, on=['municipality_name'], how='left', suffixes=(None, '_center'))
    assert X.shape[0] == old_shape[0]

    X.fillna(value={'lat_center': X.lat, 'lon_center': X.lon}, inplace=True)

    X['dist_to_center'] = X.apply(lambda row: meter_distance(row.lat, row.lon, row.lat_center, row.lon_center), axis=1)
    assert X.shape[0] == old_shape[0]

    return X


def group_ages(age: pd.DataFrame, age_ranges: List[Tuple[int, int]]):
    age_new = age[['grunnkrets_id', 'year']].drop_duplicates(subset=['grunnkrets_id'], keep='last')

    for rng in age_ranges:
        cols = [f'age_{age}' for age in range(rng[0], rng[1] + 1)]
        rng_sum = age[cols].sum(axis=1).astype(int)
        age_new[f'age_{rng[0]}_{rng[-1]}'] = rng_sum

    age = age.drop_duplicates(subset='grunnkrets_id').drop(columns=['year', *(f'age_{age}' for age in range(0, 91))], axis=1)
    age = age.merge(age_new.drop(columns=['year']), on='grunnkrets_id')

    return age


def only_latest_data(df: pd.DataFrame):
    df = df.sort_values(by='year', ascending=False)
    df = df.drop_duplicates(subset='grunnkrets_id', keep='first')
    return df


def clean_out_nan_heavy_rows(df: pd.DataFrame, age, age_ranges, spatial_2016, income_2016, households_2016):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_2016.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df2[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna()) # df2.age_0_19.isna() | 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


def create_busstops_files():
    """
    Creates a .parquet file that stores info aboute the number of busstops within a 1 kilometer
    radius of a given store, as well as the number of stops within the different importance categories.  
    """

    def bus_fields(row: pd.Series):
        output_dict = {}
        gpd.options.use_pygeos = True
        
        stops_with_dist = busstops[busstops_geo.distance(row.geometry) < 1000]
        output_dict['bus_stops_count'] = len(stops_with_dist)
        
        output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
            busstops_geo.importance_level.unique(), fill_value=0
        ).to_dict())
        
        return output_dict

    train_with_extras_bus = pd.concat([train_geo, train_geo_extra], ignore_index=True)

    train_with_extras_bus = train_with_extras_bus.join(train_with_extras_bus.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    train_with_extras_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_train.parquet')

    test_bus = test_geo.join(test_geo.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    test_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_test.parquet')


def create_stores_in_vicinity_files():
    """
    Creates a .parquet file that stores info aboute the number of other stores within a 1 kilometer
    radius of a given store.
    """

    train_with_extras = pd.concat([train_geo, train_geo_extra], ignore_index=True)[['store_id', 'geometry']]

    def store_count_in_vicinity(row: pd.Series):
        stores_in_vicinity = train_with_extras[train_with_extras.distance(row.geometry) < 1000]
        return {'stores_count_lt_1km': len(stores_in_vicinity)}

    train_with_extras_vicinity = train_with_extras.join(train_with_extras.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    train_with_extras_vicinity.to_parquet('derived_data/stores_count_lt_1km_train.parquet')

    test_vicinity = test_geo.join(test_geo.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    test_vicinity.to_parquet('derived_data/stores_count_lt_1km_test.parquet')

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# The train and test data only contains data from 2016, so for the other datasets with an age column
# we only use the values from 2016, where possible.

# %%
age_ranges = [
    (0, 19),
    (20, 39),
    (40, 59),
    (60, 79),
    (80, 90),
]

spatial_latest = only_latest_data(spatial)
income_latest = only_latest_data(income)
households_latest = only_latest_data(households)

train_spatial = train.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
muni_avg_revenue = train_spatial.groupby(by='municipality_name', as_index=False)['revenue'].mean()

# %% [markdown]
# Futhermore, we noticed that a number of rows in the train and test datasets didn't have

# %%
def clean(df: pd.DataFrame, min_val=0, max_val=100):
    print('Length of data frame:', len(df))
    df = df[(df.revenue > min_val) & (df.revenue < max_val)]
    print('Length after removing extreme values and zero revenue retail stores:',  len(df))
    return df.drop(columns=['revenue']), df.revenue


def clean_out_nan_heavy_rows(df: pd.DataFrame):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_latest.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna())  # | df2.age_0_19.isna() 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


train = clean_out_nan_heavy_rows(train)
label_name = 'revenue'
X = train.drop(columns=[label_name])
y = train[label_name]

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=.8, random_state=SEED)
X_train, y_train = clean(pd.merge(X_train, y_train, left_index=True, right_index=True))

y_train = np.log1p(y_train)
y_val = np.log1p(y_val)
# Out:
# Cleaned out 127 out of 12859 rows.
# Length of data frame: 10185
# Length after removing extreme values and zero revenue retail stores: 9947

# %% [markdown]
# # 3. Feature generation

# %% [markdown]
# Create files for busstops and stores in vicinity of each store:

# %%
# !mkdir -p derived_data

if len(os.listdir('derived_data')) == 0:
    create_busstops_files()
    create_stores_in_vicinity_files()

# %%
def generate_features(df: pd.DataFrame, data_origin: str, predictor: str = ''):
    # Define datasets to be merged
    age_groups_merge = group_ages(age, age_ranges)
    spatial_merge = spatial_latest.drop(columns=['year'])
    income_merge = income_latest.drop(columns=['year'])
    households_merge = households_latest.drop(columns=['year'])
    plaace_merge = plaace.drop_duplicates(subset='plaace_hierarchy_id')
    bus_data_train_merge = gpd.read_parquet(f'derived_data/stores_bus_stops_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])
    stores_vicinity_merge = gpd.read_parquet(f'derived_data/stores_count_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])

    # Merge datasets
    df = df.merge(age_groups_merge, on='grunnkrets_id', how='left')
    df = df.merge(spatial_merge, on='grunnkrets_id', how='left')
    df = df.merge(income_merge, on='grunnkrets_id', how='left')
    df = df.merge(households_merge, on='grunnkrets_id', how='left')
    df = df.merge(plaace_merge, how='left')
    df = df.merge(bus_data_train_merge, on='store_id', how='left')
    df = df.merge(stores_vicinity_merge, on='store_id', how='left')
    df = add_city_centre_dist(df).drop(columns=['lon_center', 'lat_center'])

    # Transformations and some post-merge cleaning
    df.stores_count_lt_1km = np.log(df.stores_count_lt_1km)
    df[age_groups_merge.columns] = df[age_groups_merge.columns].fillna(0)
    
    # Handle categories for different predictors
    if predictor == 'xgb':
        df = object_encoder(df)
    elif predictor == 'cb':
        df = nan_to_string(df)
    elif predictor == 'lgb':
        df = to_categorical(df)
    else: 
        raise ValueError('Invalid predictor')

    features = [
        'store_name', 
        'mall_name', 
        'chain_name',
        'address', 
        'lat', 'lon',
        
        *age_groups_merge.drop(columns=['grunnkrets_id']).columns,
        *income_merge.drop(columns=['grunnkrets_id']).columns,
        *households_merge.drop(columns=['grunnkrets_id']).columns,
        'lv1_desc', 'lv2_desc', 'sales_channel_name', 
        *bus_data_train_merge.drop(columns=['store_id']).columns,
        *stores_vicinity_merge.drop(columns=['store_id']).columns,
        'dist_to_center'
    ]

    return df[features]

# %% [markdown]
# # TDT4173 - Group 10: EDA, feature engineering and models
#
# `Group members`:
# - Kaspar Paus Græsdal, 493880
# - Oskar Holm, 527085
# - Vegard Følstad Kolaas, 767941
#
# In this notebook we ("[Group 10] Dunder Mifflin" on Kaggle) will elaborate upon our exploratory data analysis, and the different models we have tried out/used for this year(2022)'s project in TDT4173.

# %% [markdown]
# # TDT4173 - Group 10: EDA, feature engineering and models
#
# `Group members`:
# - Kaspar Paus Græsdal, 493880
# - Oskar Holm, 527085
# - Vegard Følstad Kolaas, 767941
#
# In this notebook we ("[Group 10] Dunder Mifflin" on Kaggle) will elaborate upon our exploratory data analysis, and the different models we have tried out/used for this year(2022)'s project in TDT4173.

# %%
# Features adapted to Catboost
X_train_cb = generate_features(X_train, data_origin='train', predictor='cb')
X_val_cb = generate_features(X_val, data_origin='train', predictor='cb')
X_test_cb = generate_features(test, data_origin='test', predictor='cb')

# Features adapted to LightGBM
X_train_lgb = generate_features(X_train, data_origin='train', predictor='lgb')
X_val_lgb = generate_features(X_val, data_origin='train', predictor='lgb')
X_test_lgb = generate_features(test, data_origin='test', predictor='lgb')

# %% [markdown]
# # 4. Hyper parameter tuning

# %% [markdown]
# ### Preparing pools and parameter grid for Catboost

# %%
def get_cb_pools():
    text_features = ['store_name', 'address', 'sales_channel_name'] 
    cat_features = ['mall_name', 'chain_name', 'lv1_desc', 'lv2_desc']

    train_pool = cb.Pool(
        X_train_cb,
        y_train,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    valid_pool = cb.Pool(
        X_val_cb,
        y_val,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    return train_pool, valid_pool


def get_cb_params(trial: optuna.Trial = None):
    gpu_count = get_gpu_device_count()
    non_tunable_cb_params = {
        'objective': 'RMSE',
        'eval_metric': 'RMSE',
        'task_type': 'GPU' if gpu_count else 'CPU', 
        'devices': f'0:{gpu_count}',
        'random_seed': SEED
    }

    if trial is None:
        return 'cb', non_tunable_cb_params
    
    tunable_params = {
        'depth': trial.suggest_int('depth', 4, 9),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 2, 6),
        # 'iterations': trial.suggest_int('iterations', 1000, 2000),
        # 'learning_rate': trial.suggest_categorical('learning_rate', 0.1, 0.5)
    }

    return 'cb', non_tunable_cb_params, tunable_params

# %% [markdown]
# ### Preparing DMatrices and parameter grid for LightGBM

# %%
def get_lgb_dmatrices():
    dtrain = lgb.Dataset(X_train_lgb, y_train, params={'verbose': -1}, free_raw_data=False)
    dvalid = lgb.Dataset(X_val_lgb, y_val, params={'verbose': -1}, free_raw_data=False)
    return dtrain, dvalid


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def get_lgb_params(trial: optuna.Trial = None):
    non_tunable_lgb_params = {
        'objective': 'rmse',
        'verbose': -1,
        'seed': 1
    }

    if trial is None:
        return 'lgb', non_tunable_lgb_params

    tunable_params = {
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'goss', 'dart']),
    }

    if tunable_params['boosting_type'] != 'goss':
        tunable_params["bagging_fraction"]: trial.suggest_float("bagging_fraction", 0.4, 1.0)
        tunable_params["bagging_freq"]: trial.suggest_int("bagging_freq", 1, 7)

    return 'lgb', non_tunable_lgb_params, tunable_params

# %% [markdown]
# ### Hyper parameter tuning with Optuna

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def objective(trial: optuna.Trial, param_grid_fn: Callable) -> float:
    model_name, non_tunable_params, tunable_params = param_grid_fn(trial)
  
    if model_name == 'cb':
        if tunable_params['bootstrap_type'] == 'Bayesian': 
            tunable_params['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)
        elif tunable_params['bootstrap_type'] == 'Bernoulli':
            tunable_params['subsample'] = trial.suggest_float('subsample', 0.1, 1, log=True)

        cbr = cb.CatBoostRegressor(**non_tunable_params, **tunable_params) 
        train_pool, valid_pool = get_cb_pools()
        cbr.fit(
            train_pool,
            eval_set=[(X_val_cb, y_val)],
            verbose=0,
            early_stopping_rounds=100,
        )
        y_pred = cbr.predict(X_val_cb)
    
    elif model_name == 'lgb':
        dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
        lgbr = lgb.train(
            params={**non_tunable_params, **tunable_params},
            train_set=dtrain_lgb,
            valid_sets=dvalid_lgb,
            verbose_eval=False,
        )
        y_pred = lgbr.predict(X_val_lgb)

    score = rmsle(np.expm1(y_val), np.expm1(y_pred))

    return score


def get_hyper_parameters(param_grid_fn: Callable, n_trials=100):
    study = optuna.create_study(
        study_name='hyperparam-tuning',
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), 
        direction='minimize'
    )
    objective_fn = lambda trial: objective(trial, param_grid_fn)
    study.optimize(objective_fn, n_trials=n_trials)  # , timeout=900 

    print('Number of finished trials: {}'.format(len(study.trials)))
    
    trial = study.best_trial
    print(f'Best trial ({trial.number}):')
    print('Value:', trial.value)
    print('Params:')
    print(trial.params)

    return param_grid_fn()[1], trial.params

# %% [markdown]
# # 5. Training step

# %% [markdown]
# ### Making predictions with Catboost

# %%
non_tunable_cb_params, tuned_params = get_hyper_parameters(get_cb_params, n_trials=30)
train_pool, valid_pool = get_cb_pools()
cbm = cb.CatBoostRegressor(**non_tunable_cb_params, **tuned_params, iterations=1000) 
cbm.fit(train_pool, eval_set=valid_pool, verbose=50, plot=True, early_stopping_rounds=50)
# Out:
# [I 2022-11-13 17:08:29,776] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-13 17:08:36,882] Trial 0 finished with value: 0.7312369645430385 and parameters: {'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.7172892741946795, 'subsample': 0.3480625209427441}. Best is trial 0 with value: 0.7312369645430385.
# [I 2022-11-13 17:08:47,321] Trial 1 finished with value: 0.7888818979242755 and parameters: {'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 3.1111954893748197, 'bagging_temperature': 9.268664596286904}. Best is trial 0 with value: 0.7312369645430385.
# [I 2022-11-13 17:09:10,154] Trial 2 finished with value: 0.72711443152328 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.0762166194028637, 'bagging_temperature': 0.40881224934548044}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:09:16,882] Trial 3 finished with value: 0.7837325587897802 and parameters: {'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 3.987774118497675, 'bagging_temperature': 9.372282883806884}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:09:26,670] Trial 4 finished with value: 0.7603113717930028 and parameters: {'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.861322099499799, 'bagging_temperature': 6.221028749455689}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:09:32,263] Trial 5 finished with value: 0.7795942050712541 and parameters: {'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 3.3859621909581983, 'bagging_temperature': 8.456056642424514}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:09:40,291] Trial 6 finished with value: 0.7428078861926364 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.784447386884117}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:09:47,561] Trial 7 finished with value: 0.7397871043993922 and parameters: {'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.121688446225577, 'bagging_temperature': 3.3541211719027544}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:10:00,509] Trial 8 finished with value: 0.7406203308317328 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 4.778734768157074}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:10:05,521] Trial 9 finished with value: 0.7330322233013825 and parameters: {'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.390193509590888, 'subsample': 0.5602813720139145}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:10:43,415] Trial 10 finished with value: 0.7368168250679771 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.16327762318691, 'subsample': 0.10074062787068443}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:11:21,340] Trial 11 finished with value: 0.7302360988934837 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.844580250194893, 'subsample': 0.2718201717533923}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:11:59,392] Trial 12 finished with value: 0.7324688168322017 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.883168809273917, 'subsample': 0.1585952270388311}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:12:22,927] Trial 13 finished with value: 0.7300218594062907 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.974329612315696, 'subsample': 0.24638681358586287}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:12:37,820] Trial 14 finished with value: 0.7360877308096834 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 5.246156069323384}. Best is trial 2 with value: 0.72711443152328.
# [I 2022-11-13 17:13:01,018] Trial 15 finished with value: 0.7259515299798315 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.0040014352050313, 'subsample': 0.8829810058101248}. Best is trial 15 with value: 0.7259515299798315.
# [I 2022-11-13 17:13:12,731] Trial 16 finished with value: 0.7297959607869363 and parameters: {'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.0307526241699088, 'bagging_temperature': 0.824723229750516}. Best is trial 15 with value: 0.7259515299798315.
# [I 2022-11-13 17:13:36,269] Trial 17 finished with value: 0.7251373468724214 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.6494599983008547, 'subsample': 0.9343232755941812}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:13:47,726] Trial 18 finished with value: 0.728037701743088 and parameters: {'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.5913603155237985, 'subsample': 0.9521382960359087}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:14:11,022] Trial 19 finished with value: 0.7268076985360553 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.593238341753438, 'subsample': 0.9732241337795682}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:14:48,987] Trial 20 finished with value: 0.7251832311624227 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.5114854351739635, 'subsample': 0.5973861343245515}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:15:26,462] Trial 21 finished with value: 0.7253100245054546 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.4981309500787736, 'subsample': 0.6091655381700407}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:16:03,840] Trial 22 finished with value: 0.7259979676185506 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.4956591233986782, 'subsample': 0.5597727503693947}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:16:37,192] Trial 23 finished with value: 0.7255102838661985 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.222406514785428, 'subsample': 0.5945215386313725}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:17:18,501] Trial 24 finished with value: 0.7254817006030925 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.03812986112886, 'subsample': 0.6531031042272721}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:17:55,643] Trial 25 finished with value: 0.7270047277341324 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.511305842286566, 'subsample': 0.3838376313258257}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:18:09,780] Trial 26 finished with value: 0.7395881942177827 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.6140698634392847}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:18:25,481] Trial 27 finished with value: 0.7269715425971142 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.753226252307164, 'subsample': 0.7484087561496562}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:19:02,612] Trial 28 finished with value: 0.728672608124663 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.3044215909369496, 'subsample': 0.4327935334666697}. Best is trial 17 with value: 0.7251373468724214.
# [I 2022-11-13 17:19:09,703] Trial 29 finished with value: 0.7300764327652688 and parameters: {'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.4231085076234575, 'subsample': 0.5023919377849231}. Best is trial 17 with value: 0.7251373468724214.
# Number of finished trials: 30
# Best trial (17):
# Value: 0.7251373468724214
# Params:
# {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.6494599983008547, 'subsample': 0.9343232755941812}
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.9763710	test: 0.9981538	best: 0.9981538 (0)	total: 31.3ms	remaining: 31.3s
# 50:	learn: 0.7440541	test: 0.7758914	best: 0.7758914 (50)	total: 1.58s	remaining: 29.4s
# 100:	learn: 0.7105180	test: 0.7505405	best: 0.7505405 (100)	total: 2.99s	remaining: 26.6s
# 150:	learn: 0.6974631	test: 0.7415716	best: 0.7415716 (150)	total: 4.27s	remaining: 24s
# 200:	learn: 0.6889687	test: 0.7364554	best: 0.7364554 (200)	total: 5.51s	remaining: 21.9s
# 250:	learn: 0.6831254	test: 0.7340055	best: 0.7340055 (250)	total: 6.72s	remaining: 20.1s
# 300:	learn: 0.6791592	test: 0.7325670	best: 0.7325670 (300)	total: 7.88s	remaining: 18.3s
# 350:	learn: 0.6751234	test: 0.7311661	best: 0.7311661 (350)	total: 8.94s	remaining: 16.5s
# 400:	learn: 0.6711432	test: 0.7298568	best: 0.7298568 (400)	total: 9.99s	remaining: 14.9s
# 450:	learn: 0.6680409	test: 0.7291608	best: 0.7291608 (450)	total: 11s	remaining: 13.4s
# 500:	learn: 0.6650323	test: 0.7286954	best: 0.7286682 (497)	total: 12s	remaining: 12s
# 550:	learn: 0.6624475	test: 0.7281780	best: 0.7281348 (545)	total: 13.1s	remaining: 10.6s
# 600:	learn: 0.6605892	test: 0.7277624	best: 0.7277351 (596)	total: 14.1s	remaining: 9.35s
# 650:	learn: 0.6581855	test: 0.7273593	best: 0.7273551 (649)	total: 15.1s	remaining: 8.09s
# 700:	learn: 0.6559411	test: 0.7268917	best: 0.7268664 (694)	total: 16.1s	remaining: 6.88s
# 750:	learn: 0.6547864	test: 0.7267761	best: 0.7267698 (747)	total: 17.2s	remaining: 5.69s
# 800:	learn: 0.6527733	test: 0.7263781	best: 0.7263587 (799)	total: 18.2s	remaining: 4.52s
# 850:	learn: 0.6508041	test: 0.7260285	best: 0.7260190 (849)	total: 19.2s	remaining: 3.36s
# 900:	learn: 0.6487218	test: 0.7256123	best: 0.7256045 (899)	total: 20.2s	remaining: 2.22s
# 950:	learn: 0.6471232	test: 0.7254412	best: 0.7254412 (950)	total: 21.2s	remaining: 1.09s
# 999:	learn: 0.6459423	test: 0.7255762	best: 0.7254412 (950)	total: 22.2s	remaining: 0us
# bestTest = 0.7254412168
# bestIteration = 950
# Shrink model to first 951 iterations.

# %% [markdown]
# ### Making predictions with LightGBM

# %%
non_tunable_lgb_params, tunable_lgb_params = get_hyper_parameters(get_lgb_params, n_trials=400)
dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
lgbm = lgb.train(
    params={**non_tunable_lgb_params, **tunable_lgb_params},
    train_set=dtrain_lgb,
    valid_sets=dvalid_lgb,
    verbose_eval=False
)
# Out:
# [I 2022-11-13 17:19:32,808] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-13 17:19:57,306] Trial 0 finished with value: 0.7537689135571148 and parameters: {'lambda_l1': 5.7585137784047633e-08, 'lambda_l2': 0.03263116871375016, 'num_leaves': 154, 'feature_fraction': 0.9681242146387169, 'min_child_samples': 56, 'boosting_type': 'dart'}. Best is trial 0 with value: 0.7537689135571148.
# [I 2022-11-13 17:20:16,954] Trial 1 finished with value: 0.7577994385612598 and parameters: {'lambda_l1': 1.4252753550605394e-08, 'lambda_l2': 2.8391180342344016e-06, 'num_leaves': 164, 'feature_fraction': 0.4428997241475635, 'min_child_samples': 30, 'boosting_type': 'dart'}. Best is trial 0 with value: 0.7537689135571148.
# [I 2022-11-13 17:20:34,156] Trial 2 finished with value: 0.7511059888421097 and parameters: {'lambda_l1': 0.0021302389054788065, 'lambda_l2': 9.608567624505813e-07, 'num_leaves': 70, 'feature_fraction': 0.7715363592183468, 'min_child_samples': 52, 'boosting_type': 'dart'}. Best is trial 2 with value: 0.7511059888421097.
# [I 2022-11-13 17:20:39,018] Trial 3 finished with value: 0.7715361501200785 and parameters: {'lambda_l1': 2.417741870429276, 'lambda_l2': 1.9297908624323255e-08, 'num_leaves': 77, 'feature_fraction': 0.5860360646859503, 'min_child_samples': 18, 'boosting_type': 'goss'}. Best is trial 2 with value: 0.7511059888421097.
# [I 2022-11-13 17:20:43,294] Trial 4 finished with value: 0.750034902509855 and parameters: {'lambda_l1': 0.034781506346054904, 'lambda_l2': 8.184182454420711e-08, 'num_leaves': 64, 'feature_fraction': 0.8985646475234521, 'min_child_samples': 74, 'boosting_type': 'dart'}. Best is trial 4 with value: 0.750034902509855.
# [I 2022-11-13 17:20:50,091] Trial 5 finished with value: 0.7484890199323155 and parameters: {'lambda_l1': 0.7436833738999057, 'lambda_l2': 3.2115713418821865e-08, 'num_leaves': 27, 'feature_fraction': 0.7858554754239322, 'min_child_samples': 15, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:20:58,441] Trial 6 finished with value: 0.7510759909017491 and parameters: {'lambda_l1': 6.647460355192173e-06, 'lambda_l2': 2.415978349672991e-05, 'num_leaves': 218, 'feature_fraction': 0.8469003083311475, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:21:05,123] Trial 7 finished with value: 0.7570258347904518 and parameters: {'lambda_l1': 6.138401429612935e-05, 'lambda_l2': 9.506662359353687e-06, 'num_leaves': 83, 'feature_fraction': 0.8302461258790035, 'min_child_samples': 18, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:21:25,777] Trial 8 finished with value: 0.7554509386320006 and parameters: {'lambda_l1': 4.076284246285952e-08, 'lambda_l2': 4.103467721800455e-06, 'num_leaves': 148, 'feature_fraction': 0.5243440346423172, 'min_child_samples': 50, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:21:57,652] Trial 9 finished with value: 0.7753888674577674 and parameters: {'lambda_l1': 0.00029919642382679224, 'lambda_l2': 0.000995676111858356, 'num_leaves': 249, 'feature_fraction': 0.9629260417117987, 'min_child_samples': 34, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:21:58,161] Trial 10 finished with value: 0.7507989499754905 and parameters: {'lambda_l1': 6.374810967401082, 'lambda_l2': 5.41180944730515, 'num_leaves': 4, 'feature_fraction': 0.6791012160235257, 'min_child_samples': 5, 'boosting_type': 'goss'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:21:59,829] Trial 11 finished with value: 0.757274671918296 and parameters: {'lambda_l1': 0.07137992318413816, 'lambda_l2': 1.0120969937338635e-08, 'num_leaves': 4, 'feature_fraction': 0.8833633993939194, 'min_child_samples': 85, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:22:06,667] Trial 12 finished with value: 0.7503432202485676 and parameters: {'lambda_l1': 0.05151892717793504, 'lambda_l2': 1.3208316779186133e-07, 'num_leaves': 46, 'feature_fraction': 0.7100857642776561, 'min_child_samples': 68, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:22:11,856] Trial 13 finished with value: 0.7537259970060484 and parameters: {'lambda_l1': 0.08181335037256295, 'lambda_l2': 0.00027211357492172594, 'num_leaves': 110, 'feature_fraction': 0.7439742115188976, 'min_child_samples': 73, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:22:21,984] Trial 14 finished with value: 0.7487948846781703 and parameters: {'lambda_l1': 0.007381041690011845, 'lambda_l2': 1.7088021082024603e-07, 'num_leaves': 36, 'feature_fraction': 0.9033986395143757, 'min_child_samples': 99, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:22:24,814] Trial 15 finished with value: 0.7546523893615459 and parameters: {'lambda_l1': 0.002918425906282942, 'lambda_l2': 1.9047043399060156e-07, 'num_leaves': 27, 'feature_fraction': 0.6305973613376379, 'min_child_samples': 100, 'boosting_type': 'goss'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:22:44,158] Trial 16 finished with value: 0.7551259887578405 and parameters: {'lambda_l1': 1.0227388300396758, 'lambda_l2': 0.00030334041062552987, 'num_leaves': 110, 'feature_fraction': 0.999831383332629, 'min_child_samples': 39, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7484890199323155.
# [I 2022-11-13 17:22:49,448] Trial 17 finished with value: 0.7475000156624854 and parameters: {'lambda_l1': 4.378274910470013e-06, 'lambda_l2': 0.028707282181448714, 'num_leaves': 34, 'feature_fraction': 0.7788802562096431, 'min_child_samples': 99, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:22:56,925] Trial 18 finished with value: 0.7645566050069794 and parameters: {'lambda_l1': 1.697534851627791e-06, 'lambda_l2': 0.09147364730034624, 'num_leaves': 108, 'feature_fraction': 0.785014441901175, 'min_child_samples': 7, 'boosting_type': 'gbdt'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:22:58,417] Trial 19 finished with value: 0.7536860278433223 and parameters: {'lambda_l1': 8.182126140890373e-07, 'lambda_l2': 0.011690729660271496, 'num_leaves': 24, 'feature_fraction': 0.657218340615997, 'min_child_samples': 24, 'boosting_type': 'goss'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:23:11,183] Trial 20 finished with value: 0.7556948367614047 and parameters: {'lambda_l1': 3.29235867548268e-05, 'lambda_l2': 1.2734250122539335, 'num_leaves': 203, 'feature_fraction': 0.600696581635216, 'min_child_samples': 40, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:23:18,178] Trial 21 finished with value: 0.7480104930524137 and parameters: {'lambda_l1': 0.002855670635227416, 'lambda_l2': 0.0034053734549657176, 'num_leaves': 41, 'feature_fraction': 0.8176253209699569, 'min_child_samples': 90, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:23:33,414] Trial 22 finished with value: 0.7502286196210098 and parameters: {'lambda_l1': 0.00048190980320412895, 'lambda_l2': 0.0029053326107458294, 'num_leaves': 51, 'feature_fraction': 0.8266354925628838, 'min_child_samples': 86, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:23:37,672] Trial 23 finished with value: 0.7481133705090843 and parameters: {'lambda_l1': 0.4996695073794826, 'lambda_l2': 0.24500507287627257, 'num_leaves': 17, 'feature_fraction': 0.7440012792552492, 'min_child_samples': 91, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:23:40,693] Trial 24 finished with value: 0.7580801718144311 and parameters: {'lambda_l1': 6.241017884184719e-07, 'lambda_l2': 0.42833118168853107, 'num_leaves': 4, 'feature_fraction': 0.731156119894891, 'min_child_samples': 94, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:23:50,177] Trial 25 finished with value: 0.7523518220409028 and parameters: {'lambda_l1': 2.0060053442112546e-05, 'lambda_l2': 0.13879359501195154, 'num_leaves': 86, 'feature_fraction': 0.8089020577503409, 'min_child_samples': 79, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:24:02,914] Trial 26 finished with value: 0.7492783645064879 and parameters: {'lambda_l1': 0.00026979610622470263, 'lambda_l2': 0.0068405239729578335, 'num_leaves': 54, 'feature_fraction': 0.7093623954885537, 'min_child_samples': 93, 'boosting_type': 'dart'}. Best is trial 17 with value: 0.7475000156624854.
# [I 2022-11-13 17:24:13,560] Trial 27 finished with value: 0.7472714098608939 and parameters: {'lambda_l1': 0.2515084816434605, 'lambda_l2': 6.726352813851527e-05, 'num_leaves': 23, 'feature_fraction': 0.7548229680980667, 'min_child_samples': 65, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:24:23,423] Trial 28 finished with value: 0.7560635866068647 and parameters: {'lambda_l1': 0.0033739433478936856, 'lambda_l2': 5.205023385382224e-05, 'num_leaves': 90, 'feature_fraction': 0.8541077713505136, 'min_child_samples': 63, 'boosting_type': 'gbdt'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:24:39,478] Trial 29 finished with value: 0.7563443086104471 and parameters: {'lambda_l1': 2.9379209161261886e-07, 'lambda_l2': 0.02242122165029534, 'num_leaves': 129, 'feature_fraction': 0.9143737266314966, 'min_child_samples': 60, 'boosting_type': 'goss'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:24:41,734] Trial 30 finished with value: 0.7493412709708394 and parameters: {'lambda_l1': 0.014032583771834084, 'lambda_l2': 9.487277557344102e-05, 'num_leaves': 42, 'feature_fraction': 0.5633087229824074, 'min_child_samples': 82, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:24:52,083] Trial 31 finished with value: 0.74808364476473 and parameters: {'lambda_l1': 0.2974234071934959, 'lambda_l2': 0.058693460446184106, 'num_leaves': 22, 'feature_fraction': 0.7541442577163939, 'min_child_samples': 92, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:03,410] Trial 32 finished with value: 0.7490215842868455 and parameters: {'lambda_l1': 0.2640874886161899, 'lambda_l2': 0.001674346380461445, 'num_leaves': 61, 'feature_fraction': 0.7691775269894001, 'min_child_samples': 76, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:05,275] Trial 33 finished with value: 0.7515190793285731 and parameters: {'lambda_l1': 0.0005642212694328576, 'lambda_l2': 0.03007062512459283, 'num_leaves': 17, 'feature_fraction': 0.41551450233232934, 'min_child_samples': 93, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:13,305] Trial 34 finished with value: 0.7480909025908318 and parameters: {'lambda_l1': 0.17531314829348646, 'lambda_l2': 0.0057052664887651166, 'num_leaves': 34, 'feature_fraction': 0.6875148341396962, 'min_child_samples': 68, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:26,491] Trial 35 finished with value: 0.7494393459929921 and parameters: {'lambda_l1': 2.978178678027026, 'lambda_l2': 0.0006891771324541281, 'num_leaves': 67, 'feature_fraction': 0.8033866308510902, 'min_child_samples': 97, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:39,983] Trial 36 finished with value: 0.7490903626614608 and parameters: {'lambda_l1': 4.200413467674958e-06, 'lambda_l2': 0.05807279264836215, 'num_leaves': 173, 'feature_fraction': 0.8701494549754032, 'min_child_samples': 88, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:49,514] Trial 37 finished with value: 0.749171189318936 and parameters: {'lambda_l1': 0.01515122744238626, 'lambda_l2': 1.0461634719898028, 'num_leaves': 41, 'feature_fraction': 0.9352046834794905, 'min_child_samples': 51, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:52,729] Trial 38 finished with value: 0.7483650909311864 and parameters: {'lambda_l1': 9.869896003376276e-05, 'lambda_l2': 0.00012056325591910904, 'num_leaves': 16, 'feature_fraction': 0.7575199348641635, 'min_child_samples': 81, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:25:59,215] Trial 39 finished with value: 0.7543694361844226 and parameters: {'lambda_l1': 2.0981649095879433, 'lambda_l2': 1.4333308531042193e-05, 'num_leaves': 69, 'feature_fraction': 0.6513171775271284, 'min_child_samples': 70, 'boosting_type': 'goss'}. Best is trial 27 with value: 0.7472714098608939.
# [I 2022-11-13 17:26:06,646] Trial 40 finished with value: 0.7470751223811462 and parameters: {'lambda_l1': 1.113293588031918e-08, 'lambda_l2': 1.015749188841034e-06, 'num_leaves': 54, 'feature_fraction': 0.8042476319170146, 'min_child_samples': 57, 'boosting_type': 'gbdt'}. Best is trial 40 with value: 0.7470751223811462.
# [I 2022-11-13 17:26:15,819] Trial 41 finished with value: 0.746045668455811 and parameters: {'lambda_l1': 3.4357221881168457e-08, 'lambda_l2': 4.348050850388604e-06, 'num_leaves': 54, 'feature_fraction': 0.8058191348965931, 'min_child_samples': 61, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:26:17,495] Trial 42 finished with value: 0.757232713731338 and parameters: {'lambda_l1': 2.2199720143051854e-08, 'lambda_l2': 8.866430646275091e-07, 'num_leaves': 80, 'feature_fraction': 0.8222903652273921, 'min_child_samples': 48, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:26:24,951] Trial 43 finished with value: 0.747184996578553 and parameters: {'lambda_l1': 1.1370870705942092e-07, 'lambda_l2': 1.5879359202541765e-06, 'num_leaves': 56, 'feature_fraction': 0.8571017145327259, 'min_child_samples': 59, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:26:31,484] Trial 44 finished with value: 0.7487066850337044 and parameters: {'lambda_l1': 1.0766309544271007e-08, 'lambda_l2': 2.1332208814794274e-06, 'num_leaves': 56, 'feature_fraction': 0.86900499090001, 'min_child_samples': 60, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:26:40,369] Trial 45 finished with value: 0.7557287593272562 and parameters: {'lambda_l1': 1.346510046923349e-07, 'lambda_l2': 3.8158972390523e-07, 'num_leaves': 92, 'feature_fraction': 0.7863360910311313, 'min_child_samples': 57, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:26:44,890] Trial 46 finished with value: 0.7573209058313767 and parameters: {'lambda_l1': 7.305588744033952e-08, 'lambda_l2': 7.850317188159396e-06, 'num_leaves': 99, 'feature_fraction': 0.8428093704151121, 'min_child_samples': 45, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:27:03,827] Trial 47 finished with value: 0.7565430029750799 and parameters: {'lambda_l1': 3.924227822661309e-08, 'lambda_l2': 1.7384055675469289e-06, 'num_leaves': 75, 'feature_fraction': 0.9322574639124311, 'min_child_samples': 63, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:27:09,964] Trial 48 finished with value: 0.7619892605730786 and parameters: {'lambda_l1': 1.4972191642496904e-07, 'lambda_l2': 3.095135889753576e-08, 'num_leaves': 127, 'feature_fraction': 0.7248211290043598, 'min_child_samples': 53, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:27:19,491] Trial 49 finished with value: 0.7495090401873279 and parameters: {'lambda_l1': 1.939496430771022e-08, 'lambda_l2': 6.478897323345028e-07, 'num_leaves': 62, 'feature_fraction': 0.8859209855620229, 'min_child_samples': 45, 'boosting_type': 'gbdt'}. Best is trial 41 with value: 0.746045668455811.
# [I 2022-11-13 17:27:25,354] Trial 50 finished with value: 0.7417078803598839 and parameters: {'lambda_l1': 2.73996845191158e-06, 'lambda_l2': 4.8764317936600005e-06, 'num_leaves': 33, 'feature_fraction': 0.7971151493411865, 'min_child_samples': 65, 'boosting_type': 'gbdt'}. Best is trial 50 with value: 0.7417078803598839.
# [I 2022-11-13 17:27:29,514] Trial 51 finished with value: 0.7445200160651905 and parameters: {'lambda_l1': 4.323194460714624e-06, 'lambda_l2': 5.001746364846966e-06, 'num_leaves': 49, 'feature_fraction': 0.788543024054929, 'min_child_samples': 55, 'boosting_type': 'gbdt'}. Best is trial 50 with value: 0.7417078803598839.
# [I 2022-11-13 17:27:35,372] Trial 52 finished with value: 0.7418920593389566 and parameters: {'lambda_l1': 1.1506018824929255e-05, 'lambda_l2': 5.25750620319371e-06, 'num_leaves': 52, 'feature_fraction': 0.7952699019274636, 'min_child_samples': 56, 'boosting_type': 'gbdt'}. Best is trial 50 with value: 0.7417078803598839.
# [I 2022-11-13 17:27:44,223] Trial 53 finished with value: 0.7443623393898868 and parameters: {'lambda_l1': 1.5136188576523675e-06, 'lambda_l2': 5.363487848301031e-06, 'num_leaves': 52, 'feature_fraction': 0.8530272169294107, 'min_child_samples': 55, 'boosting_type': 'gbdt'}. Best is trial 50 with value: 0.7417078803598839.
# [I 2022-11-13 17:27:50,527] Trial 54 finished with value: 0.7441919340500801 and parameters: {'lambda_l1': 1.5267146347535146e-05, 'lambda_l2': 4.666545707259152e-06, 'num_leaves': 49, 'feature_fraction': 0.7952065052018561, 'min_child_samples': 56, 'boosting_type': 'gbdt'}. Best is trial 50 with value: 0.7417078803598839.
# [I 2022-11-13 17:27:58,138] Trial 55 finished with value: 0.750479306857505 and parameters: {'lambda_l1': 9.721582443067874e-06, 'lambda_l2': 4.415892402806912e-06, 'num_leaves': 74, 'feature_fraction': 0.8424420177324884, 'min_child_samples': 54, 'boosting_type': 'gbdt'}. Best is trial 50 with value: 0.7417078803598839.
# [I 2022-11-13 17:28:00,456] Trial 56 finished with value: 0.7414539292043327 and parameters: {'lambda_l1': 2.2458695512075097e-06, 'lambda_l2': 3.4259844886222316e-05, 'num_leaves': 32, 'feature_fraction': 0.4956958352079587, 'min_child_samples': 46, 'boosting_type': 'gbdt'}. Best is trial 56 with value: 0.7414539292043327.
# [I 2022-11-13 17:28:02,432] Trial 57 finished with value: 0.7379949932454916 and parameters: {'lambda_l1': 1.4887839728141453e-06, 'lambda_l2': 2.7463663139791168e-05, 'num_leaves': 28, 'feature_fraction': 0.49223105976303827, 'min_child_samples': 36, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7379949932454916.
# [I 2022-11-13 17:28:09,625] Trial 58 finished with value: 0.7401674976720581 and parameters: {'lambda_l1': 1.4418009796360721e-06, 'lambda_l2': 2.716701925156086e-05, 'num_leaves': 32, 'feature_fraction': 0.48534202262233944, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7379949932454916.
# [I 2022-11-13 17:28:11,392] Trial 59 finished with value: 0.737976966941761 and parameters: {'lambda_l1': 1.2073813241389877e-05, 'lambda_l2': 2.8117252830825922e-05, 'num_leaves': 10, 'feature_fraction': 0.48390066667905973, 'min_child_samples': 30, 'boosting_type': 'gbdt'}. Best is trial 59 with value: 0.737976966941761.
# [I 2022-11-13 17:28:13,913] Trial 60 finished with value: 0.7382891558916567 and parameters: {'lambda_l1': 1.9922935368507775e-06, 'lambda_l2': 2.362322331066785e-05, 'num_leaves': 11, 'feature_fraction': 0.48693807744323997, 'min_child_samples': 25, 'boosting_type': 'gbdt'}. Best is trial 59 with value: 0.737976966941761.
# [I 2022-11-13 17:28:15,468] Trial 61 finished with value: 0.7374240205354835 and parameters: {'lambda_l1': 5.387000195507698e-07, 'lambda_l2': 2.5927853516679938e-05, 'num_leaves': 9, 'feature_fraction': 0.4867672687918355, 'min_child_samples': 30, 'boosting_type': 'gbdt'}. Best is trial 61 with value: 0.7374240205354835.
# [I 2022-11-13 17:28:19,484] Trial 62 finished with value: 0.7379840904918903 and parameters: {'lambda_l1': 1.8458399461683436e-06, 'lambda_l2': 2.411833090985351e-05, 'num_leaves': 8, 'feature_fraction': 0.48142482106047013, 'min_child_samples': 29, 'boosting_type': 'gbdt'}. Best is trial 61 with value: 0.7374240205354835.
# [I 2022-11-13 17:28:19,788] Trial 63 finished with value: 0.7350693442077924 and parameters: {'lambda_l1': 4.175620510369072e-07, 'lambda_l2': 3.038460928948613e-05, 'num_leaves': 10, 'feature_fraction': 0.48719703832965067, 'min_child_samples': 28, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:22,277] Trial 64 finished with value: 0.7374644265483601 and parameters: {'lambda_l1': 4.3445472614611003e-07, 'lambda_l2': 2.1538098556784508e-05, 'num_leaves': 11, 'feature_fraction': 0.47829457535310393, 'min_child_samples': 28, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:23,429] Trial 65 finished with value: 0.7387863927977878 and parameters: {'lambda_l1': 3.84229293164332e-07, 'lambda_l2': 1.4466603690819754e-05, 'num_leaves': 11, 'feature_fraction': 0.4598837325139664, 'min_child_samples': 25, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:23,900] Trial 66 finished with value: 0.7472436627737264 and parameters: {'lambda_l1': 7.565902844285703e-07, 'lambda_l2': 0.00017319121985883204, 'num_leaves': 2, 'feature_fraction': 0.5320127374084985, 'min_child_samples': 23, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:24,737] Trial 67 finished with value: 0.7394773794567664 and parameters: {'lambda_l1': 3.397480539779541e-07, 'lambda_l2': 1.628321086850522e-05, 'num_leaves': 10, 'feature_fraction': 0.4357648944142414, 'min_child_samples': 36, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:25,134] Trial 68 finished with value: 0.7366004729653504 and parameters: {'lambda_l1': 9.69456217926214e-07, 'lambda_l2': 4.842661422213869e-05, 'num_leaves': 9, 'feature_fraction': 0.5277532758959553, 'min_child_samples': 11, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:35,362] Trial 69 finished with value: 0.7392335335642678 and parameters: {'lambda_l1': 2.270755080547456e-07, 'lambda_l2': 5.653748114968612e-05, 'num_leaves': 24, 'feature_fraction': 0.5275792791180822, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:39,061] Trial 70 finished with value: 0.7501555143257436 and parameters: {'lambda_l1': 3.397867217741208e-05, 'lambda_l2': 0.00032961324711110006, 'num_leaves': 9, 'feature_fraction': 0.5582661861548138, 'min_child_samples': 20, 'boosting_type': 'goss'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:40,744] Trial 71 finished with value: 0.7397561592522148 and parameters: {'lambda_l1': 9.437969585655482e-07, 'lambda_l2': 3.546196182281899e-05, 'num_leaves': 13, 'feature_fraction': 0.49294568484404944, 'min_child_samples': 28, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:40,954] Trial 72 finished with value: 0.7380747713672295 and parameters: {'lambda_l1': 5.462115966977021e-07, 'lambda_l2': 0.0007142817379928516, 'num_leaves': 5, 'feature_fraction': 0.4685069605234443, 'min_child_samples': 11, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:42,545] Trial 73 finished with value: 0.7375013733673339 and parameters: {'lambda_l1': 5.695747569827614e-07, 'lambda_l2': 0.0005326150764918496, 'num_leaves': 20, 'feature_fraction': 0.4618576451705507, 'min_child_samples': 12, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:44,844] Trial 74 finished with value: 0.7383538035791203 and parameters: {'lambda_l1': 5.736290747568674e-06, 'lambda_l2': 0.000200174480298058, 'num_leaves': 21, 'feature_fraction': 0.40394337438592054, 'min_child_samples': 18, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:45,707] Trial 75 finished with value: 0.7427201351897188 and parameters: {'lambda_l1': 8.153745657684712e-08, 'lambda_l2': 9.165973364193348e-05, 'num_leaves': 27, 'feature_fraction': 0.5145118239774651, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:46,517] Trial 76 finished with value: 0.748139824672445 and parameters: {'lambda_l1': 4.710661072354373e-07, 'lambda_l2': 0.0003965853558087561, 'num_leaves': 2, 'feature_fraction': 0.44294336561789965, 'min_child_samples': 35, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:51,253] Trial 77 finished with value: 0.7380752789015637 and parameters: {'lambda_l1': 8.500574164368441e-07, 'lambda_l2': 9.687397046349279e-06, 'num_leaves': 19, 'feature_fraction': 0.5525067608975957, 'min_child_samples': 39, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:28:58,223] Trial 78 finished with value: 0.7453302024932267 and parameters: {'lambda_l1': 3.067262148303128e-06, 'lambda_l2': 7.382369386689489e-05, 'num_leaves': 40, 'feature_fraction': 0.584696627003568, 'min_child_samples': 7, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:03,617] Trial 79 finished with value: 0.7382955126953129 and parameters: {'lambda_l1': 2.2743329061255595e-07, 'lambda_l2': 0.0001895080804848406, 'num_leaves': 17, 'feature_fraction': 0.510195344382355, 'min_child_samples': 29, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:14,710] Trial 80 finished with value: 0.774648787757464 and parameters: {'lambda_l1': 1.1451469855488182e-06, 'lambda_l2': 0.0011050517803418288, 'num_leaves': 194, 'feature_fraction': 0.4656344497358037, 'min_child_samples': 20, 'boosting_type': 'goss'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:16,030] Trial 81 finished with value: 0.7374267269183598 and parameters: {'lambda_l1': 5.192824841281133e-07, 'lambda_l2': 0.0005928617259862214, 'num_leaves': 7, 'feature_fraction': 0.4660512674440119, 'min_child_samples': 11, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:29,614] Trial 82 finished with value: 0.7785644984182529 and parameters: {'lambda_l1': 8.602082592193643e-06, 'lambda_l2': 3.939901337640492e-05, 'num_leaves': 247, 'feature_fraction': 0.43115620503277685, 'min_child_samples': 11, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:31,094] Trial 83 finished with value: 0.738348424707729 and parameters: {'lambda_l1': 2.2591356011286943e-07, 'lambda_l2': 0.00052028306991266, 'num_leaves': 27, 'feature_fraction': 0.4506433027207425, 'min_child_samples': 42, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:31,933] Trial 84 finished with value: 0.7372725252806932 and parameters: {'lambda_l1': 5.694360373046341e-07, 'lambda_l2': 0.00013925823986120256, 'num_leaves': 9, 'feature_fraction': 0.4741688199079358, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:33,933] Trial 85 finished with value: 0.7379977414511149 and parameters: {'lambda_l1': 5.195759168249839e-07, 'lambda_l2': 0.00011133754982241216, 'num_leaves': 8, 'feature_fraction': 0.4216042123244383, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:36,862] Trial 86 finished with value: 0.7390155871669003 and parameters: {'lambda_l1': 1.5171453817404097e-07, 'lambda_l2': 0.0033324800661212093, 'num_leaves': 15, 'feature_fraction': 0.5396378096963416, 'min_child_samples': 5, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:40,004] Trial 87 finished with value: 0.738975193269871 and parameters: {'lambda_l1': 5.4421972098354296e-08, 'lambda_l2': 0.0016132093459260918, 'num_leaves': 7, 'feature_fraction': 0.4729012096598724, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:43,327] Trial 88 finished with value: 0.747903637760505 and parameters: {'lambda_l1': 9.823646017931298e-08, 'lambda_l2': 1.1084627740097004e-05, 'num_leaves': 2, 'feature_fraction': 0.5113131810636931, 'min_child_samples': 15, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:48,097] Trial 89 finished with value: 0.7418658241293531 and parameters: {'lambda_l1': 3.841897376860699e-06, 'lambda_l2': 0.0001336869635216034, 'num_leaves': 20, 'feature_fraction': 0.4539147461619302, 'min_child_samples': 9, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:49,904] Trial 90 finished with value: 0.7386086979718487 and parameters: {'lambda_l1': 3.4611744035078346e-07, 'lambda_l2': 5.944115540921432e-05, 'num_leaves': 15, 'feature_fraction': 0.4798153770788849, 'min_child_samples': 27, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:52,680] Trial 91 finished with value: 0.7399708617640597 and parameters: {'lambda_l1': 1.2522700101337708e-06, 'lambda_l2': 2.1973113378204423e-05, 'num_leaves': 29, 'feature_fraction': 0.49905551537965065, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:55,671] Trial 92 finished with value: 0.7421987137102459 and parameters: {'lambda_l1': 8.310449258806255e-07, 'lambda_l2': 0.00030389586673388214, 'num_leaves': 37, 'feature_fraction': 0.5761203153707898, 'min_child_samples': 33, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:58,164] Trial 93 finished with value: 0.7395888437968188 and parameters: {'lambda_l1': 1.7617545137183524e-06, 'lambda_l2': 4.326451686011105e-05, 'num_leaves': 26, 'feature_fraction': 0.608902584454525, 'min_child_samples': 12, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:58,644] Trial 94 finished with value: 0.7368727223152254 and parameters: {'lambda_l1': 2.2191442362202548e-05, 'lambda_l2': 8.60960945524743e-06, 'num_leaves': 8, 'feature_fraction': 0.5088856193721388, 'min_child_samples': 8, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:29:59,851] Trial 95 finished with value: 0.7366337812619965 and parameters: {'lambda_l1': 2.667316910789776e-05, 'lambda_l2': 1.2887784029013525e-05, 'num_leaves': 8, 'feature_fraction': 0.5461908300462721, 'min_child_samples': 8, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:03,721] Trial 96 finished with value: 0.7547820589427704 and parameters: {'lambda_l1': 0.00015094984978271823, 'lambda_l2': 2.29034060687938e-06, 'num_leaves': 20, 'feature_fraction': 0.5482305705116463, 'min_child_samples': 9, 'boosting_type': 'goss'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:09,702] Trial 97 finished with value: 0.7465338182255619 and parameters: {'lambda_l1': 4.61645980240238e-05, 'lambda_l2': 1.0414421700276829e-05, 'num_leaves': 45, 'feature_fraction': 0.519967129970318, 'min_child_samples': 15, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:13,224] Trial 98 finished with value: 0.7380283516215236 and parameters: {'lambda_l1': 2.3106962752001187e-05, 'lambda_l2': 8.445425957624836e-06, 'num_leaves': 13, 'feature_fraction': 0.5013031021991744, 'min_child_samples': 5, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:14,037] Trial 99 finished with value: 0.7481398236288315 and parameters: {'lambda_l1': 8.89715303937807e-05, 'lambda_l2': 1.6502600296510473e-05, 'num_leaves': 2, 'feature_fraction': 0.44895761897624503, 'min_child_samples': 8, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:16,570] Trial 100 finished with value: 0.7473974009121779 and parameters: {'lambda_l1': 5.888603452575097e-06, 'lambda_l2': 7.407369269951435e-05, 'num_leaves': 37, 'feature_fraction': 0.5399853362144587, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:18,364] Trial 101 finished with value: 0.7380976646157762 and parameters: {'lambda_l1': 1.5694668151281734e-05, 'lambda_l2': 3.147339765538878e-06, 'num_leaves': 8, 'feature_fraction': 0.47743020897381167, 'min_child_samples': 17, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:21,255] Trial 102 finished with value: 0.7386727904372168 and parameters: {'lambda_l1': 0.0006499233738040025, 'lambda_l2': 1.8081192561201927e-05, 'num_leaves': 13, 'feature_fraction': 0.4230487310869745, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:24,752] Trial 103 finished with value: 0.7398976404834384 and parameters: {'lambda_l1': 1.8213298230291655e-07, 'lambda_l2': 0.0002123650904777377, 'num_leaves': 22, 'feature_fraction': 0.46033094061076585, 'min_child_samples': 14, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:26,069] Trial 104 finished with value: 0.7376311707721271 and parameters: {'lambda_l1': 2.6977105482383205e-06, 'lambda_l2': 0.0001295109497371688, 'num_leaves': 7, 'feature_fraction': 0.5051475909491618, 'min_child_samples': 10, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:29,164] Trial 105 finished with value: 0.739781270697794 and parameters: {'lambda_l1': 2.5798165613226866e-06, 'lambda_l2': 0.0017236900914358638, 'num_leaves': 17, 'feature_fraction': 0.5032123418333839, 'min_child_samples': 10, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:31,511] Trial 106 finished with value: 0.7380659655871786 and parameters: {'lambda_l1': 3.0420299624729694e-05, 'lambda_l2': 0.0005883602734121843, 'num_leaves': 7, 'feature_fraction': 0.4021507704964867, 'min_child_samples': 7, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:36,875] Trial 107 finished with value: 0.7398183669570108 and parameters: {'lambda_l1': 7.391700800059307e-06, 'lambda_l2': 0.00015111355783667418, 'num_leaves': 30, 'feature_fraction': 0.5258848723005265, 'min_child_samples': 21, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:48,613] Trial 108 finished with value: 0.7681284022945798 and parameters: {'lambda_l1': 6.324828692173482e-07, 'lambda_l2': 4.8351610962595184e-05, 'num_leaves': 165, 'feature_fraction': 0.5667211614126422, 'min_child_samples': 5, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:30:49,589] Trial 109 finished with value: 0.7370668572523066 and parameters: {'lambda_l1': 3.3009925988516657e-07, 'lambda_l2': 7.306435971332706e-06, 'num_leaves': 11, 'feature_fraction': 0.4351060973678864, 'min_child_samples': 26, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:05,614] Trial 110 finished with value: 0.7613289761242834 and parameters: {'lambda_l1': 2.7746676546256816e-07, 'lambda_l2': 7.247332211266888e-06, 'num_leaves': 139, 'feature_fraction': 0.43234943434504264, 'min_child_samples': 25, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:07,433] Trial 111 finished with value: 0.7392507386497488 and parameters: {'lambda_l1': 4.621735912056588e-07, 'lambda_l2': 8.04467421769318e-05, 'num_leaves': 13, 'feature_fraction': 0.4677949696648121, 'min_child_samples': 17, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:08,086] Trial 112 finished with value: 0.7375355974966313 and parameters: {'lambda_l1': 1.1942380889137381e-05, 'lambda_l2': 2.8518515451916383e-05, 'num_leaves': 21, 'feature_fraction': 0.4454196070850037, 'min_child_samples': 33, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:08,603] Trial 113 finished with value: 0.7386389327793904 and parameters: {'lambda_l1': 1.0669528599470429e-06, 'lambda_l2': 3.0700022679985054e-06, 'num_leaves': 22, 'feature_fraction': 0.4426084179899293, 'min_child_samples': 33, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:11,340] Trial 114 finished with value: 0.7378248792803047 and parameters: {'lambda_l1': 6.026874177323062e-08, 'lambda_l2': 0.0004400474523206088, 'num_leaves': 6, 'feature_fraction': 0.45786339037757223, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:12,562] Trial 115 finished with value: 0.7386059044118586 and parameters: {'lambda_l1': 6.326399315253775e-07, 'lambda_l2': 1.1945878322830436e-05, 'num_leaves': 16, 'feature_fraction': 0.5052995024929982, 'min_child_samples': 27, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:13,130] Trial 116 finished with value: 0.7634972034915545 and parameters: {'lambda_l1': 2.999719074736243e-06, 'lambda_l2': 0.00026587404869254027, 'num_leaves': 2, 'feature_fraction': 0.4147089114874933, 'min_child_samples': 11, 'boosting_type': 'goss'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:20,772] Trial 117 finished with value: 0.7400996408642813 and parameters: {'lambda_l1': 6.269695002593087e-05, 'lambda_l2': 0.0001156647632016323, 'num_leaves': 24, 'feature_fraction': 0.4716021842586844, 'min_child_samples': 7, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:26,720] Trial 118 finished with value: 0.7423583792369153 and parameters: {'lambda_l1': 3.5232205518317803e-07, 'lambda_l2': 0.001066859887782709, 'num_leaves': 34, 'feature_fraction': 0.44017063690886604, 'min_child_samples': 23, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:27,804] Trial 119 finished with value: 0.7377876394368469 and parameters: {'lambda_l1': 4.381918445303985e-06, 'lambda_l2': 3.749835986265041e-05, 'num_leaves': 12, 'feature_fraction': 0.4895737400799689, 'min_child_samples': 9, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:31,449] Trial 120 finished with value: 0.738268872326522 and parameters: {'lambda_l1': 1.231506397352879e-07, 'lambda_l2': 6.7585994055741725e-06, 'num_leaves': 18, 'feature_fraction': 0.5213390760857073, 'min_child_samples': 18, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:31,940] Trial 121 finished with value: 0.7376507520486049 and parameters: {'lambda_l1': 6.650143470722814e-06, 'lambda_l2': 2.2330207603223293e-05, 'num_leaves': 11, 'feature_fraction': 0.4892297076855799, 'min_child_samples': 9, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:32,853] Trial 122 finished with value: 0.7368601213552298 and parameters: {'lambda_l1': 1.7651033342781797e-05, 'lambda_l2': 7.572178556586445, 'num_leaves': 6, 'feature_fraction': 0.5368968287766974, 'min_child_samples': 11, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:33,596] Trial 123 finished with value: 0.7352331025477247 and parameters: {'lambda_l1': 1.0259601020196799e-06, 'lambda_l2': 1.48850612147043e-06, 'num_leaves': 7, 'feature_fraction': 0.535625482890582, 'min_child_samples': 12, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:37,072] Trial 124 finished with value: 0.738438041119462 and parameters: {'lambda_l1': 2.7636245187275857e-07, 'lambda_l2': 9.822799747823513e-08, 'num_leaves': 22, 'feature_fraction': 0.6015911229174785, 'min_child_samples': 15, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:37,951] Trial 125 finished with value: 0.737096281562857 and parameters: {'lambda_l1': 8.857312195421999e-07, 'lambda_l2': 1.379856418043852e-06, 'num_leaves': 5, 'feature_fraction': 0.5456047786509161, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:38,155] Trial 126 finished with value: 0.7472437156480181 and parameters: {'lambda_l1': 0.0009150012848614731, 'lambda_l2': 3.1150039918771936e-07, 'num_leaves': 2, 'feature_fraction': 0.5430342556710568, 'min_child_samples': 14, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:38,627] Trial 127 finished with value: 0.7363495958850786 and parameters: {'lambda_l1': 1.0187900476326028e-06, 'lambda_l2': 7.116034017639117, 'num_leaves': 6, 'feature_fraction': 0.6264595076418135, 'min_child_samples': 12, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:39,334] Trial 128 finished with value: 0.735664613846391 and parameters: {'lambda_l1': 9.162613642785428e-07, 'lambda_l2': 3.4817881052382815, 'num_leaves': 8, 'feature_fraction': 0.637611671261739, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:42,572] Trial 129 finished with value: 0.7359315234507469 and parameters: {'lambda_l1': 0.0001749443656073006, 'lambda_l2': 4.690718638657061, 'num_leaves': 7, 'feature_fraction': 0.6546587817028037, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:45,297] Trial 130 finished with value: 0.7473969329839545 and parameters: {'lambda_l1': 0.0002542018904969233, 'lambda_l2': 9.705408769794747, 'num_leaves': 2, 'feature_fraction': 0.6612834026286386, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:45,641] Trial 131 finished with value: 0.7355334850767348 and parameters: {'lambda_l1': 1.0897142750508255e-06, 'lambda_l2': 8.933092990019693, 'num_leaves': 7, 'feature_fraction': 0.6431841847272107, 'min_child_samples': 12, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:48,055] Trial 132 finished with value: 0.7374064822254369 and parameters: {'lambda_l1': 0.00013801679712859867, 'lambda_l2': 2.5480676499529227, 'num_leaves': 13, 'feature_fraction': 0.6774736844292899, 'min_child_samples': 20, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:50,212] Trial 133 finished with value: 0.7359874227606298 and parameters: {'lambda_l1': 0.00013981516646732875, 'lambda_l2': 2.5724052502951573, 'num_leaves': 15, 'feature_fraction': 0.6436669688656905, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:52,809] Trial 134 finished with value: 0.7391953614954809 and parameters: {'lambda_l1': 0.00018087699863983598, 'lambda_l2': 2.9522620747198856, 'num_leaves': 16, 'feature_fraction': 0.6293062713280213, 'min_child_samples': 18, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:53,375] Trial 135 finished with value: 0.7363344440665951 and parameters: {'lambda_l1': 0.0012372559777001156, 'lambda_l2': 8.540602504080532, 'num_leaves': 6, 'feature_fraction': 0.6335179911547721, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:55,402] Trial 136 finished with value: 0.7363166422531117 and parameters: {'lambda_l1': 0.0010779121373976454, 'lambda_l2': 9.775128986192719, 'num_leaves': 5, 'feature_fraction': 0.6331992244365137, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:31:57,344] Trial 137 finished with value: 0.7384951802584572 and parameters: {'lambda_l1': 0.004855570938148291, 'lambda_l2': 7.7710541071543675, 'num_leaves': 25, 'feature_fraction': 0.6355880404347058, 'min_child_samples': 7, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:08,407] Trial 138 finished with value: 0.7373799755263912 and parameters: {'lambda_l1': 0.0009825923047606744, 'lambda_l2': 4.609104699173764, 'num_leaves': 17, 'feature_fraction': 0.6452902673729025, 'min_child_samples': 11, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:10,832] Trial 139 finished with value: 0.7487590523989972 and parameters: {'lambda_l1': 0.0014014503181759331, 'lambda_l2': 0.9031549613769044, 'num_leaves': 6, 'feature_fraction': 0.6682713718634212, 'min_child_samples': 14, 'boosting_type': 'goss'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:16,038] Trial 140 finished with value: 0.741506737875728 and parameters: {'lambda_l1': 0.00039494442209617013, 'lambda_l2': 1.5579163130075655, 'num_leaves': 29, 'feature_fraction': 0.6119094686722449, 'min_child_samples': 7, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:20,130] Trial 141 finished with value: 0.7363999210478521 and parameters: {'lambda_l1': 8.030221469660887e-05, 'lambda_l2': 5.580797367543021, 'num_leaves': 6, 'feature_fraction': 0.6212577898971436, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:20,894] Trial 142 finished with value: 0.74723176744339 and parameters: {'lambda_l1': 8.94731142924166e-05, 'lambda_l2': 4.838224272419241, 'num_leaves': 2, 'feature_fraction': 0.6948931527065113, 'min_child_samples': 13, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:23,274] Trial 143 finished with value: 0.7362770349162422 and parameters: {'lambda_l1': 0.0018653901492192175, 'lambda_l2': 6.483827976044953, 'num_leaves': 11, 'feature_fraction': 0.6208757381440851, 'min_child_samples': 17, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:24,528] Trial 144 finished with value: 0.7367083525151196 and parameters: {'lambda_l1': 0.0013171944953432478, 'lambda_l2': 3.247841460737912, 'num_leaves': 8, 'feature_fraction': 0.628559819573602, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:29,089] Trial 145 finished with value: 0.737601334927397 and parameters: {'lambda_l1': 0.0022747649877186897, 'lambda_l2': 2.9871211212271906, 'num_leaves': 15, 'feature_fraction': 0.6238956900501386, 'min_child_samples': 17, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:31,146] Trial 146 finished with value: 0.7362428495717335 and parameters: {'lambda_l1': 0.00517520455804085, 'lambda_l2': 6.325960720295553, 'num_leaves': 13, 'feature_fraction': 0.6472052723308664, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:32,557] Trial 147 finished with value: 0.7386289156074369 and parameters: {'lambda_l1': 0.007281402826229355, 'lambda_l2': 2.049628666972448, 'num_leaves': 13, 'feature_fraction': 0.6446379224827254, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:34,297] Trial 148 finished with value: 0.7409315051764729 and parameters: {'lambda_l1': 0.023388120703453395, 'lambda_l2': 0.5282618238280964, 'num_leaves': 26, 'feature_fraction': 0.6166291964113968, 'min_child_samples': 21, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:39,449] Trial 149 finished with value: 0.7374464436615166 and parameters: {'lambda_l1': 0.003389639124922216, 'lambda_l2': 4.171847287535227, 'num_leaves': 18, 'feature_fraction': 0.592186445906931, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:41,313] Trial 150 finished with value: 0.7382627638596327 and parameters: {'lambda_l1': 0.0016983534450767382, 'lambda_l2': 6.378982946375872, 'num_leaves': 10, 'feature_fraction': 0.6384222716275915, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 63 with value: 0.7350693442077924.
# [I 2022-11-13 17:32:42,430] Trial 151 finished with value: 0.7347139306426141 and parameters: {'lambda_l1': 0.000779575990508888, 'lambda_l2': 7.86405872026885, 'num_leaves': 7, 'feature_fraction': 0.6578180373320605, 'min_child_samples': 12, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:42,776] Trial 152 finished with value: 0.7472019860355212 and parameters: {'lambda_l1': 0.000881319616031417, 'lambda_l2': 4.097760522299763, 'num_leaves': 2, 'feature_fraction': 0.6554252854815222, 'min_child_samples': 15, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:44,329] Trial 153 finished with value: 0.7364021823598081 and parameters: {'lambda_l1': 0.0005650021274333421, 'lambda_l2': 9.827110715949244, 'num_leaves': 8, 'feature_fraction': 0.6729733561950887, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:46,735] Trial 154 finished with value: 0.7356940135500505 and parameters: {'lambda_l1': 0.00027474679066446855, 'lambda_l2': 9.643501495181926, 'num_leaves': 12, 'feature_fraction': 0.673855898646615, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:48,348] Trial 155 finished with value: 0.7365865025008256 and parameters: {'lambda_l1': 0.00023964556692191442, 'lambda_l2': 9.632882938621277, 'num_leaves': 18, 'feature_fraction': 0.6830769459342879, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:52,158] Trial 156 finished with value: 0.7361991862569413 and parameters: {'lambda_l1': 0.000327967288248198, 'lambda_l2': 9.606881883191619, 'num_leaves': 18, 'feature_fraction': 0.7068659550004189, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:56,757] Trial 157 finished with value: 0.737860078147261 and parameters: {'lambda_l1': 0.00045928011278535674, 'lambda_l2': 6.182006008210886, 'num_leaves': 14, 'feature_fraction': 0.6701067744921769, 'min_child_samples': 23, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:32:58,841] Trial 158 finished with value: 0.7404028422020928 and parameters: {'lambda_l1': 0.000547893851469793, 'lambda_l2': 1.8428618937493269, 'num_leaves': 23, 'feature_fraction': 0.6986846972400383, 'min_child_samples': 21, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:12,228] Trial 159 finished with value: 0.758983416614276 and parameters: {'lambda_l1': 0.006115442972067834, 'lambda_l2': 1.1259134219340736, 'num_leaves': 120, 'feature_fraction': 0.7206000599798389, 'min_child_samples': 18, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:15,592] Trial 160 finished with value: 0.7381000670851989 and parameters: {'lambda_l1': 0.0007172349568830125, 'lambda_l2': 5.73367398920945, 'num_leaves': 14, 'feature_fraction': 0.7100818232009921, 'min_child_samples': 24, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:22,494] Trial 161 finished with value: 0.7389689067432531 and parameters: {'lambda_l1': 0.0002850108694744029, 'lambda_l2': 9.8995496663506, 'num_leaves': 20, 'feature_fraction': 0.6880077994502701, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:24,629] Trial 162 finished with value: 0.7380811225229316 and parameters: {'lambda_l1': 0.00019987159196982652, 'lambda_l2': 8.537563293984515, 'num_leaves': 18, 'feature_fraction': 0.6546767145339413, 'min_child_samples': 20, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:25,902] Trial 163 finished with value: 0.7471511618902481 and parameters: {'lambda_l1': 0.0003325960580532382, 'lambda_l2': 4.035057268968947, 'num_leaves': 2, 'feature_fraction': 0.6693771665602888, 'min_child_samples': 14, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:26,648] Trial 164 finished with value: 0.7373714456615202 and parameters: {'lambda_l1': 0.002294338062722636, 'lambda_l2': 6.165915466794833, 'num_leaves': 11, 'feature_fraction': 0.676432318021402, 'min_child_samples': 18, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:28,161] Trial 165 finished with value: 0.7361961703090953 and parameters: {'lambda_l1': 0.00438812005602742, 'lambda_l2': 9.946518378682649, 'num_leaves': 7, 'feature_fraction': 0.6875038387320316, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:29,377] Trial 166 finished with value: 0.736008622234905 and parameters: {'lambda_l1': 0.012406851988282673, 'lambda_l2': 3.0923900823424746, 'num_leaves': 6, 'feature_fraction': 0.6450566286292425, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:35,688] Trial 167 finished with value: 0.7366103846634753 and parameters: {'lambda_l1': 0.00365782833783662, 'lambda_l2': 2.2446503149029704, 'num_leaves': 6, 'feature_fraction': 0.6440795294977929, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:46,406] Trial 168 finished with value: 0.7972077134357838 and parameters: {'lambda_l1': 0.0104917340473596, 'lambda_l2': 3.338040562730135, 'num_leaves': 228, 'feature_fraction': 0.6579272777512004, 'min_child_samples': 12, 'boosting_type': 'goss'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:54,278] Trial 169 finished with value: 0.7366224233887267 and parameters: {'lambda_l1': 0.012845394792855269, 'lambda_l2': 0.5828576837579938, 'num_leaves': 13, 'feature_fraction': 0.6158650009651314, 'min_child_samples': 16, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:57,930] Trial 170 finished with value: 0.7354116486292637 and parameters: {'lambda_l1': 0.052002714938334235, 'lambda_l2': 5.880340114993035, 'num_leaves': 6, 'feature_fraction': 0.6258706584285417, 'min_child_samples': 23, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:58,890] Trial 171 finished with value: 0.7473390282492066 and parameters: {'lambda_l1': 0.0013758052799865389, 'lambda_l2': 5.297443980397368, 'num_leaves': 2, 'feature_fraction': 0.5971592007041279, 'min_child_samples': 24, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:33:59,206] Trial 172 finished with value: 0.736025872221389 and parameters: {'lambda_l1': 0.04066001913453693, 'lambda_l2': 5.608643986048743, 'num_leaves': 6, 'feature_fraction': 0.621310843790835, 'min_child_samples': 26, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:01,698] Trial 173 finished with value: 0.7359066411434748 and parameters: {'lambda_l1': 0.08116009391502552, 'lambda_l2': 2.491552228423779, 'num_leaves': 11, 'feature_fraction': 0.6412659916611333, 'min_child_samples': 26, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:06,145] Trial 174 finished with value: 0.7361510777970625 and parameters: {'lambda_l1': 0.10519294310819843, 'lambda_l2': 1.941576891359759, 'num_leaves': 12, 'feature_fraction': 0.6370272732230137, 'min_child_samples': 26, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:08,396] Trial 175 finished with value: 0.7483217909653562 and parameters: {'lambda_l1': 0.038288559452925704, 'lambda_l2': 1.311815669376498, 'num_leaves': 15, 'feature_fraction': 0.6515790603875046, 'min_child_samples': 26, 'boosting_type': 'dart'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:10,997] Trial 176 finished with value: 0.7388205389694426 and parameters: {'lambda_l1': 0.07506686664292744, 'lambda_l2': 2.2753382867672953, 'num_leaves': 20, 'feature_fraction': 0.6049520895814039, 'min_child_samples': 25, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:19,136] Trial 177 finished with value: 0.7389266034188923 and parameters: {'lambda_l1': 0.197713451562396, 'lambda_l2': 0.7730090992382533, 'num_leaves': 26, 'feature_fraction': 0.6628389190763991, 'min_child_samples': 23, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:21,545] Trial 178 finished with value: 0.736204428592871 and parameters: {'lambda_l1': 0.06806284539308789, 'lambda_l2': 0.2669602715584888, 'num_leaves': 11, 'feature_fraction': 0.7373870353364653, 'min_child_samples': 27, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# [I 2022-11-13 17:34:38,592] Trial 179 finished with value: 0.7710774369970032 and parameters: {'lambda_l1': 0.13852723536580894, 'lambda_l2': 0.3280844546586377, 'num_leaves': 181, 'feature_fraction': 0.7337612008197474, 'min_child_samples': 28, 'boosting_type': 'gbdt'}. Best is trial 151 with value: 0.7347139306426141.
# Number of finished trials: 180
# Best trial (151):
# Value: 0.7347139306426141
# Params:
# {'lambda_l1': 0.000779575990508888, 'lambda_l2': 7.86405872026885, 'num_leaves': 7, 'feature_fraction': 0.6578180373320605, 'min_child_samples': 12, 'boosting_type': 'gbdt'}

# %%
# Catboost validation prediction
y_pred_val_cb = np.expm1(cbm.predict(X_val_cb))
print('Catboost validation score:', rmsle(np.expm1(y_val), y_pred_val_cb))

# LightGBM validation prediction
y_val_pred_lgb = np.expm1(lgbm.predict(X_val_lgb))
print('LightGBM validation score:', rmsle(np.expm1(y_val), y_val_pred_lgb))
# Out:
# Catboost validation score: 0.7254412175205048
# LightGBM validation score: 0.7347139306426141

# %% [markdown]
# # 6. Stacking

# %%
y_pred_test_cb = np.expm1(cbm.predict(X_test_cb))
y_pred_test_lgb = np.expm1(lgbm.predict(X_test_lgb))

test_stack = np.array([y_pred_test_cb, y_pred_test_lgb])
stack_test_avg = np.mean(test_stack, axis=0)

submission = pd.read_csv('data/sample_submission.csv')
submission['predicted'] = stack_test_avg
submission.to_csv('submissions/cb_lgb_lordag_natt_clean.csv', index=False)
