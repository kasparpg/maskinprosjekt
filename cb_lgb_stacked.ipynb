# %% [markdown]
# # 1. Initial setup

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.1 Install required packages
#
# We ran into some issues with some of the geo related packages, such as geopandas, on certain machines. If the code does not run on your machine, you can comment out the lines commented with "# GEO PROBLEM HERE", and it will hopefully allow the code to run. This may of course impact the final score.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: attrs==22.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: autopep8==2.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: backcall==0.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: catboost==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: certifi==2022.9.24 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2022.9.24)
# Requirement already satisfied: click==8.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (8.1.3)
# Requirement already satisfied: click-plugins==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: cligj==0.7.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: colorama==0.4.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: contourpy==1.0.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (0.11.0)
# Requirement already satisfied: Cython==0.29.28 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.29.28)
# Requirement already satisfied: debugpy==1.6.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.4)
# Requirement already satisfied: executing==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: Fiona==1.8.22 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.8.22)
# Requirement already satisfied: fonttools==4.38.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (4.38.0)
# Requirement already satisfied: gensim==4.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (4.2.0)
# Requirement already satisfied: geographiclib==1.52 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (1.52)
# Requirement already satisfied: geopandas==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: geopy==2.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (2.2.0)
# Requirement already satisfied: graphviz==0.20.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (0.20.1)
# Requirement already satisfied: ipykernel==6.17.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (6.17.0)
# Requirement already satisfied: ipython==8.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (8.6.0)
# Requirement already satisfied: jedi==0.18.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (0.18.1)
# Requirement already satisfied: joblib==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: jupyter_client==7.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (7.4.4)
# Requirement already satisfied: jupyter_core==4.11.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (4.11.2)
# Requirement already satisfied: kiwisolver==1.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (1.4.4)
# Requirement already satisfied: matplotlib==3.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (3.6.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (0.1.6)
# Requirement already satisfied: munch==2.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (2.5.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (1.5.6)
# Requirement already satisfied: numpy==1.23.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (1.23.4)
# Requirement already satisfied: packaging==21.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (21.3)
# Requirement already satisfied: pandas==1.5.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (1.5.1)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (0.7.5)
# Requirement already satisfied: Pillow==9.3.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (9.3.0)
# Requirement already satisfied: plotly==5.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (5.11.0)
# Requirement already satisfied: prompt-toolkit==3.0.31 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (3.0.31)
# Requirement already satisfied: psutil==5.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (5.9.3)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (0.2.2)
# Requirement already satisfied: pyarrow==10.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (10.0.0)
# Requirement already satisfied: pycodestyle==2.9.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.9.1)
# Requirement already satisfied: pygeos==0.13 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.13)
# Requirement already satisfied: Pygments==2.13.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (2.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (3.0.9)
# Requirement already satisfied: pyproj==3.4.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (3.4.0)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2.8.2)
# Requirement already satisfied: pytz==2022.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (2022.6)
# Requirement already satisfied: pyzmq==24.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (24.0.1)
# Requirement already satisfied: scikit-learn==1.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (1.1.3)
# Requirement already satisfied: scipy==1.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (0.12.1)
# Requirement already satisfied: Shapely==1.8.5.post1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (1.8.5.post1)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (1.16.0)
# Requirement already satisfied: sklearn==0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (0.0)
# Requirement already satisfied: smart-open==6.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.2.0)
# Requirement already satisfied: stack-data==0.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (0.6.0)
# Requirement already satisfied: tenacity==8.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (8.1.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (3.1.0)
# Requirement already satisfied: tomli==2.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (2.0.1)
# Requirement already satisfied: tornado==6.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (6.2)
# Requirement already satisfied: tqdm==4.64.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (4.64.1)
# Requirement already satisfied: traitlets==5.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (5.5.0)
# Requirement already satisfied: wcwidth==0.2.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 69)) (0.2.5)
# Requirement already satisfied: xgboost==1.7.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (1.7.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from Fiona==1.8.22->-r requirements.txt (line 18)) (44.0.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./venv/lib/python3.8/site-packages (from ipython==8.6.0->-r requirements.txt (line 26)) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython==8.6.0->-r requirements.txt (line 26)) (0.7.0)

# %% [markdown]
# ## 1.2 Import packages and data

# %%
# %autoreload

import warnings
import os.path
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import geopy
import os
import shutil
import geopandas as gpd
import catboost as cb
import optuna
import lightgbm as lgb
import geopandas as gpd

from pyproj import Geod
from shapely import wkt
from shapely.geometry import Point, LineString
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_log_error
from typing import Callable, Dict, List, Tuple
from catboost.utils import get_gpu_device_count
from tqdm import tqdm

tqdm.pandas()

warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None  # default='warn'

SEED = 23

spatial = pd.read_csv('data/grunnkrets_norway_stripped.csv')
age = pd.read_csv('data/grunnkrets_age_distribution.csv')
income = pd.read_csv('data/grunnkrets_income_households.csv').set_index(['grunnkrets_id', 'year']).add_prefix('income_').reset_index()
households = pd.read_csv('data/grunnkrets_households_num_persons.csv')
submission = pd.read_csv('data/sample_submission.csv')
plaace = pd.read_csv('data/plaace_hierarchy.csv')
busstops = pd.read_csv('data/busstops_norway.csv')

train = pd.read_csv('data/stores_train.csv')
train_extra = pd.read_csv('data/stores_extra.csv')
test = pd.read_csv('data/stores_test.csv') 

submission = pd.read_csv('data/sample_submission.csv')  # Please do not delete this file

# %% [markdown]
# Create geopandas version of some of the datasets:

# %%
busstops_geo = gpd.GeoDataFrame(busstops, geometry=busstops.geometry.apply(wkt.loads))

train_geo = gpd.GeoDataFrame(train[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train.lon, train.lat)).drop(columns=['lon', 'lat'])
train_geo = train_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

train_geo_extra = gpd.GeoDataFrame(train_extra[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train_extra.lon, train_extra.lat)).drop(columns=['lon', 'lat'])
train_geo_extra = train_geo_extra.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

test_geo = gpd.GeoDataFrame(test[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(test.lon, test.lat)).drop(columns=['lon', 'lat'])
test_geo = test_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

# %% [markdown]
# ## 2.2 Helper functions

# %%
def rmsle(y_true, y_pred):
    y_pred[y_pred < 0] = 0 + 1e-6
    y_true[y_true < 0] = 0 + 1e-6
    return np.sqrt(mean_squared_log_error(y_true, y_pred))


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def to_categorical(df: pd.DataFrame):
    for cat_col in df.select_dtypes(include=[object]).columns:
        df[cat_col] = df[cat_col].astype('category')
    return df


def object_encoder(df: pd.DataFrame):
    enc = OrdinalEncoder()
    obj_cols = df.select_dtypes(include=[object]).columns
    df[obj_cols] = enc.fit_transform(df[obj_cols])
    return df


def nan_to_string(df: pd.DataFrame):
    nan = '#N/A'
    cols = df[df.columns[df.isna().any()]].columns
    df[cols] = df[cols].fillna(nan)
    return df


def meter_distance(lat1, lon1, lat2, lon2):
    line_string = LineString([Point(lon1, lat1), Point(lon2, lat2)])
    geod = Geod(ellps="WGS84")
    return geod.geometry_length(line_string)


def add_city_centre_dist(X: pd.DataFrame):
    old_shape = X.shape

    city_centres = X.groupby(['municipality_name'])[['lat', 'lon']].apply(lambda x: x.sum() / (x.count()))[['lat', 'lon']]
    X = X.merge(city_centres, on=['municipality_name'], how='left', suffixes=(None, '_center'))
    assert X.shape[0] == old_shape[0]

    X.fillna(value={'lat_center': X.lat, 'lon_center': X.lon}, inplace=True)

    X['dist_to_center'] = X.apply(lambda row: meter_distance(row.lat, row.lon, row.lat_center, row.lon_center), axis=1)
    assert X.shape[0] == old_shape[0]

    return X


def group_ages(age: pd.DataFrame, age_ranges: List[Tuple[int, int]]):
    age_new = age[['grunnkrets_id', 'year']].drop_duplicates(subset=['grunnkrets_id'], keep='last')

    for rng in age_ranges:
        cols = [f'age_{age}' for age in range(rng[0], rng[1] + 1)]
        rng_sum = age[cols].sum(axis=1).astype(int)
        age_new[f'age_{rng[0]}_{rng[-1]}'] = rng_sum

    age = age.drop_duplicates(subset='grunnkrets_id').drop(columns=['year', *(f'age_{age}' for age in range(0, 91))], axis=1)
    age = age.merge(age_new.drop(columns=['year']), on='grunnkrets_id')

    return age


def only_latest_data(df: pd.DataFrame):
    df = df.sort_values(by='year', ascending=False)
    df = df.drop_duplicates(subset='grunnkrets_id', keep='first')
    return df


def clean_out_nan_heavy_rows(df: pd.DataFrame, age, age_ranges, spatial_2016, income_2016, households_2016):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_2016.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df2[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna()) # df2.age_0_19.isna() | 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


def create_busstops_files():
    """
    Creates a .parquet file that stores info aboute the number of busstops within a 1 kilometer
    radius of a given store, as well as the number of stops within the different importance categories.  
    """

    def bus_fields(row: pd.Series):
        output_dict = {}
        gpd.options.use_pygeos = True
        
        stops_with_dist = busstops[busstops_geo.distance(row.geometry) < 1000]
        output_dict['bus_stops_count'] = len(stops_with_dist)
        
        output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
            busstops_geo.importance_level.unique(), fill_value=0
        ).to_dict())
        
        return output_dict

    train_with_extras_bus = pd.concat([train_geo, train_geo_extra], ignore_index=True)

    train_with_extras_bus = train_with_extras_bus.join(train_with_extras_bus.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    train_with_extras_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_train.parquet')

    test_bus = test_bus.join(test_bus.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    test_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_test.parquet')


def create_stores_in_vicinity_files():
    """
    Creates a .parquet file that stores info aboute the number of other stores within a 1 kilometer
    radius of a given store.
    """

    train_with_extras = pd.concat([train_geo, train_geo_extra], ignore_index=True)[['store_id', 'geometry']]

    def store_count_in_vicinity(row: pd.Series):
        stores_in_vicinity = train_with_extras[train_with_extras.distance(row.geometry) < 1000]
        return {'stores_count_lt_1km': len(stores_in_vicinity)}

    train_with_extras = train_with_extras.join(train_with_extras.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    train_with_extras.to_parquet('derived_data/stores_count_lt_1km_train.parquet')

    test = test.join(test.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    test.to_parquet('derived_data/stores_count_lt_1km_test.parquet')

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# The train and test data only contains data from 2016, so for the other datasets with an age column
# we only use the values from 2016, where possible.

# %%
age_ranges = [
    (0, 19),
    (20, 39),
    (40, 59),
    (60, 79),
    (80, 90),
]

spatial_latest = only_latest_data(spatial)
income_latest = only_latest_data(income)
households_latest = only_latest_data(households)

train_spatial = train.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
muni_avg_revenue = train_spatial.groupby(by='municipality_name', as_index=False)['revenue'].mean()

# %% [markdown]
# Futhermore, we noticed that a number of rows in the train and test datasets didn't have

# %%
def clean(df: pd.DataFrame, min_val=0, max_val=100):
    print('Length of data frame:', len(df))
    df = df[(df.revenue > min_val) & (df.revenue < max_val)]
    print('Length after removing extreme values and zero revenue retail stores:',  len(df))
    return df.drop(columns=['revenue']), df.revenue


def clean_out_nan_heavy_rows(df: pd.DataFrame):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_latest.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna())  # | df2.age_0_19.isna() 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


train = clean_out_nan_heavy_rows(train)
label_name = 'revenue'
X = train.drop(columns=[label_name])
y = train[label_name]

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=.8, random_state=SEED)
X_train, y_train = clean(pd.merge(X_train, y_train, left_index=True, right_index=True))

y_train = np.log1p(y_train)
y_val = np.log1p(y_val)
# Out:
# Cleaned out 127 out of 12859 rows.
# Length of data frame: 10185
# Length after removing extreme values and zero revenue retail stores: 9947

# %% [markdown]
# # 3. Feature generation

# %% [markdown]
# Create files for busstops and stores in vicinity of each store:

# %%
# !mkdir -p derived_data

create_busstops_files()
create_stores_in_vicinity_files()
# Out:
#   0%|          | 1/41416 [00:00<10:38, 64.84it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [59], line 3
#       1 get_ipython().system('mkdir -p derived_data')
# ----> 3 create_busstops_files()
#       4 create_stores_in_vicinity_files()
#
# Cell In [56], line 108, in create_busstops_files()
#     104     return output_dict
#     106 train_geo_with_extras = pd.concat([train, train_extra], ignore_index=True)
# --> 108 train_geo_with_extras = train_geo_with_extras.join(train_geo_with_extras.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
#     109 train_geo_with_extras.to_parquet('derived_data/stores_bus_stops_lt_1km_train.parquet')
#     111 test = test.join(test.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/frame.py:9555, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9544 from pandas.core.apply import frame_apply
#    9546 op = frame_apply(
#    9547     self,
#    9548     func=func,
#    (...)
#    9553     kwargs=kwargs,
#    9554 )
# -> 9555 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/apply.py:889, in FrameApply.apply_series_generator(self)
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# Cell In [56], line 108, in create_busstops_files.<locals>.<lambda>(row)
#     104     return output_dict
#     106 train_geo_with_extras = pd.concat([train, train_extra], ignore_index=True)
# --> 108 train_geo_with_extras = train_geo_with_extras.join(train_geo_with_extras.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
#     109 train_geo_with_extras.to_parquet('derived_data/stores_bus_stops_lt_1km_train.parquet')
#     111 test = test.join(test.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
#
# Cell In [56], line 97, in create_busstops_files.<locals>.bus_fields(row)
#      94 output_dict = {}
#      95 gpd.options.use_pygeos = True
# ---> 97 stops_with_dist = busstops[busstops_geo.distance(row.geometry) < 1000]
#      98 output_dict['bus_stops_count'] = len(stops_with_dist)
#     100 output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
#     101     busstops_geo.importance_level.unique(), fill_value=0
#     102 ).to_dict())
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'geometry'

# %%
def generate_features(df: pd.DataFrame, data_origin: str, predictor: str = ''):
    # Define datasets to be merged
    age_groups_merge = group_ages(age, age_ranges)
    spatial_merge = spatial_latest.drop(columns=['year'])
    income_merge = income_latest.drop(columns=['year'])
    households_merge = households_latest.drop(columns=['year'])
    plaace_merge = plaace.drop_duplicates(subset='plaace_hierarchy_id')
    bus_data_train_merge = gpd.read_parquet(f'derived_data/stores_bus_stops_lt_1km_{data_origin}_with_extras.parquet').drop(columns=['geometry'])
    stores_vicinity_merge = gpd.read_parquet(f'derived_data/stores_count_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])

    # Merge datasets
    df = df.merge(age_groups_merge, on='grunnkrets_id', how='left')
    df = df.merge(spatial_merge, on='grunnkrets_id', how='left')
    df = df.merge(income_merge, on='grunnkrets_id', how='left')
    df = df.merge(households_merge, on='grunnkrets_id', how='left')
    df = df.merge(plaace_merge, how='left')
    df = df.merge(bus_data_train_merge, on='store_id', how='left')
    df = df.merge(stores_vicinity_merge, on='store_id', how='left')
    df = add_city_centre_dist(df).drop(columns=['lon_center', 'lat_center'])

    # Transformations and some post-merge cleaning
    df.stores_count_lt_1km = np.log(df.stores_count_lt_1km)
    df[age_groups_merge.columns] = df[age_groups_merge.columns].fillna(0)
    
    # Handle categories for different predictors
    if predictor == 'xgb':
        df = object_encoder(df)
    elif predictor == 'cb':
        df = nan_to_string(df)
    elif predictor == 'lgb':
        df = to_categorical(df)
    else: 
        raise ValueError('Invalid predictor')

    features = [
        'store_name', 
        'mall_name', 
        'chain_name',
        'address', 
        'lat', 'lon',
        
        *age_groups_merge.drop(columns=['grunnkrets_id']).columns,
        *income_merge.drop(columns=['grunnkrets_id']).columns,
        *households_merge.drop(columns=['grunnkrets_id']).columns,
        'lv1_desc', 'lv2_desc', 'sales_channel_name', 
        *bus_data_train_merge.drop(columns=['store_id']).columns,
        *stores_vicinity_merge.drop(columns=['store_id']).columns,
        'dist_to_center'
    ]

    return df[features]

# %%
# Features adapted to Catboost
X_train_cb = generate_features(X_train, data_origin='train', predictor='cb')
X_val_cb = generate_features(X_val, data_origin='train', predictor='cb')
X_test_cb = generate_features(test, data_origin='test', predictor='cb')

# Features adapted to LightGBM
X_train_lgb = generate_features(X_train, data_origin='train', predictor='lgb')
X_val_lgb = generate_features(X_val, data_origin='train', predictor='lgb')
X_test_lgb = generate_features(test, data_origin='test', predictor='lgb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [34], line 2
#       1 # Features adapted to Catboost
# ----> 2 X_train_cb = generate_features(X_train, data_origin='train', predictor='cb')
#       3 X_val_cb = generate_features(X_val, data_origin='train', predictor='cb')
#       4 X_test_cb = generate_features(test, data_origin='test', predictor='cb')
#
# Cell In [33], line 8, in generate_features(df, data_origin, predictor)
#       6 households_merge = households_latest.drop(columns=['year'])
#       7 plaace_merge = plaace.drop_duplicates(subset='plaace_hierarchy_id')
# ----> 8 bus_data_train_merge = gpd.read_parquet(f'derived_data/stores_bus_stops_lt_1km_{data_origin}_with_extras.parquet').drop(columns=['geometry'])
#       9 stores_vicinity_merge = gpd.read_parquet(f'derived_data/stores_count_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])
#      11 # Merge datasets
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/geopandas/io/arrow.py:560, in _read_parquet(path, columns, storage_options, **kwargs)
#     558 path = _expand_user(path)
#     559 kwargs["use_pandas_metadata"] = True
# --> 560 table = parquet.read_table(path, columns=columns, filesystem=filesystem, **kwargs)
#     562 # read metadata separately to get the raw Parquet FileMetaData metadata
#     563 # (pyarrow doesn't properly exposes those in schema.metadata for files
#     564 # created by GDAL - https://issues.apache.org/jira/browse/ARROW-16688)
#     565 metadata = None
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pyarrow/parquet/core.py:2824, in read_table(source, columns, use_threads, metadata, schema, use_pandas_metadata, memory_map, read_dictionary, filesystem, filters, buffer_size, partitioning, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit)
#    2817     raise ValueError(
#    2818         "The 'metadata' keyword is no longer supported with the new "
#    2819         "datasets-based implementation. Specify "
#    2820         "'use_legacy_dataset=True' to temporarily recover the old "
#    2821         "behaviour."
#    2822     )
#    2823 try:
# -> 2824     dataset = _ParquetDatasetV2(
#    2825         source,
#    2826         schema=schema,
#    2827         filesystem=filesystem,
#    2828         partitioning=partitioning,
#    2829         memory_map=memory_map,
#    2830         read_dictionary=read_dictionary,
#    2831         buffer_size=buffer_size,
#    2832         filters=filters,
#    2833         ignore_prefixes=ignore_prefixes,
#    2834         pre_buffer=pre_buffer,
#    2835         coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    2836         thrift_string_size_limit=thrift_string_size_limit,
#    2837         thrift_container_size_limit=thrift_container_size_limit,
#    2838     )
#    2839 except ImportError:
#    2840     # fall back on ParquetFile for simple cases when pyarrow.dataset
#    2841     # module is not available
#    2842     if filters is not None:
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pyarrow/parquet/core.py:2423, in _ParquetDatasetV2.__init__(self, path_or_paths, filesystem, filters, partitioning, read_dictionary, buffer_size, memory_map, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, schema, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, **kwargs)
#    2419 if partitioning == "hive":
#    2420     partitioning = ds.HivePartitioning.discover(
#    2421         infer_dictionary=True)
# -> 2423 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    2424                            schema=schema, format=parquet_format,
#    2425                            partitioning=partitioning,
#    2426                            ignore_prefixes=ignore_prefixes)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pyarrow/dataset.py:752, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     741 kwargs = dict(
#     742     schema=schema,
#     743     filesystem=filesystem,
#    (...)
#     748     selector_ignore_prefixes=ignore_prefixes
#     749 )
#     751 if _is_path_like(source):
# --> 752     return _filesystem_dataset(source, **kwargs)
#     753 elif isinstance(source, (tuple, list)):
#     754     if all(_is_path_like(elem) for elem in source):
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pyarrow/dataset.py:444, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     442     fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     443 else:
# --> 444     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     446 options = FileSystemFactoryOptions(
#     447     partitioning=partitioning,
#     448     partition_base_dir=partition_base_dir,
#     449     exclude_invalid_files=exclude_invalid_files,
#     450     selector_ignore_prefixes=selector_ignore_prefixes
#     451 )
#     452 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File ~/Desktop/maskinprosjekt/venv/lib/python3.8/site-packages/pyarrow/dataset.py:420, in _ensure_single_source(path, filesystem)
#     418     paths_or_selector = [path]
#     419 else:
# --> 420     raise FileNotFoundError(path)
#     422 return filesystem, paths_or_selector
#
# FileNotFoundError: derived_data/stores_bus_stops_lt_1km_train_with_extras.parquet

# %% [markdown]
# # 4. Hyper parameter tuning

# %% [markdown]
# ### Preparing pools and parameter grid for Catboost

# %%
def get_cb_pools():
    text_features = ['store_name', 'address', 'sales_channel_name'] 
    cat_features = ['mall_name', 'chain_name', 'lv1_desc', 'lv2_desc']

    train_pool = cb.Pool(
        X_train_cb,
        y_train,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    valid_pool = cb.Pool(
        X_val_cb,
        y_val,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    return train_pool, valid_pool


def get_cb_params(trial: optuna.Trial = None):
    gpu_count = get_gpu_device_count()
    non_tunable_cb_params = {
        'objective': 'RMSE',
        'eval_metric': 'RMSE',
        'task_type': 'GPU' if gpu_count else 'CPU', 
        'devices': f'0:{gpu_count}',
        'random_seed': SEED
    }

    if trial is None:
        return 'cb', non_tunable_cb_params
    
    tunable_params = {
        'depth': trial.suggest_int('depth', 4, 9),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 2, 6),
        # 'iterations': trial.suggest_int('iterations', 1000, 2000),
        # 'learning_rate': trial.suggest_categorical('learning_rate', 0.1, 0.5)
    }

    return 'cb', non_tunable_cb_params, tunable_params

# %% [markdown]
# ### Preparing DMatrices and parameter grid for LightGBM

# %%
def get_lgb_dmatrices():
    dtrain = lgb.Dataset(X_train_lgb, y_train, params={'verbose': -1}, free_raw_data=False)
    dvalid = lgb.Dataset(X_val_lgb, y_val, params={'verbose': -1}, free_raw_data=False)
    return dtrain, dvalid


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def get_lgb_params(trial: optuna.Trial = None):
    non_tunable_lgb_params = {
        'objective': 'rmse',
        'verbose': -1,
        'seed': 1
    }

    if trial is None:
        return 'lgb', non_tunable_lgb_params

    tunable_params = {
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'goss', 'dart']),
    }

    if tunable_params['boosting_type'] != 'goss':
        tunable_params["bagging_fraction"]: trial.suggest_float("bagging_fraction", 0.4, 1.0)
        tunable_params["bagging_freq"]: trial.suggest_int("bagging_freq", 1, 7)

    return 'lgb', non_tunable_lgb_params, tunable_params

# %% [markdown]
# ### Hyper parameter tuning with Optuna

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def objective(trial: optuna.Trial, param_grid_fn: Callable) -> float:
    model_name, non_tunable_params, tunable_params = param_grid_fn(trial)
  
    if model_name == 'cb':
        if tunable_params['bootstrap_type'] == 'Bayesian': 
            tunable_params['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)
        elif tunable_params['bootstrap_type'] == 'Bernoulli':
            tunable_params['subsample'] = trial.suggest_float('subsample', 0.1, 1, log=True)

        cbr = cb.CatBoostRegressor(**non_tunable_params, **tunable_params) 
        train_pool, valid_pool = get_cb_pools()
        cbr.fit(
            train_pool,
            eval_set=[(X_val_cb, y_val)],
            verbose=0,
            early_stopping_rounds=100,
        )
        y_pred = cbr.predict(X_val_cb)
    
    elif model_name == 'lgb':
        dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
        lgbr = lgb.train(
            params={**non_tunable_params, **tunable_params},
            train_set=dtrain_lgb,
            valid_sets=dvalid_lgb,
            verbose_eval=False,
        )
        y_pred = lgbr.predict(X_val_lgb)

    score = rmsle(np.expm1(y_val), np.expm1(y_pred))

    return score


def get_hyper_parameters(param_grid_fn: Callable, n_trials=100):
    study = optuna.create_study(
        study_name='hyperparam-tuning',
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), 
        direction='minimize'
    )
    objective_fn = lambda trial: objective(trial, param_grid_fn)
    study.optimize(objective_fn, n_trials=n_trials, timeout=900) 

    print('Number of finished trials: {}'.format(len(study.trials)))
    
    trial = study.best_trial
    print(f'Best trial ({trial.number}):')
    print('Value:', trial.value)
    print('Params:')
    print(trial.params)

    return param_grid_fn()[1], trial.params

# %% [markdown]
# # 5. Training step

# %% [markdown]
# ### Making predictions with Catboost

# %%
non_tunable_cb_params, tuned_params = get_hyper_parameters(get_cb_params, n_trials=30)
train_pool, valid_pool = get_cb_pools()
cbm = cb.CatBoostRegressor(**non_tunable_cb_params, **tuned_params, iterations=1000) 
cbm.fit(train_pool, eval_set=valid_pool, verbose=50, plot=True, early_stopping_rounds=50)
# Out:
# [I 2022-11-12 17:26:39,189] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-12 17:26:43,989] Trial 0 finished with value: 0.7598035568551953 and parameters: {'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 4.499266869376305}. Best is trial 0 with value: 0.7598035568551953.
# [I 2022-11-12 17:26:52,235] Trial 1 finished with value: 0.743787329551192 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.1973719556948565}. Best is trial 1 with value: 0.743787329551192.
# [I 2022-11-12 17:27:00,066] Trial 2 finished with value: 0.7516743506996096 and parameters: {'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.275496919307908, 'bagging_temperature': 4.847785467502032}. Best is trial 1 with value: 0.743787329551192.
# [I 2022-11-12 17:27:13,212] Trial 3 finished with value: 0.7403624906312618 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.93493901766097}. Best is trial 3 with value: 0.7403624906312618.
# [I 2022-11-12 17:27:22,297] Trial 4 finished with value: 0.7287491051522794 and parameters: {'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.1012494126380967, 'subsample': 0.6990327154334154}. Best is trial 4 with value: 0.7287491051522794.
# [I 2022-11-12 17:27:34,178] Trial 5 finished with value: 0.7997162841435396 and parameters: {'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.175992162283142, 'bagging_temperature': 9.495434311669188}. Best is trial 4 with value: 0.7287491051522794.
# [I 2022-11-12 17:27:40,696] Trial 6 finished with value: 0.7335880026177741 and parameters: {'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.5652714866137, 'subsample': 0.25100351374132557}. Best is trial 4 with value: 0.7287491051522794.
# [I 2022-11-12 17:27:49,860] Trial 7 finished with value: 0.7287896619231765 and parameters: {'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.689690807299053, 'subsample': 0.830760793790344}. Best is trial 4 with value: 0.7287491051522794.
# [I 2022-11-12 17:27:59,024] Trial 8 finished with value: 0.766641478776604 and parameters: {'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.217632163676011, 'bagging_temperature': 7.255805776917898}. Best is trial 4 with value: 0.7287491051522794.
# [I 2022-11-12 17:28:05,389] Trial 9 finished with value: 0.7283996913786346 and parameters: {'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.1946467305664736, 'subsample': 0.6431801296987338}. Best is trial 9 with value: 0.7283996913786346.
# [I 2022-11-12 17:28:14,908] Trial 10 finished with value: 0.7384817300207763 and parameters: {'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.750218504932113, 'subsample': 0.10194398377947697}. Best is trial 9 with value: 0.7283996913786346.
# [I 2022-11-12 17:28:22,544] Trial 11 finished with value: 0.7305461526471334 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.4457765053491314, 'subsample': 0.8096441325303414}. Best is trial 9 with value: 0.7283996913786346.
# [I 2022-11-12 17:28:31,576] Trial 12 finished with value: 0.7323720477745743 and parameters: {'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.900509807688237, 'subsample': 0.46511130361983827}. Best is trial 9 with value: 0.7283996913786346.
# [I 2022-11-12 17:28:40,605] Trial 13 finished with value: 0.7322335124205929 and parameters: {'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.102646878275923, 'subsample': 0.4667788090935851}. Best is trial 9 with value: 0.7283996913786346.
# [I 2022-11-12 17:29:19,558] Trial 14 finished with value: 0.7272983407999798 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.520355015981673, 'subsample': 0.4383061075286045}. Best is trial 14 with value: 0.7272983407999798.
# [I 2022-11-12 17:29:30,832] Trial 15 finished with value: 0.7309139915861693 and parameters: {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.646135763766585, 'subsample': 0.352170270982891}. Best is trial 14 with value: 0.7272983407999798.
# [I 2022-11-12 17:29:42,545] Trial 16 finished with value: 0.7334268171666178 and parameters: {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.037839112244402, 'subsample': 0.20410436461426945}. Best is trial 14 with value: 0.7272983407999798.
# [I 2022-11-12 17:30:06,623] Trial 17 finished with value: 0.7276965162188694 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.599555567199909, 'subsample': 0.4785688380690075}. Best is trial 14 with value: 0.7272983407999798.
# [I 2022-11-12 17:30:30,617] Trial 18 finished with value: 0.7265727098928215 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.4649107291511902, 'bagging_temperature': 0.044820629825256475}. Best is trial 18 with value: 0.7265727098928215.
# [I 2022-11-12 17:31:08,724] Trial 19 finished with value: 0.7264632104984834 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.4594360470744427, 'bagging_temperature': 0.05617983752855586}. Best is trial 19 with value: 0.7264632104984834.
# [I 2022-11-12 17:31:32,272] Trial 20 finished with value: 0.7272421287459913 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.429193232126376, 'bagging_temperature': 0.29309734263004356}. Best is trial 19 with value: 0.7264632104984834.
# [I 2022-11-12 17:31:56,074] Trial 21 finished with value: 0.7270974395214836 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.360822537988982, 'bagging_temperature': 0.053950908246135174}. Best is trial 19 with value: 0.7264632104984834.
# [I 2022-11-12 17:32:34,579] Trial 22 finished with value: 0.7254945537998989 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.0838819764887813, 'bagging_temperature': 0.2799838432027024}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:33:12,848] Trial 23 finished with value: 0.7306961391395228 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.055748433396224, 'bagging_temperature': 1.8169187444361161}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:33:49,762] Trial 24 finished with value: 0.7332741106109204 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.772966959006084, 'bagging_temperature': 2.355655595559071}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:34:25,647] Trial 25 finished with value: 0.7326384192124852 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.025291387220704, 'bagging_temperature': 2.0685104312778773}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:34:48,033] Trial 26 finished with value: 0.7274639044144313 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.499842252396802, 'bagging_temperature': 0.04338225001043797}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:35:24,791] Trial 27 finished with value: 0.7361651102365241 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.974412208988988, 'bagging_temperature': 3.6655634497416996}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:35:47,054] Trial 28 finished with value: 0.7302219136684817 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.3737396481784625, 'bagging_temperature': 1.4262098882855654}. Best is trial 22 with value: 0.7254945537998989.
# [I 2022-11-12 17:35:59,847] Trial 29 finished with value: 0.7407333628453188 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 4.9062064317042005}. Best is trial 22 with value: 0.7254945537998989.
# Number of finished trials: 30
# Best trial (22):
# Value: 0.7254945537998989
# Params:
# {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.0838819764887813, 'bagging_temperature': 0.2799838432027024}
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.9762567	test: 0.9980231	best: 0.9980231 (0)	total: 44.8ms	remaining: 44.8s
# 50:	learn: 0.7416743	test: 0.7759031	best: 0.7759031 (50)	total: 2.29s	remaining: 42.7s
# 100:	learn: 0.7080542	test: 0.7496085	best: 0.7496085 (100)	total: 4.47s	remaining: 39.8s
# 150:	learn: 0.6943073	test: 0.7409423	best: 0.7409423 (150)	total: 6.45s	remaining: 36.3s
# 200:	learn: 0.6863721	test: 0.7367553	best: 0.7367553 (200)	total: 8.34s	remaining: 33.2s
# 250:	learn: 0.6799041	test: 0.7341050	best: 0.7341050 (250)	total: 10.3s	remaining: 30.6s
# 300:	learn: 0.6746040	test: 0.7320160	best: 0.7320160 (300)	total: 12.1s	remaining: 28.2s
# 350:	learn: 0.6699134	test: 0.7303145	best: 0.7303145 (350)	total: 13.9s	remaining: 25.7s
# 400:	learn: 0.6658473	test: 0.7291386	best: 0.7291386 (400)	total: 15.6s	remaining: 23.2s
# 450:	learn: 0.6622157	test: 0.7283322	best: 0.7283322 (450)	total: 17.2s	remaining: 20.9s
# 500:	learn: 0.6592825	test: 0.7275695	best: 0.7275509 (498)	total: 18.8s	remaining: 18.8s
# 550:	learn: 0.6557336	test: 0.7270751	best: 0.7270442 (544)	total: 20.5s	remaining: 16.7s
# 600:	learn: 0.6538903	test: 0.7269357	best: 0.7269007 (589)	total: 22.1s	remaining: 14.7s
# 650:	learn: 0.6517113	test: 0.7264727	best: 0.7264571 (647)	total: 23.8s	remaining: 12.7s
# 700:	learn: 0.6497025	test: 0.7263982	best: 0.7263277 (673)	total: 25.4s	remaining: 10.8s
# 750:	learn: 0.6472014	test: 0.7260661	best: 0.7259662 (735)	total: 27.1s	remaining: 8.99s
# 800:	learn: 0.6454003	test: 0.7258356	best: 0.7258197 (798)	total: 28.7s	remaining: 7.14s
# 850:	learn: 0.6432056	test: 0.7256572	best: 0.7256528 (845)	total: 30.4s	remaining: 5.32s
# 900:	learn: 0.6415695	test: 0.7255295	best: 0.7254965 (893)	total: 32s	remaining: 3.52s
# 950:	learn: 0.6397819	test: 0.7255200	best: 0.7254946 (932)	total: 33.7s	remaining: 1.73s
# bestTest = 0.7254945632
# bestIteration = 932
# Shrink model to first 933 iterations.

# %% [markdown]
# ### Making predictions with LightGBM

# %%
non_tunable_lgb_params, tunable_lgb_params = get_hyper_parameters(get_lgb_params, n_trials=400)
dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
lgbm = lgb.train(
    params={**non_tunable_lgb_params, **tunable_lgb_params},
    train_set=dtrain_lgb,
    valid_sets=dvalid_lgb,
    verbose_eval=False
)
# Out:
# [I 2022-11-12 17:36:35,380] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-12 17:36:36,715] Trial 0 finished with value: 0.748169735529483 and parameters: {'lambda_l1': 0.47428868589469175, 'lambda_l2': 8.41330901704073e-06, 'num_leaves': 160, 'feature_fraction': 0.6081335292696387, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 0 with value: 0.748169735529483.
# [I 2022-11-12 17:36:37,006] Trial 1 finished with value: 0.7478681710907554 and parameters: {'lambda_l1': 7.114495484519206e-05, 'lambda_l2': 0.0016321402528865145, 'num_leaves': 232, 'feature_fraction': 0.9584310634035017, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:37,332] Trial 2 finished with value: 0.7520109371742657 and parameters: {'lambda_l1': 0.06835524162119104, 'lambda_l2': 2.773531495145743e-06, 'num_leaves': 162, 'feature_fraction': 0.45952145586033083, 'min_child_samples': 95, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:37,817] Trial 3 finished with value: 0.7550681771822592 and parameters: {'lambda_l1': 6.938471487762251e-06, 'lambda_l2': 0.0017370192188128082, 'num_leaves': 181, 'feature_fraction': 0.4241358601341199, 'min_child_samples': 46, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:38,372] Trial 4 finished with value: 0.7764626376719184 and parameters: {'lambda_l1': 1.0488444040568395e-06, 'lambda_l2': 1.6554441986629776e-08, 'num_leaves': 146, 'feature_fraction': 0.8296349971719144, 'min_child_samples': 24, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:38,704] Trial 5 finished with value: 0.751450773760187 and parameters: {'lambda_l1': 1.2203846678354239e-08, 'lambda_l2': 8.217899461576883e-07, 'num_leaves': 155, 'feature_fraction': 0.6238859711074776, 'min_child_samples': 93, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:39,099] Trial 6 finished with value: 0.7541312615180173 and parameters: {'lambda_l1': 4.5482126149015166e-05, 'lambda_l2': 0.4469998347588504, 'num_leaves': 97, 'feature_fraction': 0.5998169881583539, 'min_child_samples': 29, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:39,552] Trial 7 finished with value: 0.7650253859162899 and parameters: {'lambda_l1': 5.958514358789156e-08, 'lambda_l2': 0.1452322025591106, 'num_leaves': 172, 'feature_fraction': 0.5990971304739573, 'min_child_samples': 45, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:39,716] Trial 8 finished with value: 0.7511372341027928 and parameters: {'lambda_l1': 7.145645389752713e-06, 'lambda_l2': 0.00028264389555599054, 'num_leaves': 68, 'feature_fraction': 0.8339066951205167, 'min_child_samples': 79, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:39,900] Trial 9 finished with value: 0.7573494389237494 and parameters: {'lambda_l1': 0.3360888004575042, 'lambda_l2': 0.0018434171333041678, 'num_leaves': 195, 'feature_fraction': 0.6244697447045039, 'min_child_samples': 64, 'boosting_type': 'goss'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:40,767] Trial 10 finished with value: 0.7681456986398227 and parameters: {'lambda_l1': 0.0032286545296137258, 'lambda_l2': 2.1944960728399487, 'num_leaves': 243, 'feature_fraction': 0.997611859291902, 'min_child_samples': 8, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.7478681710907554.
# [I 2022-11-12 17:36:40,852] Trial 11 finished with value: 0.7373309503014104 and parameters: {'lambda_l1': 7.947966943103843, 'lambda_l2': 3.9258829815434285e-05, 'num_leaves': 5, 'feature_fraction': 0.9928198769483059, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.7373309503014104.
# [I 2022-11-12 17:36:40,947] Trial 12 finished with value: 0.7382760015051605 and parameters: {'lambda_l1': 0.0011664474658984914, 'lambda_l2': 7.89839458467437e-05, 'num_leaves': 7, 'feature_fraction': 0.9687391537183725, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.7373309503014104.
# [I 2022-11-12 17:36:41,035] Trial 13 finished with value: 0.7368882410130924 and parameters: {'lambda_l1': 7.576163284905685, 'lambda_l2': 6.056185468688543e-05, 'num_leaves': 5, 'feature_fraction': 0.8821639969878956, 'min_child_samples': 68, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:41,113] Trial 14 finished with value: 0.7377397584140251 and parameters: {'lambda_l1': 6.181717496437182, 'lambda_l2': 1.1830491558612406e-07, 'num_leaves': 4, 'feature_fraction': 0.8603799297005988, 'min_child_samples': 62, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:41,320] Trial 15 finished with value: 0.7436637287053862 and parameters: {'lambda_l1': 4.733987208662685, 'lambda_l2': 3.625962806114386e-05, 'num_leaves': 47, 'feature_fraction': 0.7464427050103941, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:41,551] Trial 16 finished with value: 0.7456054541800458 and parameters: {'lambda_l1': 0.01617485244061516, 'lambda_l2': 0.038799412731029305, 'num_leaves': 52, 'feature_fraction': 0.9008433349592131, 'min_child_samples': 58, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:41,870] Trial 17 finished with value: 0.7485665386565566 and parameters: {'lambda_l1': 0.754106558963817, 'lambda_l2': 0.011661590359467405, 'num_leaves': 107, 'feature_fraction': 0.7499955945998971, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:42,034] Trial 18 finished with value: 0.7422283992245325 and parameters: {'lambda_l1': 0.03199908640875934, 'lambda_l2': 3.0611776108641845e-07, 'num_leaves': 28, 'feature_fraction': 0.9128650487549869, 'min_child_samples': 49, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:42,184] Trial 19 finished with value: 0.7514221598781005 and parameters: {'lambda_l1': 7.727725514149761, 'lambda_l2': 1.619224992814249e-05, 'num_leaves': 87, 'feature_fraction': 0.7795617767859251, 'min_child_samples': 84, 'boosting_type': 'goss'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:42,354] Trial 20 finished with value: 0.7429256908184293 and parameters: {'lambda_l1': 0.670507639504746, 'lambda_l2': 0.00014154376966865137, 'num_leaves': 28, 'feature_fraction': 0.9457181333880732, 'min_child_samples': 40, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:42,461] Trial 21 finished with value: 0.7380467166575931 and parameters: {'lambda_l1': 7.913665576294675, 'lambda_l2': 5.674215416608337e-08, 'num_leaves': 10, 'feature_fraction': 0.8732975019830613, 'min_child_samples': 63, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:42,529] Trial 22 finished with value: 0.7472785182511239 and parameters: {'lambda_l1': 2.0948626218262087, 'lambda_l2': 2.607223176158229e-07, 'num_leaves': 2, 'feature_fraction': 0.8396485987356654, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:42,726] Trial 23 finished with value: 0.741899597886839 and parameters: {'lambda_l1': 0.1043364608785185, 'lambda_l2': 3.5434450698257336e-06, 'num_leaves': 39, 'feature_fraction': 0.6831769010494811, 'min_child_samples': 54, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:43,003] Trial 24 finished with value: 0.749255014215982 and parameters: {'lambda_l1': 0.007516253303265969, 'lambda_l2': 1.1818962657832224e-08, 'num_leaves': 67, 'feature_fraction': 0.9095000684587775, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:43,148] Trial 25 finished with value: 0.7403712682917805 and parameters: {'lambda_l1': 1.6457722622757907, 'lambda_l2': 9.955566410441188e-07, 'num_leaves': 23, 'feature_fraction': 0.7942243434865346, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:43,561] Trial 26 finished with value: 0.7576242502981728 and parameters: {'lambda_l1': 0.17862706453661412, 'lambda_l2': 6.491997391576384e-08, 'num_leaves': 122, 'feature_fraction': 0.8900755112948389, 'min_child_samples': 58, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:43,844] Trial 27 finished with value: 0.7499436626422854 and parameters: {'lambda_l1': 2.4105377806252424, 'lambda_l2': 0.0006095594163639215, 'num_leaves': 67, 'feature_fraction': 0.9771753177911915, 'min_child_samples': 40, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:43,992] Trial 28 finished with value: 0.7515668997865154 and parameters: {'lambda_l1': 9.354945207920231, 'lambda_l2': 0.01436005629440526, 'num_leaves': 21, 'feature_fraction': 0.702410113345463, 'min_child_samples': 77, 'boosting_type': 'dart'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:44,155] Trial 29 finished with value: 0.7528242086352528 and parameters: {'lambda_l1': 0.36907884368465765, 'lambda_l2': 2.1057148548127383e-05, 'num_leaves': 49, 'feature_fraction': 0.9340207651165984, 'min_child_samples': 87, 'boosting_type': 'goss'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:44,443] Trial 30 finished with value: 0.7492859388176435 and parameters: {'lambda_l1': 0.0004989017692457391, 'lambda_l2': 4.03611417890889e-06, 'num_leaves': 74, 'feature_fraction': 0.8700825372017429, 'min_child_samples': 57, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:44,524] Trial 31 finished with value: 0.7377950316733768 and parameters: {'lambda_l1': 9.282134702680299, 'lambda_l2': 5.688389567512042e-08, 'num_leaves': 4, 'feature_fraction': 0.8564391247170058, 'min_child_samples': 65, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:44,645] Trial 32 finished with value: 0.7390874275306232 and parameters: {'lambda_l1': 1.4989404303190976, 'lambda_l2': 8.755118365720804e-08, 'num_leaves': 13, 'feature_fraction': 0.9994972934181748, 'min_child_samples': 67, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:44,713] Trial 33 finished with value: 0.7472422469979383 and parameters: {'lambda_l1': 0.06780987180734825, 'lambda_l2': 7.28095468724667e-07, 'num_leaves': 2, 'feature_fraction': 0.8523472397875848, 'min_child_samples': 62, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:45,038] Trial 34 finished with value: 0.7523103345238958 and parameters: {'lambda_l1': 0.8875951215352041, 'lambda_l2': 9.507061818592324e-06, 'num_leaves': 212, 'feature_fraction': 0.7970720298438856, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:45,217] Trial 35 finished with value: 0.7436729877731083 and parameters: {'lambda_l1': 3.4943137842873684, 'lambda_l2': 1.7348365397590457e-07, 'num_leaves': 32, 'feature_fraction': 0.9321266222620199, 'min_child_samples': 52, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:45,454] Trial 36 finished with value: 0.7509917047312228 and parameters: {'lambda_l1': 0.3819610872466285, 'lambda_l2': 2.8189899153215122e-08, 'num_leaves': 41, 'feature_fraction': 0.49535455920206295, 'min_child_samples': 92, 'boosting_type': 'dart'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:45,584] Trial 37 finished with value: 0.7394691984299459 and parameters: {'lambda_l1': 9.045324063460997, 'lambda_l2': 1.7012133772952124e-06, 'num_leaves': 17, 'feature_fraction': 0.8089521608300615, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:45,823] Trial 38 finished with value: 0.7466765796640816 and parameters: {'lambda_l1': 0.05180511989342321, 'lambda_l2': 0.0007883650494456166, 'num_leaves': 36, 'feature_fraction': 0.7527545171811039, 'min_child_samples': 80, 'boosting_type': 'dart'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,084] Trial 39 finished with value: 0.7483339721965064 and parameters: {'lambda_l1': 0.23588618376627873, 'lambda_l2': 7.685485746537577e-05, 'num_leaves': 136, 'feature_fraction': 0.7009566150133807, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,302] Trial 40 finished with value: 0.7544296703153011 and parameters: {'lambda_l1': 1.721432599626789e-05, 'lambda_l2': 0.0034580596793107867, 'num_leaves': 56, 'feature_fraction': 0.8635430937900473, 'min_child_samples': 43, 'boosting_type': 'goss'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,425] Trial 41 finished with value: 0.738460505371112 and parameters: {'lambda_l1': 3.7478910663741933, 'lambda_l2': 8.016833383230845e-08, 'num_leaves': 13, 'feature_fraction': 0.8866688815539607, 'min_child_samples': 62, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,518] Trial 42 finished with value: 0.7385396125836193 and parameters: {'lambda_l1': 1.0727934343161076e-06, 'lambda_l2': 3.3030978346217596e-08, 'num_leaves': 4, 'feature_fraction': 0.8180230532379905, 'min_child_samples': 62, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,659] Trial 43 finished with value: 0.7380005656922077 and parameters: {'lambda_l1': 1.292835968305003, 'lambda_l2': 4.609492931449954e-07, 'num_leaves': 17, 'feature_fraction': 0.9507407038347199, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,797] Trial 44 finished with value: 0.7403209783570106 and parameters: {'lambda_l1': 1.338327351077505, 'lambda_l2': 5.551420248671858e-07, 'num_leaves': 19, 'feature_fraction': 0.9478189450035281, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:46,981] Trial 45 finished with value: 0.7409671273309745 and parameters: {'lambda_l1': 4.444036939101211, 'lambda_l2': 6.91684667834912e-06, 'num_leaves': 32, 'feature_fraction': 0.9640576380830719, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:47,161] Trial 46 finished with value: 0.748675181772531 and parameters: {'lambda_l1': 0.7863437566556362, 'lambda_l2': 9.236783720603812, 'num_leaves': 18, 'feature_fraction': 0.9721744124639431, 'min_child_samples': 7, 'boosting_type': 'dart'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:47,410] Trial 47 finished with value: 0.7518412622768663 and parameters: {'lambda_l1': 9.280989682404863e-05, 'lambda_l2': 1.5809570205422423e-06, 'num_leaves': 55, 'feature_fraction': 0.9054637415603936, 'min_child_samples': 30, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:47,573] Trial 48 finished with value: 0.7576412845492705 and parameters: {'lambda_l1': 3.417486670475319, 'lambda_l2': 2.647270355268641e-07, 'num_leaves': 81, 'feature_fraction': 0.5557020273730315, 'min_child_samples': 73, 'boosting_type': 'goss'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:47,783] Trial 49 finished with value: 0.7453394768637577 and parameters: {'lambda_l1': 0.16196999718862226, 'lambda_l2': 0.0002200485074387305, 'num_leaves': 43, 'feature_fraction': 0.9263360689629823, 'min_child_samples': 67, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:48,011] Trial 50 finished with value: 0.7404408040078555 and parameters: {'lambda_l1': 9.338253429582453, 'lambda_l2': 4.470031636523292e-05, 'num_leaves': 99, 'feature_fraction': 0.8419883500536967, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 13 with value: 0.7368882410130924.
# [I 2022-11-12 17:36:48,111] Trial 51 finished with value: 0.736218667688213 and parameters: {'lambda_l1': 3.802277788940301, 'lambda_l2': 3.344218296068629e-08, 'num_leaves': 8, 'feature_fraction': 0.877735724927137, 'min_child_samples': 58, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:48,186] Trial 52 finished with value: 0.7396898104602585 and parameters: {'lambda_l1': 2.0907668826230084, 'lambda_l2': 1.5472211749688188e-08, 'num_leaves': 3, 'feature_fraction': 0.9790293833006003, 'min_child_samples': 49, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:48,355] Trial 53 finished with value: 0.7431833038990139 and parameters: {'lambda_l1': 0.4997948026853712, 'lambda_l2': 1.303278548647075e-07, 'num_leaves': 27, 'feature_fraction': 0.8897815197875457, 'min_child_samples': 55, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:48,466] Trial 54 finished with value: 0.7383986243584865 and parameters: {'lambda_l1': 3.748212245353463, 'lambda_l2': 3.088758997721717e-08, 'num_leaves': 12, 'feature_fraction': 0.7743457423178105, 'min_child_samples': 60, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:48,625] Trial 55 finished with value: 0.7409839901992609 and parameters: {'lambda_l1': 1.25512701018674e-08, 'lambda_l2': 4.4989809450945934e-07, 'num_leaves': 25, 'feature_fraction': 0.9559237894267537, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:48,747] Trial 56 finished with value: 0.739426235142916 and parameters: {'lambda_l1': 0.020336020963339543, 'lambda_l2': 1.0527608477822988e-08, 'num_leaves': 14, 'feature_fraction': 0.9206054977217397, 'min_child_samples': 51, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:49,102] Trial 57 finished with value: 0.7563277971705227 and parameters: {'lambda_l1': 1.37176869541677, 'lambda_l2': 3.6094110884855146e-08, 'num_leaves': 252, 'feature_fraction': 0.8658528258200178, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:49,255] Trial 58 finished with value: 0.7563647100859126 and parameters: {'lambda_l1': 0.7582378450649393, 'lambda_l2': 1.6815519558109468e-07, 'num_leaves': 36, 'feature_fraction': 0.4032635772721139, 'min_child_samples': 76, 'boosting_type': 'goss'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:49,354] Trial 59 finished with value: 0.737379176263609 and parameters: {'lambda_l1': 5.156964918556833, 'lambda_l2': 1.1742500284477322e-06, 'num_leaves': 8, 'feature_fraction': 0.8242168759279153, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:49,647] Trial 60 finished with value: 0.7499728705709118 and parameters: {'lambda_l1': 0.0030185705786265437, 'lambda_l2': 1.953673624197199e-06, 'num_leaves': 157, 'feature_fraction': 0.822871885308792, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:49,755] Trial 61 finished with value: 0.737314614512796 and parameters: {'lambda_l1': 6.189882259871052, 'lambda_l2': 5.36782808665026e-06, 'num_leaves': 9, 'feature_fraction': 0.8475542635036803, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:49,862] Trial 62 finished with value: 0.738223782462349 and parameters: {'lambda_l1': 5.50990367616785, 'lambda_l2': 9.781946997938432e-06, 'num_leaves': 7, 'feature_fraction': 0.8353857270705325, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:50,014] Trial 63 finished with value: 0.7386573393883588 and parameters: {'lambda_l1': 4.986603964070952, 'lambda_l2': 1.9974701511749e-05, 'num_leaves': 25, 'feature_fraction': 0.7627470922618076, 'min_child_samples': 99, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:50,085] Trial 64 finished with value: 0.7477910923992213 and parameters: {'lambda_l1': 9.888261443776788, 'lambda_l2': 4.889022290302143e-06, 'num_leaves': 2, 'feature_fraction': 0.852355138929795, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 51 with value: 0.736218667688213.
# [I 2022-11-12 17:36:50,194] Trial 65 finished with value: 0.7361188507961374 and parameters: {'lambda_l1': 2.4611749284254576, 'lambda_l2': 8.981247751541367e-05, 'num_leaves': 10, 'feature_fraction': 0.7261711906370724, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:50,432] Trial 66 finished with value: 0.7489398158345986 and parameters: {'lambda_l1': 2.3736033858212577, 'lambda_l2': 8.603166547237976e-05, 'num_leaves': 191, 'feature_fraction': 0.6800201674525543, 'min_child_samples': 94, 'boosting_type': 'dart'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:50,643] Trial 67 finished with value: 0.7456191060417633 and parameters: {'lambda_l1': 0.14566946358069635, 'lambda_l2': 0.000491498757202208, 'num_leaves': 45, 'feature_fraction': 0.7276127311295584, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:50,886] Trial 68 finished with value: 0.7470359686636189 and parameters: {'lambda_l1': 0.32807208708665747, 'lambda_l2': 4.287828029088489e-05, 'num_leaves': 60, 'feature_fraction': 0.787535410628186, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:50,991] Trial 69 finished with value: 0.7361502994671196 and parameters: {'lambda_l1': 0.8602157751805427, 'lambda_l2': 0.00015976567594268423, 'num_leaves': 9, 'feature_fraction': 0.7303985175776838, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:51,159] Trial 70 finished with value: 0.7388646881211992 and parameters: {'lambda_l1': 2.6027010978507508, 'lambda_l2': 0.00013469696207167015, 'num_leaves': 31, 'feature_fraction': 0.7290022915032423, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:51,264] Trial 71 finished with value: 0.7363096725363205 and parameters: {'lambda_l1': 0.9619915613093873, 'lambda_l2': 1.8823232175502113e-05, 'num_leaves': 10, 'feature_fraction': 0.6389070293918181, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 65 with value: 0.7361188507961374.
# [I 2022-11-12 17:36:51,378] Trial 72 finished with value: 0.7350713236297679 and parameters: {'lambda_l1': 1.0088708752153481, 'lambda_l2': 2.6200053680156504e-05, 'num_leaves': 12, 'feature_fraction': 0.6601712632443549, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 72 with value: 0.7350713236297679.
# [I 2022-11-12 17:36:51,525] Trial 73 finished with value: 0.7347807974937491 and parameters: {'lambda_l1': 0.5816645670252242, 'lambda_l2': 1.6395603107627904e-05, 'num_leaves': 23, 'feature_fraction': 0.6496068058683458, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:51,667] Trial 74 finished with value: 0.7394119254936071 and parameters: {'lambda_l1': 0.09526947182885015, 'lambda_l2': 0.0014388383196800648, 'num_leaves': 23, 'feature_fraction': 0.6472191991846112, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:51,782] Trial 75 finished with value: 0.7356605045905155 and parameters: {'lambda_l1': 0.48151300546648856, 'lambda_l2': 2.5514393194486125e-05, 'num_leaves': 12, 'feature_fraction': 0.6505103558816435, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:52,053] Trial 76 finished with value: 0.7510233845487625 and parameters: {'lambda_l1': 0.24980061063607442, 'lambda_l2': 0.00018926398952578424, 'num_leaves': 167, 'feature_fraction': 0.5802827992807337, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:52,235] Trial 77 finished with value: 0.7416579688077963 and parameters: {'lambda_l1': 0.4933564675695867, 'lambda_l2': 1.4956865443717328e-05, 'num_leaves': 37, 'feature_fraction': 0.6488253266824366, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:52,379] Trial 78 finished with value: 0.753860509891417 and parameters: {'lambda_l1': 0.04042672575050811, 'lambda_l2': 0.0003829588223635729, 'num_leaves': 21, 'feature_fraction': 0.6216032571038723, 'min_child_samples': 84, 'boosting_type': 'goss'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:52,495] Trial 79 finished with value: 0.7355019158619891 and parameters: {'lambda_l1': 1.0085612782579132, 'lambda_l2': 8.712197068028369e-05, 'num_leaves': 12, 'feature_fraction': 0.653814666461385, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:52,979] Trial 80 finished with value: 0.7585924762097024 and parameters: {'lambda_l1': 0.09983281252153628, 'lambda_l2': 2.6808501347880093e-05, 'num_leaves': 117, 'feature_fraction': 0.6602419516627991, 'min_child_samples': 14, 'boosting_type': 'dart'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,094] Trial 81 finished with value: 0.7366766250918371 and parameters: {'lambda_l1': 1.0500157275780504, 'lambda_l2': 7.94527971015337e-05, 'num_leaves': 14, 'feature_fraction': 0.5863413628691065, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,204] Trial 82 finished with value: 0.736399496247061 and parameters: {'lambda_l1': 1.0045442495521295, 'lambda_l2': 9.624009490170302e-05, 'num_leaves': 13, 'feature_fraction': 0.5857044908598957, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,366] Trial 83 finished with value: 0.7395392627170078 and parameters: {'lambda_l1': 0.55029802202714, 'lambda_l2': 0.00015026208848962835, 'num_leaves': 30, 'feature_fraction': 0.5589476957099372, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,473] Trial 84 finished with value: 0.7360036461664027 and parameters: {'lambda_l1': 0.2693802340238635, 'lambda_l2': 0.0011561786812000815, 'num_leaves': 11, 'feature_fraction': 0.6094761879128986, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,617] Trial 85 finished with value: 0.7383046037403482 and parameters: {'lambda_l1': 0.1923630715253712, 'lambda_l2': 0.0011397217172058936, 'num_leaves': 23, 'feature_fraction': 0.6793035360402744, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,727] Trial 86 finished with value: 0.7354351164991653 and parameters: {'lambda_l1': 0.296198831633322, 'lambda_l2': 0.000268466481610172, 'num_leaves': 11, 'feature_fraction': 0.6246281345455639, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:53,854] Trial 87 finished with value: 0.7357274215621391 and parameters: {'lambda_l1': 0.0130746303947478, 'lambda_l2': 0.0031109190343080687, 'num_leaves': 18, 'feature_fraction': 0.6131237484192861, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:54,062] Trial 88 finished with value: 0.7429375942453179 and parameters: {'lambda_l1': 0.010026692705564399, 'lambda_l2': 0.004906982086174872, 'num_leaves': 50, 'feature_fraction': 0.6074414472239028, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:54,245] Trial 89 finished with value: 0.7371043937893268 and parameters: {'lambda_l1': 0.07734756259318104, 'lambda_l2': 0.0028276785238751634, 'num_leaves': 37, 'feature_fraction': 0.6666155799868458, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:54,524] Trial 90 finished with value: 0.7495996402630344 and parameters: {'lambda_l1': 0.022136323107126057, 'lambda_l2': 0.008761938833934757, 'num_leaves': 149, 'feature_fraction': 0.6301989888140238, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:54,654] Trial 91 finished with value: 0.7365378270939424 and parameters: {'lambda_l1': 1.8639898928565424, 'lambda_l2': 0.00027202285311611694, 'num_leaves': 19, 'feature_fraction': 0.6224078752484643, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:54,783] Trial 92 finished with value: 0.7366901814375728 and parameters: {'lambda_l1': 0.35901826123499725, 'lambda_l2': 0.029616315056410967, 'num_leaves': 17, 'feature_fraction': 0.7218157109979079, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:54,939] Trial 93 finished with value: 0.739238005740366 and parameters: {'lambda_l1': 0.0031306107956496887, 'lambda_l2': 0.0008349472232664439, 'num_leaves': 29, 'feature_fraction': 0.5295454728833062, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,035] Trial 94 finished with value: 0.7355292161041876 and parameters: {'lambda_l1': 0.0010051772967110293, 'lambda_l2': 0.00036102989870319977, 'num_leaves': 7, 'feature_fraction': 0.6924500413907642, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,107] Trial 95 finished with value: 0.7474743672009284 and parameters: {'lambda_l1': 0.000502741638151691, 'lambda_l2': 0.002241854523619988, 'num_leaves': 2, 'feature_fraction': 0.6933411030998101, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,233] Trial 96 finished with value: 0.7368650979308481 and parameters: {'lambda_l1': 0.001291513337437865, 'lambda_l2': 0.00038246790749612105, 'num_leaves': 17, 'feature_fraction': 0.6652540119522673, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,397] Trial 97 finished with value: 0.7502921593581819 and parameters: {'lambda_l1': 0.007120024330308932, 'lambda_l2': 5.1169990346992026e-05, 'num_leaves': 222, 'feature_fraction': 0.7104774626288193, 'min_child_samples': 92, 'boosting_type': 'goss'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,492] Trial 98 finished with value: 0.7359274877063378 and parameters: {'lambda_l1': 0.00016466872423874797, 'lambda_l2': 3.058501692871869e-05, 'num_leaves': 8, 'feature_fraction': 0.6047250922059144, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,634] Trial 99 finished with value: 0.7374822103791961 and parameters: {'lambda_l1': 7.5858967135327e-05, 'lambda_l2': 3.496130624995134e-05, 'num_leaves': 24, 'feature_fraction': 0.5955112383521574, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,884] Trial 100 finished with value: 0.7491140509572927 and parameters: {'lambda_l1': 0.00017268147220906387, 'lambda_l2': 0.0006703828805247762, 'num_leaves': 43, 'feature_fraction': 0.569934541158835, 'min_child_samples': 82, 'boosting_type': 'dart'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:55,982] Trial 101 finished with value: 0.7360625069556841 and parameters: {'lambda_l1': 1.947757517613097e-05, 'lambda_l2': 1.0660609327294948e-05, 'num_leaves': 8, 'feature_fraction': 0.6090407641997836, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:56,092] Trial 102 finished with value: 0.7354205120592214 and parameters: {'lambda_l1': 3.458377809487651e-05, 'lambda_l2': 1.1728348563678011e-05, 'num_leaves': 12, 'feature_fraction': 0.6088679219930124, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 73 with value: 0.7347807974937491.
# [I 2022-11-12 17:36:56,210] Trial 103 finished with value: 0.7347713421282834 and parameters: {'lambda_l1': 2.448044907344491e-05, 'lambda_l2': 2.491665529451862e-06, 'num_leaves': 14, 'feature_fraction': 0.6002341078642955, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:56,378] Trial 104 finished with value: 0.741387802183144 and parameters: {'lambda_l1': 2.7490586914538816e-05, 'lambda_l2': 2.7669725496309275e-06, 'num_leaves': 34, 'feature_fraction': 0.5432201496630578, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:56,505] Trial 105 finished with value: 0.736889608120457 and parameters: {'lambda_l1': 0.00015137676230566789, 'lambda_l2': 1.3360634093235788e-05, 'num_leaves': 18, 'feature_fraction': 0.6138271686379967, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:56,622] Trial 106 finished with value: 0.7358808023059414 and parameters: {'lambda_l1': 3.943278927147035e-05, 'lambda_l2': 3.007594633798161e-06, 'num_leaves': 14, 'feature_fraction': 0.6368513759257183, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:56,774] Trial 107 finished with value: 0.738358559838032 and parameters: {'lambda_l1': 2.9384469833259145e-06, 'lambda_l2': 2.9601854069606663e-05, 'num_leaves': 27, 'feature_fraction': 0.6363329036686867, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:56,898] Trial 108 finished with value: 0.736668089063509 and parameters: {'lambda_l1': 4.9512981962767836e-05, 'lambda_l2': 6.887454228923509e-06, 'num_leaves': 16, 'feature_fraction': 0.6461516410648048, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:56,967] Trial 109 finished with value: 0.747769312933421 and parameters: {'lambda_l1': 7.518875936568427e-06, 'lambda_l2': 5.730792129171104e-05, 'num_leaves': 2, 'feature_fraction': 0.6545087987199584, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,102] Trial 110 finished with value: 0.7388914916501405 and parameters: {'lambda_l1': 0.00043628393443690306, 'lambda_l2': 2.880468574900114e-06, 'num_leaves': 21, 'feature_fraction': 0.6738351365436763, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,216] Trial 111 finished with value: 0.7353077617214648 and parameters: {'lambda_l1': 9.144651056354403e-06, 'lambda_l2': 1.2067817530157183e-05, 'num_leaves': 13, 'feature_fraction': 0.5920823283738633, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,331] Trial 112 finished with value: 0.7364938893062121 and parameters: {'lambda_l1': 5.701468805573815e-06, 'lambda_l2': 6.590797272468913e-06, 'num_leaves': 13, 'feature_fraction': 0.5956540493492468, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,423] Trial 113 finished with value: 0.7369038171135152 and parameters: {'lambda_l1': 1.1334930955918812e-05, 'lambda_l2': 2.4257406349749075e-05, 'num_leaves': 7, 'feature_fraction': 0.6893405118638227, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,578] Trial 114 finished with value: 0.7396194125664801 and parameters: {'lambda_l1': 3.894191258569874e-05, 'lambda_l2': 0.2913091632823017, 'num_leaves': 28, 'feature_fraction': 0.6350421231941135, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,714] Trial 115 finished with value: 0.7373376036305233 and parameters: {'lambda_l1': 2.0126639498798303e-06, 'lambda_l2': 4.4046941324580736e-06, 'num_leaves': 21, 'feature_fraction': 0.5714018739446477, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,826] Trial 116 finished with value: 0.7362594777558819 and parameters: {'lambda_l1': 0.00012490982416627034, 'lambda_l2': 1.3469916407091993e-05, 'num_leaves': 6, 'feature_fraction': 0.6203408115394183, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:57,941] Trial 117 finished with value: 0.7364510133450837 and parameters: {'lambda_l1': 0.0002435766023740828, 'lambda_l2': 9.091534725650357e-06, 'num_leaves': 14, 'feature_fraction': 0.6585234217025663, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,085] Trial 118 finished with value: 0.7589426006593631 and parameters: {'lambda_l1': 0.0012259115145974587, 'lambda_l2': 2.1292867133373343e-06, 'num_leaves': 33, 'feature_fraction': 0.5231784253392828, 'min_child_samples': 96, 'boosting_type': 'goss'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,243] Trial 119 finished with value: 0.7364284342799385 and parameters: {'lambda_l1': 4.731519387963914e-05, 'lambda_l2': 1.1897950500290713e-06, 'num_leaves': 25, 'feature_fraction': 0.5987772322687439, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,497] Trial 120 finished with value: 0.7497261828093839 and parameters: {'lambda_l1': 1.9620611434791166e-05, 'lambda_l2': 3.2192805297366645e-05, 'num_leaves': 39, 'feature_fraction': 0.6397928436307465, 'min_child_samples': 91, 'boosting_type': 'dart'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,606] Trial 121 finished with value: 0.7361650942364535 and parameters: {'lambda_l1': 0.0008278857586423888, 'lambda_l2': 0.006884228660942031, 'num_leaves': 11, 'feature_fraction': 0.6240719533226169, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,720] Trial 122 finished with value: 0.735166297763929 and parameters: {'lambda_l1': 1.2714603971722579e-05, 'lambda_l2': 0.0002728034680865976, 'num_leaves': 13, 'feature_fraction': 0.6134127816512085, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,813] Trial 123 finished with value: 0.7357839310037996 and parameters: {'lambda_l1': 1.26546933577005e-05, 'lambda_l2': 0.0002597339353926474, 'num_leaves': 6, 'feature_fraction': 0.6706682318032554, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:58,882] Trial 124 finished with value: 0.7479169914217146 and parameters: {'lambda_l1': 4.442578127728352e-06, 'lambda_l2': 0.00023847975526302613, 'num_leaves': 2, 'feature_fraction': 0.6731780597219221, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,016] Trial 125 finished with value: 0.7362436946232972 and parameters: {'lambda_l1': 9.830755402938687e-06, 'lambda_l2': 0.0003950186860296346, 'num_leaves': 19, 'feature_fraction': 0.6992489015179323, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,139] Trial 126 finished with value: 0.7380660392216023 and parameters: {'lambda_l1': 1.1519294938551715e-05, 'lambda_l2': 0.00013837834686948461, 'num_leaves': 16, 'feature_fraction': 0.6527411907226333, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,288] Trial 127 finished with value: 0.7372124667272609 and parameters: {'lambda_l1': 3.014293668792172e-05, 'lambda_l2': 9.85036865966199e-05, 'num_leaves': 25, 'feature_fraction': 0.5786728607384463, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,400] Trial 128 finished with value: 0.7363514639359625 and parameters: {'lambda_l1': 5.693995545870052e-07, 'lambda_l2': 6.147469274978236e-05, 'num_leaves': 12, 'feature_fraction': 0.6331517829845424, 'min_child_samples': 34, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,581] Trial 129 finished with value: 0.7379149039823137 and parameters: {'lambda_l1': 2.8592819180575967e-06, 'lambda_l2': 0.0002872959046031322, 'num_leaves': 32, 'feature_fraction': 0.7079906266886282, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,717] Trial 130 finished with value: 0.7359165817297597 and parameters: {'lambda_l1': 1.754782495216059e-05, 'lambda_l2': 1.8361955627297197e-05, 'num_leaves': 21, 'feature_fraction': 0.5904918460755292, 'min_child_samples': 99, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,806] Trial 131 finished with value: 0.7362034068023056 and parameters: {'lambda_l1': 2.308554237162672e-05, 'lambda_l2': 1.966785416148791e-05, 'num_leaves': 6, 'feature_fraction': 0.6129755946224257, 'min_child_samples': 99, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:36:59,941] Trial 132 finished with value: 0.73735059933783 and parameters: {'lambda_l1': 1.3858916008997705e-05, 'lambda_l2': 3.7671885632756104e-06, 'num_leaves': 21, 'feature_fraction': 0.5920242904715474, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:37:00,062] Trial 133 finished with value: 0.7369810890665747 and parameters: {'lambda_l1': 6.87388784882722e-05, 'lambda_l2': 1.4832274195404844e-05, 'num_leaves': 15, 'feature_fraction': 0.5603641223668646, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:37:00,151] Trial 134 finished with value: 0.7359764875396966 and parameters: {'lambda_l1': 7.4919298170351504e-06, 'lambda_l2': 4.423099663070454e-05, 'num_leaves': 6, 'feature_fraction': 0.6852407403226528, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:37:00,308] Trial 135 finished with value: 0.736117816085958 and parameters: {'lambda_l1': 4.6302425471664695e-06, 'lambda_l2': 8.881064326481769e-06, 'num_leaves': 28, 'feature_fraction': 0.6480411832392694, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 103 with value: 0.7347713421282834.
# [I 2022-11-12 17:37:00,419] Trial 136 finished with value: 0.7328815716145676 and parameters: {'lambda_l1': 1.1885678531902196e-06, 'lambda_l2': 0.00010800373677674506, 'num_leaves': 12, 'feature_fraction': 0.6262130543158102, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:00,503] Trial 137 finished with value: 0.7479169966129551 and parameters: {'lambda_l1': 4.869018341385601e-07, 'lambda_l2': 0.000551147581931455, 'num_leaves': 2, 'feature_fraction': 0.6626605580726055, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:00,613] Trial 138 finished with value: 0.7354874721147968 and parameters: {'lambda_l1': 1.1487733497811211e-07, 'lambda_l2': 0.0001259439911287, 'num_leaves': 12, 'feature_fraction': 0.6298171264011281, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:00,717] Trial 139 finished with value: 0.7356988332949502 and parameters: {'lambda_l1': 6.709846130002802e-08, 'lambda_l2': 0.00011950451927162764, 'num_leaves': 10, 'feature_fraction': 0.6292182173236726, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:00,829] Trial 140 finished with value: 0.750678678554532 and parameters: {'lambda_l1': 1.2298629301713073e-07, 'lambda_l2': 0.0001067541923969625, 'num_leaves': 10, 'feature_fraction': 0.6217353797145355, 'min_child_samples': 82, 'boosting_type': 'goss'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:00,953] Trial 141 finished with value: 0.7347183016938994 and parameters: {'lambda_l1': 9.773038899773592e-08, 'lambda_l2': 0.000203104254866072, 'num_leaves': 16, 'feature_fraction': 0.6291868565552557, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:01,080] Trial 142 finished with value: 0.7377771637912709 and parameters: {'lambda_l1': 5.7364300881317585e-08, 'lambda_l2': 0.00017748018351247268, 'num_leaves': 18, 'feature_fraction': 0.6043921945712348, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:01,191] Trial 143 finished with value: 0.7348094698341108 and parameters: {'lambda_l1': 9.89552496579438e-08, 'lambda_l2': 7.328744302285708e-05, 'num_leaves': 12, 'feature_fraction': 0.6243150604855265, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:01,297] Trial 144 finished with value: 0.735069957414059 and parameters: {'lambda_l1': 9.571926844000699e-08, 'lambda_l2': 7.334197247053368e-05, 'num_leaves': 9, 'feature_fraction': 0.6292734190602186, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:01,409] Trial 145 finished with value: 0.7361361163322571 and parameters: {'lambda_l1': 1.4238504788000376e-07, 'lambda_l2': 5.2431270998117725e-05, 'num_leaves': 13, 'feature_fraction': 0.6442955923588658, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:01,558] Trial 146 finished with value: 0.7353809991170431 and parameters: {'lambda_l1': 2.8101263577892615e-08, 'lambda_l2': 8.070274209682079e-05, 'num_leaves': 25, 'feature_fraction': 0.6235093007887512, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:01,843] Trial 147 finished with value: 0.7463756952318736 and parameters: {'lambda_l1': 4.8978975822660335e-08, 'lambda_l2': 7.044292301908942e-05, 'num_leaves': 135, 'feature_fraction': 0.6232693479759488, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# ...
# [I 2022-11-12 17:37:29,910] Trial 352 finished with value: 0.7368702600313198 and parameters: {'lambda_l1': 6.600288993565413e-07, 'lambda_l2': 3.846089583911725e-05, 'num_leaves': 23, 'feature_fraction': 0.6074263781975107, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,032] Trial 353 finished with value: 0.7359408579788259 and parameters: {'lambda_l1': 1.128265973003231e-06, 'lambda_l2': 0.00012409872157107747, 'num_leaves': 15, 'feature_fraction': 0.5910442486824018, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,129] Trial 354 finished with value: 0.7359377390291371 and parameters: {'lambda_l1': 1.529436565161699e-06, 'lambda_l2': 0.00020375786428517318, 'num_leaves': 7, 'feature_fraction': 0.6249607443967449, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,261] Trial 355 finished with value: 0.735364079954929 and parameters: {'lambda_l1': 6.657411238914425e-07, 'lambda_l2': 0.024242104446243883, 'num_leaves': 18, 'feature_fraction': 0.6116935827869017, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,335] Trial 356 finished with value: 0.7472555582641076 and parameters: {'lambda_l1': 3.3701233767891893e-06, 'lambda_l2': 6.809854123700131e-05, 'num_leaves': 2, 'feature_fraction': 0.5378339081206313, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,450] Trial 357 finished with value: 0.7373292013071304 and parameters: {'lambda_l1': 2.7845648602049645e-08, 'lambda_l2': 0.00015907272665882996, 'num_leaves': 13, 'feature_fraction': 0.5949647932029138, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,611] Trial 358 finished with value: 0.7400657369582218 and parameters: {'lambda_l1': 5.629364305293859e-07, 'lambda_l2': 0.0002505035264779586, 'num_leaves': 30, 'feature_fraction': 0.6303143972810704, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,754] Trial 359 finished with value: 0.7377488897669658 and parameters: {'lambda_l1': 1.0374373356934631e-06, 'lambda_l2': 0.00010525949047066502, 'num_leaves': 23, 'feature_fraction': 0.5778157565086782, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,854] Trial 360 finished with value: 0.7360732552148384 and parameters: {'lambda_l1': 3.9687076691060055e-07, 'lambda_l2': 0.00025911199422005846, 'num_leaves': 8, 'feature_fraction': 0.608731463567449, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:30,982] Trial 361 finished with value: 0.7368965399324359 and parameters: {'lambda_l1': 0.037420851398511944, 'lambda_l2': 0.00015566376066190898, 'num_leaves': 17, 'feature_fraction': 0.6189619790544592, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:31,094] Trial 362 finished with value: 0.7350840135226636 and parameters: {'lambda_l1': 6.7096130045545e-06, 'lambda_l2': 9.147097659422089e-05, 'num_leaves': 12, 'feature_fraction': 0.6000969022633319, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:31,369] Trial 363 finished with value: 0.7494517218902469 and parameters: {'lambda_l1': 1.0512303843574685e-07, 'lambda_l2': 1.6157110867947043e-07, 'num_leaves': 192, 'feature_fraction': 0.6290934098235268, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:31,502] Trial 364 finished with value: 0.7364929425684614 and parameters: {'lambda_l1': 5.8696560453486794e-08, 'lambda_l2': 4.9850868280980744e-05, 'num_leaves': 19, 'feature_fraction': 0.6157764401111382, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:31,651] Trial 365 finished with value: 0.737681669200728 and parameters: {'lambda_l1': 8.939377412862649e-07, 'lambda_l2': 0.00047504519567084157, 'num_leaves': 25, 'feature_fraction': 0.6378322163850441, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:31,809] Trial 366 finished with value: 0.7567098962256245 and parameters: {'lambda_l1': 3.2916630559915814e-07, 'lambda_l2': 4.8235215451708035e-06, 'num_leaves': 79, 'feature_fraction': 0.5827875744665946, 'min_child_samples': 91, 'boosting_type': 'goss'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:31,912] Trial 367 finished with value: 0.7361553658578837 and parameters: {'lambda_l1': 3.917497038275226e-08, 'lambda_l2': 0.0002635161595174422, 'num_leaves': 8, 'feature_fraction': 0.6036804701078117, 'min_child_samples': 99, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:32,193] Trial 368 finished with value: 0.7479058901620554 and parameters: {'lambda_l1': 7.584873593604501e-05, 'lambda_l2': 0.0001693458850138491, 'num_leaves': 175, 'feature_fraction': 0.6215310416331119, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:32,315] Trial 369 finished with value: 0.7356150611188244 and parameters: {'lambda_l1': 5.061454803361293e-07, 'lambda_l2': 0.00031039267864027564, 'num_leaves': 14, 'feature_fraction': 0.594426467040319, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:32,449] Trial 370 finished with value: 0.7354722707554405 and parameters: {'lambda_l1': 1.2461852555974109e-07, 'lambda_l2': 8.678676227765952e-05, 'num_leaves': 20, 'feature_fraction': 0.4798272702775588, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:32,563] Trial 371 finished with value: 0.7366029217760705 and parameters: {'lambda_l1': 2.3138765278355507e-07, 'lambda_l2': 0.16002992689761328, 'num_leaves': 11, 'feature_fraction': 0.5717724898632489, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:32,683] Trial 372 finished with value: 0.7538101567269908 and parameters: {'lambda_l1': 9.24057291760945e-08, 'lambda_l2': 0.0004776183415115609, 'num_leaves': 6, 'feature_fraction': 0.6354116982603367, 'min_child_samples': 98, 'boosting_type': 'dart'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:32,877] Trial 373 finished with value: 0.7401008094651504 and parameters: {'lambda_l1': 1.644369750393058e-06, 'lambda_l2': 0.00013132150745203856, 'num_leaves': 40, 'feature_fraction': 0.7448562079891416, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,010] Trial 374 finished with value: 0.734884878600426 and parameters: {'lambda_l1': 3.211253489763838e-07, 'lambda_l2': 0.00020989745297057933, 'num_leaves': 17, 'feature_fraction': 0.609310991964511, 'min_child_samples': 54, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,171] Trial 375 finished with value: 0.7399868162081646 and parameters: {'lambda_l1': 5.325779050527423e-07, 'lambda_l2': 0.000397263458643223, 'num_leaves': 29, 'feature_fraction': 0.6253086830542282, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,317] Trial 376 finished with value: 0.7371121872001105 and parameters: {'lambda_l1': 1.608056774816816e-07, 'lambda_l2': 0.0006457041981710473, 'num_leaves': 23, 'feature_fraction': 0.6435972947966384, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,430] Trial 377 finished with value: 0.7364624248985416 and parameters: {'lambda_l1': 6.521499147995669e-08, 'lambda_l2': 0.0001847163192459599, 'num_leaves': 12, 'feature_fraction': 0.5896208523830098, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,711] Trial 378 finished with value: 0.7462213864307048 and parameters: {'lambda_l1': 7.992185825260416e-07, 'lambda_l2': 0.00011865459555148898, 'num_leaves': 107, 'feature_fraction': 0.6106907252133303, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,788] Trial 379 finished with value: 0.7477693172896502 and parameters: {'lambda_l1': 2.2445661734075987e-07, 'lambda_l2': 0.0003197788599944703, 'num_leaves': 2, 'feature_fraction': 0.6353211988426679, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:33,915] Trial 380 finished with value: 0.7367230996659269 and parameters: {'lambda_l1': 3.9762149921326365e-07, 'lambda_l2': 7.213187608624256e-05, 'num_leaves': 17, 'feature_fraction': 0.5997232831810456, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:34,022] Trial 381 finished with value: 0.7350304706525879 and parameters: {'lambda_l1': 1.3657890999949907e-07, 'lambda_l2': 3.2336469679964196e-05, 'num_leaves': 9, 'feature_fraction': 0.6208476582171102, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:34,262] Trial 382 finished with value: 0.7467419123221356 and parameters: {'lambda_l1': 2.956450541281392e-07, 'lambda_l2': 0.00022378245012237097, 'num_leaves': 64, 'feature_fraction': 0.5796014544922687, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:34,472] Trial 383 finished with value: 0.7427458663504435 and parameters: {'lambda_l1': 6.768681559571384e-07, 'lambda_l2': 0.0001425739134303169, 'num_leaves': 50, 'feature_fraction': 0.5540672439908986, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:34,762] Trial 384 finished with value: 0.7494751439953989 and parameters: {'lambda_l1': 2.490956092176943e-06, 'lambda_l2': 0.0003182844267626271, 'num_leaves': 140, 'feature_fraction': 0.6488748932669176, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:34,912] Trial 385 finished with value: 0.7377649939455564 and parameters: {'lambda_l1': 1.196375604126895e-06, 'lambda_l2': 0.0006682760641903314, 'num_leaves': 23, 'feature_fraction': 0.6134690245574079, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,034] Trial 386 finished with value: 0.7343870606464741 and parameters: {'lambda_l1': 8.710054191108673e-08, 'lambda_l2': 3.9046612862649157, 'num_leaves': 14, 'feature_fraction': 0.6323297868758492, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,205] Trial 387 finished with value: 0.7394912424425597 and parameters: {'lambda_l1': 5.130003899003821e-08, 'lambda_l2': 7.714890198606013, 'num_leaves': 33, 'feature_fraction': 0.6366768283170847, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,323] Trial 388 finished with value: 0.7358205095596595 and parameters: {'lambda_l1': 8.132391046794925e-08, 'lambda_l2': 5.6618354011546056e-05, 'num_leaves': 14, 'feature_fraction': 0.5667510494318329, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,431] Trial 389 finished with value: 0.7503215061398669 and parameters: {'lambda_l1': 8.280449755047984e-08, 'lambda_l2': 2.2003465886485324e-05, 'num_leaves': 8, 'feature_fraction': 0.5994249159128663, 'min_child_samples': 89, 'boosting_type': 'goss'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,566] Trial 390 finished with value: 0.7365904751493292 and parameters: {'lambda_l1': 2.3037818067872484e-08, 'lambda_l2': 0.07557946329533806, 'num_leaves': 19, 'feature_fraction': 0.6278740005859276, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,714] Trial 391 finished with value: 0.7376516318322122 and parameters: {'lambda_l1': 0.0003861028565227022, 'lambda_l2': 0.2678435329924069, 'num_leaves': 27, 'feature_fraction': 0.4114218427752663, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,833] Trial 392 finished with value: 0.7354027858587853 and parameters: {'lambda_l1': 4.154814669212535e-08, 'lambda_l2': 1.3350803220721633e-06, 'num_leaves': 13, 'feature_fraction': 0.6538734233857264, 'min_child_samples': 98, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:35,974] Trial 393 finished with value: 0.737006252486679 and parameters: {'lambda_l1': 1.915897752113017e-07, 'lambda_l2': 7.102949135351164e-06, 'num_leaves': 21, 'feature_fraction': 0.6095237489400519, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:36,098] Trial 394 finished with value: 0.753109799628067 and parameters: {'lambda_l1': 5.105267592124731e-07, 'lambda_l2': 3.334374988116713, 'num_leaves': 7, 'feature_fraction': 0.5927308322609682, 'min_child_samples': 96, 'boosting_type': 'dart'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:36,230] Trial 395 finished with value: 0.7359733443834378 and parameters: {'lambda_l1': 0.02150093519059264, 'lambda_l2': 8.468527287023241e-05, 'num_leaves': 17, 'feature_fraction': 0.6202823814315053, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:36,397] Trial 396 finished with value: 0.7358314684685368 and parameters: {'lambda_l1': 1.1494365978312822e-07, 'lambda_l2': 0.616960466497662, 'num_leaves': 11, 'feature_fraction': 0.6385469671082774, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:36,473] Trial 397 finished with value: 0.7473478693738239 and parameters: {'lambda_l1': 3.6815494745972456e-07, 'lambda_l2': 0.01862870332817048, 'num_leaves': 2, 'feature_fraction': 0.5857489861833332, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:36,622] Trial 398 finished with value: 0.7372064314287601 and parameters: {'lambda_l1': 0.0001052225136264009, 'lambda_l2': 0.00012792937854860198, 'num_leaves': 24, 'feature_fraction': 0.6026207859343331, 'min_child_samples': 89, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# [I 2022-11-12 17:37:36,749] Trial 399 finished with value: 0.7368760621782788 and parameters: {'lambda_l1': 2.3093195640972947e-07, 'lambda_l2': 2.9951752717088233e-06, 'num_leaves': 16, 'feature_fraction': 0.6202734852918832, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 136 with value: 0.7328815716145676.
# Number of finished trials: 400
# Best trial (136):
# Value: 0.7328815716145676
# Params:
# {'lambda_l1': 1.1885678531902196e-06, 'lambda_l2': 0.00010800373677674506, 'num_leaves': 12, 'feature_fraction': 0.6262130543158102, 'min_child_samples': 87, 'boosting_type': 'gbdt'}

# %%
dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
lgbm = lgb.train(
    params={**get_lgb_params()[1], **{'lambda_l1': 0.026873437304227192, 'lambda_l2': 9.270495297846024, 'num_leaves': 7, 'feature_fraction': 0.8633788253368204, 'min_child_samples': 81, 'boosting_type': 'gbdt'}},
    train_set=dtrain_lgb,
    valid_sets=dvalid_lgb,
    verbose_eval=False
)

# %%
# Catboost validation prediction
y_pred_val_cb = np.expm1(cbm.predict(X_val_cb))
print('Catboost validation score:', rmsle(np.expm1(y_val), y_pred_val_cb))

# Catboost validation prediction
y_val_pred_lgb = np.expm1(lgbm.predict(X_val_lgb))
print('LightGBM validation score:', rmsle(np.expm1(y_val), y_val_pred_lgb))
# Out:
# LightGBM validation score: 0.7254945537998989
# LightGBM validation score: 0.7375281967134544

# %%
y_pred_test_cb = np.expm1(cbm.predict(X_test_cb))
y_pred_test_lgb = np.expm1(lgbm.predict(X_test_lgb))

test_stack = np.array([y_pred_test_cb, y_pred_test_lgb])
stack_test_avg = np.mean(test_stack, axis=0)

submission = pd.read_csv('data/sample_submission.csv')
submission['predicted'] = stack_test_avg
submission.to_csv('submissions/cb_lgb_automl_stacked2.csv', index=False)
