# %% [markdown]
# # 1. Initial setup

# %%
# %load_ext autoreload

# %% [markdown]
# ## 1.1 Install required packages
#
# We ran into some issues with some of the geo related packages, such as geopandas, on certain machines. If the code does not run on your machine, you can comment out the lines commented with "# GEO PROBLEM HERE", and it will hopefully allow the code to run. This may of course impact the final score.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: attrs==22.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: autopep8==2.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: backcall==0.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: catboost==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: certifi==2022.9.24 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2022.9.24)
# Requirement already satisfied: click==8.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (8.1.3)
# Requirement already satisfied: click-plugins==1.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: cligj==0.7.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: colorama==0.4.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: contourpy==1.0.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (1.0.6)
# Requirement already satisfied: cycler==0.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (0.11.0)
# Requirement already satisfied: Cython==0.29.28 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.29.28)
# Requirement already satisfied: debugpy==1.6.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: decorator==5.1.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: entrypoints==0.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.4)
# Requirement already satisfied: executing==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: Fiona==1.8.22 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (1.8.22)
# Requirement already satisfied: fonttools==4.38.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (4.38.0)
# Requirement already satisfied: gensim==4.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (4.2.0)
# Requirement already satisfied: geographiclib==1.52 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (1.52)
# Requirement already satisfied: geopandas==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: geopy==2.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (2.2.0)
# Requirement already satisfied: graphviz==0.20.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (0.20.1)
# Requirement already satisfied: ipykernel==6.17.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (6.17.0)
# Requirement already satisfied: ipython==8.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (8.6.0)
# Requirement already satisfied: jedi==0.18.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (0.18.1)
# Requirement already satisfied: joblib==1.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: jupyter_client==7.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (7.4.4)
# Requirement already satisfied: jupyter_core==4.11.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (4.11.2)
# Requirement already satisfied: kiwisolver==1.4.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (1.4.4)
# Requirement already satisfied: matplotlib==3.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (3.6.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (0.1.6)
# Requirement already satisfied: munch==2.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (2.5.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (1.5.6)
# Requirement already satisfied: numpy==1.23.4 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (1.23.4)
# Requirement already satisfied: packaging==21.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (21.3)
# Requirement already satisfied: pandas==1.5.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (1.5.1)
# Requirement already satisfied: parso==0.8.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (0.7.5)
# Requirement already satisfied: Pillow==9.3.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (9.3.0)
# Requirement already satisfied: plotly==5.11.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (5.11.0)
# Requirement already satisfied: prompt-toolkit==3.0.31 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (3.0.31)
# Requirement already satisfied: psutil==5.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (5.9.3)
# Requirement already satisfied: pure-eval==0.2.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (0.2.2)
# Requirement already satisfied: pyarrow==10.0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (10.0.0)
# Requirement already satisfied: pycodestyle==2.9.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.9.1)
# Requirement already satisfied: pygeos==0.13 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.13)
# Requirement already satisfied: Pygments==2.13.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (2.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (3.0.9)
# Requirement already satisfied: pyproj==3.4.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (3.4.0)
# Requirement already satisfied: python-dateutil==2.8.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2.8.2)
# Requirement already satisfied: pytz==2022.6 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (2022.6)
# Requirement already satisfied: pyzmq==24.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (24.0.1)
# Requirement already satisfied: scikit-learn==1.1.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (1.1.3)
# Requirement already satisfied: scipy==1.9.3 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (1.9.3)
# Requirement already satisfied: seaborn==0.12.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (0.12.1)
# Requirement already satisfied: Shapely==1.8.5.post1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (1.8.5.post1)
# Requirement already satisfied: six==1.16.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (1.16.0)
# Requirement already satisfied: sklearn==0.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (0.0)
# Requirement already satisfied: smart-open==6.2.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.2.0)
# Requirement already satisfied: stack-data==0.6.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (0.6.0)
# Requirement already satisfied: tenacity==8.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (8.1.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (3.1.0)
# Requirement already satisfied: tomli==2.0.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (2.0.1)
# Requirement already satisfied: tornado==6.2 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (6.2)
# Requirement already satisfied: tqdm==4.64.1 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (4.64.1)
# Requirement already satisfied: traitlets==5.5.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (5.5.0)
# Requirement already satisfied: wcwidth==0.2.5 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 69)) (0.2.5)
# Requirement already satisfied: xgboost==1.7.0 in ./venv/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (1.7.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from Fiona==1.8.22->-r requirements.txt (line 18)) (44.0.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in ./venv/lib/python3.8/site-packages (from ipython==8.6.0->-r requirements.txt (line 26)) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython==8.6.0->-r requirements.txt (line 26)) (0.7.0)

# %% [markdown]
# ## 1.2 Import packages and data

# %%
# %autoreload

import warnings
import os.path
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import geopy
import os
import shutil
import geopandas as gpd
import catboost as cb
import optuna
import lightgbm as lgb
import geopandas as gpd

from pyproj import Geod
from shapely import wkt
from shapely.geometry import Point, LineString
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_log_error
from typing import Callable, Dict, List, Tuple
from catboost.utils import get_gpu_device_count
from tqdm import tqdm

tqdm.pandas()

warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None  # default='warn'

SEED = 23

spatial = pd.read_csv('data/grunnkrets_norway_stripped.csv')
age = pd.read_csv('data/grunnkrets_age_distribution.csv')
income = pd.read_csv('data/grunnkrets_income_households.csv').set_index(['grunnkrets_id', 'year']).add_prefix('income_').reset_index()
households = pd.read_csv('data/grunnkrets_households_num_persons.csv')
submission = pd.read_csv('data/sample_submission.csv')
plaace = pd.read_csv('data/plaace_hierarchy.csv')
busstops = pd.read_csv('data/busstops_norway.csv')

train = pd.read_csv('data/stores_train.csv')
train_extra = pd.read_csv('data/stores_extra.csv')
test = pd.read_csv('data/stores_test.csv') 

submission = pd.read_csv('data/sample_submission.csv')  # Please do not delete this file

# %% [markdown]
# Create geopandas version of some of the datasets:

# %%
busstops_geo = gpd.GeoDataFrame(busstops, geometry=busstops.geometry.apply(wkt.loads))

train_geo = gpd.GeoDataFrame(train[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train.lon, train.lat)).drop(columns=['lon', 'lat'])
train_geo = train_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

train_geo_extra = gpd.GeoDataFrame(train_extra[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(train_extra.lon, train_extra.lat)).drop(columns=['lon', 'lat'])
train_geo_extra = train_geo_extra.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

test_geo = gpd.GeoDataFrame(test[['store_id', 'lon','lat']], geometry=gpd.points_from_xy(test.lon, test.lat)).drop(columns=['lon', 'lat'])
test_geo = test_geo.set_crs('epsg:4326', allow_override=True).to_crs('epsg:3857')

# %% [markdown]
# ## 1.2 Helper functions

# %%
def rmsle(y_true, y_pred):
    y_pred[y_pred < 0] = 0 + 1e-6
    y_true[y_true < 0] = 0 + 1e-6
    return np.sqrt(mean_squared_log_error(y_true, y_pred))


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def to_categorical(df: pd.DataFrame):
    for cat_col in df.select_dtypes(include=[object]).columns:
        df[cat_col] = df[cat_col].astype('category')
    return df


def object_encoder(df: pd.DataFrame):
    enc = OrdinalEncoder()
    obj_cols = df.select_dtypes(include=[object]).columns
    df[obj_cols] = enc.fit_transform(df[obj_cols])
    return df


def nan_to_string(df: pd.DataFrame):
    nan = '#N/A'
    cols = df[df.columns[df.isna().any()]].columns
    df[cols] = df[cols].fillna(nan)
    return df


def meter_distance(lat1, lon1, lat2, lon2):
    line_string = LineString([Point(lon1, lat1), Point(lon2, lat2)])
    geod = Geod(ellps="WGS84")
    return geod.geometry_length(line_string)


def add_city_centre_dist(X: pd.DataFrame):
    old_shape = X.shape

    city_centres = X.groupby(['municipality_name'])[['lat', 'lon']].apply(lambda x: x.sum() / (x.count()))[['lat', 'lon']]
    X = X.merge(city_centres, on=['municipality_name'], how='left', suffixes=(None, '_center'))
    assert X.shape[0] == old_shape[0]

    X.fillna(value={'lat_center': X.lat, 'lon_center': X.lon}, inplace=True)

    X['dist_to_center'] = X.apply(lambda row: meter_distance(row.lat, row.lon, row.lat_center, row.lon_center), axis=1)
    assert X.shape[0] == old_shape[0]

    return X


def group_ages(age: pd.DataFrame, age_ranges: List[Tuple[int, int]]):
    age_new = age[['grunnkrets_id', 'year']].drop_duplicates(subset=['grunnkrets_id'], keep='last')

    for rng in age_ranges:
        cols = [f'age_{age}' for age in range(rng[0], rng[1] + 1)]
        rng_sum = age[cols].sum(axis=1).astype(int)
        age_new[f'age_{rng[0]}_{rng[-1]}'] = rng_sum

    age = age.drop_duplicates(subset='grunnkrets_id').drop(columns=['year', *(f'age_{age}' for age in range(0, 91))], axis=1)
    age = age.merge(age_new.drop(columns=['year']), on='grunnkrets_id')

    return age


def only_latest_data(df: pd.DataFrame):
    df = df.sort_values(by='year', ascending=False)
    df = df.drop_duplicates(subset='grunnkrets_id', keep='first')
    return df


def clean_out_nan_heavy_rows(df: pd.DataFrame, age, age_ranges, spatial_2016, income_2016, households_2016):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_2016.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_2016.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df2[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna()) # df2.age_0_19.isna() | 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


def create_busstops_files():
    """
    Creates a .parquet file that stores info aboute the number of busstops within a 1 kilometer
    radius of a given store, as well as the number of stops within the different importance categories.  
    """

    def bus_fields(row: pd.Series):
        output_dict = {}
        gpd.options.use_pygeos = True
        
        stops_with_dist = busstops[busstops_geo.distance(row.geometry) < 1000]
        output_dict['bus_stops_count'] = len(stops_with_dist)
        
        output_dict.update(stops_with_dist.importance_level.value_counts().reindex(
            busstops_geo.importance_level.unique(), fill_value=0
        ).to_dict())
        
        return output_dict

    train_with_extras_bus = pd.concat([train_geo, train_geo_extra], ignore_index=True)

    train_with_extras_bus = train_with_extras_bus.join(train_with_extras_bus.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    train_with_extras_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_train.parquet')

    test_bus = test_geo.join(test_geo.progress_apply(lambda row: bus_fields(row), axis=1, result_type='expand'))
    test_bus.to_parquet('derived_data/stores_bus_stops_lt_1km_test.parquet')


def create_stores_in_vicinity_files():
    """
    Creates a .parquet file that stores info aboute the number of other stores within a 1 kilometer
    radius of a given store.
    """

    train_with_extras = pd.concat([train_geo, train_geo_extra], ignore_index=True)[['store_id', 'geometry']]

    def store_count_in_vicinity(row: pd.Series):
        stores_in_vicinity = train_with_extras[train_with_extras.distance(row.geometry) < 1000]
        return {'stores_count_lt_1km': len(stores_in_vicinity)}

    train_with_extras_vicinity = train_with_extras.join(train_with_extras.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    train_with_extras_vicinity.to_parquet('derived_data/stores_count_lt_1km_train.parquet')

    test_vicinity = test_geo.join(test_geo.progress_apply(lambda row: store_count_in_vicinity(row), axis=1, result_type='expand'))
    test_vicinity.to_parquet('derived_data/stores_count_lt_1km_test.parquet')

# %% [markdown]
# # 2. Data cleaning

# %% [markdown]
# The train and test data only contains data from 2016, so for the other datasets with an age column
# we only use the values from 2016, where possible.

# %%
age_ranges = [
    (0, 19),
    (20, 39),
    (40, 59),
    (60, 79),
    (80, 90),
]

spatial_latest = only_latest_data(spatial)
income_latest = only_latest_data(income)
households_latest = only_latest_data(households)

train_spatial = train.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
muni_avg_revenue = train_spatial.groupby(by='municipality_name', as_index=False)['revenue'].mean()

# %% [markdown]
# Futhermore, we noticed that a number of rows in the train and test datasets didn't have

# %%
def clean(df: pd.DataFrame, min_val=0, max_val=100):
    print('Length of data frame:', len(df))
    df = df[(df.revenue > min_val) & (df.revenue < max_val)]
    print('Length after removing extreme values and zero revenue retail stores:',  len(df))
    return df.drop(columns=['revenue']), df.revenue


def clean_out_nan_heavy_rows(df: pd.DataFrame):
    """Cleans out rows that have no match in the age, spatial, income or household datasets."""

    # df2 = df.merge(group_ages(age, age_ranges), on='grunnkrets_id', how='left')
    df2 = df.merge(spatial_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(income_latest.drop(columns=['year']), on='grunnkrets_id', how='left')
    df2 = df2.merge(households_latest.drop(columns=['year']), on='grunnkrets_id', how='left')

    df_cleaned = df[
        ~(df2.couple_children_0_to_5_years.isna() | df2.grunnkrets_name.isna() | df2.income_all_households.isna())  # | df2.age_0_19.isna() 
    ]

    print(f'Cleaned out {len(df) - len(df_cleaned)} out of {len(df)} rows.')

    return df_cleaned


train = clean_out_nan_heavy_rows(train)
label_name = 'revenue'
X = train.drop(columns=[label_name])
y = train[label_name]

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=.8, random_state=SEED)
X_train, y_train = clean(pd.merge(X_train, y_train, left_index=True, right_index=True))

y_train = np.log1p(y_train)
y_val = np.log1p(y_val)
# Out:
# Cleaned out 127 out of 12859 rows.
# Length of data frame: 10185
# Length after removing extreme values and zero revenue retail stores: 9947

# %% [markdown]
# # 3. Feature generation

# %% [markdown]
# Create files for busstops and stores in vicinity of each store:

# %%
# !mkdir -p derived_data

if len(os.listdir('derived_data')) == 0:
    create_busstops_files()
    create_stores_in_vicinity_files()

# %%
def generate_features(df: pd.DataFrame, data_origin: str, predictor: str = ''):
    # Define datasets to be merged
    age_groups_merge = group_ages(age, age_ranges)
    spatial_merge = spatial_latest.drop(columns=['year'])
    income_merge = income_latest.drop(columns=['year'])
    households_merge = households_latest.drop(columns=['year'])
    plaace_merge = plaace.drop_duplicates(subset='plaace_hierarchy_id')
    bus_data_train_merge = gpd.read_parquet(f'derived_data/stores_bus_stops_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])
    stores_vicinity_merge = gpd.read_parquet(f'derived_data/stores_count_lt_1km_{data_origin}.parquet').drop(columns=['geometry'])

    # Merge datasets
    df = df.merge(age_groups_merge, on='grunnkrets_id', how='left')
    df = df.merge(spatial_merge, on='grunnkrets_id', how='left')
    df = df.merge(income_merge, on='grunnkrets_id', how='left')
    df = df.merge(households_merge, on='grunnkrets_id', how='left')
    df = df.merge(plaace_merge, how='left')
    df = df.merge(bus_data_train_merge, on='store_id', how='left')
    df = df.merge(stores_vicinity_merge, on='store_id', how='left')
    df = add_city_centre_dist(df).drop(columns=['lon_center', 'lat_center'])

    # Transformations and some post-merge cleaning
    df.stores_count_lt_1km = np.log(df.stores_count_lt_1km)
    df[age_groups_merge.columns] = df[age_groups_merge.columns].fillna(0)
    
    # Handle categories for different predictors
    if predictor == 'xgb':
        df = object_encoder(df)
    elif predictor == 'cb':
        df = nan_to_string(df)
    elif predictor == 'lgb':
        df = to_categorical(df)
    else: 
        raise ValueError('Invalid predictor')

    features = [
        'store_name', 
        'mall_name', 
        'chain_name',
        'address', 
        'lat', 'lon',
        
        *age_groups_merge.drop(columns=['grunnkrets_id']).columns,
        *income_merge.drop(columns=['grunnkrets_id']).columns,
        *households_merge.drop(columns=['grunnkrets_id']).columns,
        'lv1_desc', 'lv2_desc', 'sales_channel_name', 
        *bus_data_train_merge.drop(columns=['store_id']).columns,
        *stores_vicinity_merge.drop(columns=['store_id']).columns,
        'dist_to_center'
    ]

    return df[features]

# %%
# Features adapted to Catboost
X_train_cb = generate_features(X_train, data_origin='train', predictor='cb')
X_val_cb = generate_features(X_val, data_origin='train', predictor='cb')
X_test_cb = generate_features(test, data_origin='test', predictor='cb')

# Features adapted to LightGBM
X_train_lgb = generate_features(X_train, data_origin='train', predictor='lgb')
X_val_lgb = generate_features(X_val, data_origin='train', predictor='lgb')
X_test_lgb = generate_features(test, data_origin='test', predictor='lgb')

# %% [markdown]
# # 4. Hyper parameter tuning

# %% [markdown]
# ### Preparing pools and parameter grid for Catboost

# %%
def get_cb_pools():
    text_features = ['store_name', 'address', 'sales_channel_name'] 
    cat_features = ['mall_name', 'chain_name', 'lv1_desc', 'lv2_desc']

    train_pool = cb.Pool(
        X_train_cb,
        y_train,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    valid_pool = cb.Pool(
        X_val_cb,
        y_val,
        cat_features=cat_features,
        text_features=text_features,
        feature_names=list(X_train_cb)
    )

    return train_pool, valid_pool


def get_cb_params(trial: optuna.Trial = None):
    gpu_count = get_gpu_device_count()
    non_tunable_cb_params = {
        'objective': 'RMSE',
        'eval_metric': 'RMSE',
        'task_type': 'GPU' if gpu_count else 'CPU', 
        'devices': f'0:{gpu_count}',
        'random_seed': SEED
    }

    if trial is None:
        return 'cb', non_tunable_cb_params
    
    tunable_params = {
        'depth': trial.suggest_int('depth', 4, 9),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 2, 6),
        # 'iterations': trial.suggest_int('iterations', 1000, 2000),
        # 'learning_rate': trial.suggest_categorical('learning_rate', 0.1, 0.5)
    }

    return 'cb', non_tunable_cb_params, tunable_params

# %% [markdown]
# ### Preparing DMatrices and parameter grid for LightGBM

# %%
def get_lgb_dmatrices():
    dtrain = lgb.Dataset(X_train_lgb, y_train, params={'verbose': -1}, free_raw_data=False)
    dvalid = lgb.Dataset(X_val_lgb, y_val, params={'verbose': -1}, free_raw_data=False)
    return dtrain, dvalid


rmsle_scorer = make_scorer(lambda y, y_true: rmsle(y, y_true), greater_is_better=False)

def get_lgb_params(trial: optuna.Trial = None):
    non_tunable_lgb_params = {
        'objective': 'rmse',
        'verbose': -1,
        'seed': 1
    }

    if trial is None:
        return 'lgb', non_tunable_lgb_params

    tunable_params = {
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'goss', 'dart']),
    }

    if tunable_params['boosting_type'] != 'goss':
        tunable_params["bagging_fraction"]: trial.suggest_float("bagging_fraction", 0.4, 1.0)
        tunable_params["bagging_freq"]: trial.suggest_int("bagging_freq", 1, 7)

    return 'lgb', non_tunable_lgb_params, tunable_params

# %% [markdown]
# ### Hyper parameter tuning with Optuna

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

def objective(trial: optuna.Trial, param_grid_fn: Callable) -> float:
    model_name, non_tunable_params, tunable_params = param_grid_fn(trial)
  
    if model_name == 'cb':
        if tunable_params['bootstrap_type'] == 'Bayesian': 
            tunable_params['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)
        elif tunable_params['bootstrap_type'] == 'Bernoulli':
            tunable_params['subsample'] = trial.suggest_float('subsample', 0.1, 1, log=True)

        cbr = cb.CatBoostRegressor(**non_tunable_params, **tunable_params) 
        train_pool, valid_pool = get_cb_pools()
        cbr.fit(
            train_pool,
            eval_set=[(X_val_cb, y_val)],
            verbose=0,
            early_stopping_rounds=100,
        )
        y_pred = cbr.predict(X_val_cb)
    
    elif model_name == 'lgb':
        dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
        lgbr = lgb.train(
            params={**non_tunable_params, **tunable_params},
            train_set=dtrain_lgb,
            valid_sets=dvalid_lgb,
            verbose_eval=False,
        )
        y_pred = lgbr.predict(X_val_lgb)

    score = rmsle(np.expm1(y_val), np.expm1(y_pred))

    return score


def get_hyper_parameters(param_grid_fn: Callable, n_trials=100):
    study = optuna.create_study(
        study_name='hyperparam-tuning',
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), 
        direction='minimize'
    )
    objective_fn = lambda trial: objective(trial, param_grid_fn)
    study.optimize(objective_fn, n_trials=n_trials, timeout=900) 

    print('Number of finished trials: {}'.format(len(study.trials)))
    
    trial = study.best_trial
    print(f'Best trial ({trial.number}):')
    print('Value:', trial.value)
    print('Params:')
    print(trial.params)

    return param_grid_fn()[1], trial.params

# %% [markdown]
# # 5. Training step

# %% [markdown]
# ### Making predictions with Catboost

# %%
non_tunable_cb_params, tuned_params = get_hyper_parameters(get_cb_params, n_trials=30)
train_pool, valid_pool = get_cb_pools()
cbm = cb.CatBoostRegressor(**non_tunable_cb_params, **tuned_params, iterations=1000) 
cbm.fit(train_pool, eval_set=valid_pool, verbose=50, plot=True, early_stopping_rounds=50)
# Out:
# [I 2022-11-13 00:20:24,003] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-13 00:20:59,969] Trial 0 finished with value: 0.7251078102322673 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.1261632129852615, 'subsample': 0.8257793106611021}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:21:24,129] Trial 1 finished with value: 0.7752005239309969 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.420729736709516, 'bagging_temperature': 9.40543091109802}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:21:35,115] Trial 2 finished with value: 0.7332051152663198 and parameters: {'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.7450922227787435, 'subsample': 0.2889057238700009}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:21:59,237] Trial 3 finished with value: 0.7667908750517393 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.349916872790958, 'bagging_temperature': 7.696889527155545}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:22:34,604] Trial 4 finished with value: 0.7262537523102071 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.516586432197981, 'bagging_temperature': 1.0985319975707286}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:22:49,289] Trial 5 finished with value: 0.7367660215770476 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 3.828540880158755}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:22:58,571] Trial 6 finished with value: 0.7701037715952038 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.554748979761608, 'bagging_temperature': 6.898956527179267}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:23:05,244] Trial 7 finished with value: 0.7538095721177245 and parameters: {'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 2.680032287495175, 'bagging_temperature': 5.737956206874726}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:23:27,525] Trial 8 finished with value: 0.733255657711869 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.774328461476107, 'subsample': 0.19338463658269103}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:24:03,655] Trial 9 finished with value: 0.7327739684593857 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 2.558208375801036, 'subsample': 0.16380016679054699}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:24:09,456] Trial 10 finished with value: 0.7594534042940843 and parameters: {'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 4.979456986372216}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:24:22,762] Trial 11 finished with value: 0.7262835155196021 and parameters: {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.514731975910039, 'subsample': 0.9802995940716664}. Best is trial 0 with value: 0.7251078102322673.
# [I 2022-11-13 00:24:57,790] Trial 12 finished with value: 0.725015479415308 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.905524530999218, 'bagging_temperature': 0.3261203914373796}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:25:12,716] Trial 13 finished with value: 0.7263847484491914 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.939463633961062, 'subsample': 0.810027359851088}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:25:25,323] Trial 14 finished with value: 0.7420356839666897 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 4.998204807842931}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:25:35,655] Trial 15 finished with value: 0.7293749353334449 and parameters: {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 3.6469899446781806, 'bagging_temperature': 0.9758589709514293}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:25:50,832] Trial 16 finished with value: 0.7277775700475821 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 5.954460382561495, 'subsample': 0.5832511069684225}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:26:26,390] Trial 17 finished with value: 0.7346657715411309 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.860329907386341, 'bagging_temperature': 3.2922400857579364}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:26:34,475] Trial 18 finished with value: 0.7303506032611543 and parameters: {'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 3.448735155730131, 'subsample': 0.503037598533607}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:26:42,673] Trial 19 finished with value: 0.7431821081597728 and parameters: {'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 2.0483957099513077}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:26:52,067] Trial 20 finished with value: 0.7401885753336717 and parameters: {'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.645277598297687, 'subsample': 0.11030907171888273}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:27:28,439] Trial 21 finished with value: 0.7254886303192717 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.4043196632672625, 'bagging_temperature': 0.11776202964853688}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:28:05,644] Trial 22 finished with value: 0.7251416565184746 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.164365208068011, 'bagging_temperature': 0.030414241678608178}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:28:29,050] Trial 23 finished with value: 0.7375312873329107 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.25318222758451, 'bagging_temperature': 3.2433306819538448}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:29:04,998] Trial 24 finished with value: 0.7339966208447205 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.788109371866282, 'bagging_temperature': 2.7926772977718466}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:29:40,422] Trial 25 finished with value: 0.7315819114109512 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 4.2199342641381445, 'bagging_temperature': 1.8533602558434372}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:29:49,568] Trial 26 finished with value: 0.747803052555877 and parameters: {'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.145871751558923, 'bagging_temperature': 4.511703094431818}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:30:04,456] Trial 27 finished with value: 0.7291277902927831 and parameters: {'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'l2_leaf_reg': 4.721077831716105, 'subsample': 0.4027987460321408}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:30:39,907] Trial 28 finished with value: 0.7250628688770401 and parameters: {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.642433537149827, 'bagging_temperature': 0.238036777397649}. Best is trial 12 with value: 0.725015479415308.
# [I 2022-11-13 00:30:54,348] Trial 29 finished with value: 0.7384181274333966 and parameters: {'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'l2_leaf_reg': 5.777072763386803}. Best is trial 12 with value: 0.725015479415308.
# Number of finished trials: 30
# Best trial (12):
# Value: 0.725015479415308
# Params:
# {'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'l2_leaf_reg': 5.905524530999218, 'bagging_temperature': 0.3261203914373796}
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.9764669	test: 0.9982183	best: 0.9982183 (0)	total: 47.7ms	remaining: 47.6s
# 50:	learn: 0.7443888	test: 0.7779448	best: 0.7779448 (50)	total: 2.33s	remaining: 43.4s
# 100:	learn: 0.7105999	test: 0.7509939	best: 0.7509939 (100)	total: 4.46s	remaining: 39.7s
# 150:	learn: 0.6979159	test: 0.7428328	best: 0.7428328 (150)	total: 6.41s	remaining: 36s
# 200:	learn: 0.6898355	test: 0.7377910	best: 0.7377910 (200)	total: 8.27s	remaining: 32.9s
# 250:	learn: 0.6840371	test: 0.7348595	best: 0.7348485 (247)	total: 10.1s	remaining: 30.1s
# 300:	learn: 0.6795774	test: 0.7328234	best: 0.7328234 (300)	total: 11.8s	remaining: 27.5s
# 350:	learn: 0.6750344	test: 0.7310707	best: 0.7310707 (350)	total: 13.5s	remaining: 25s
# 400:	learn: 0.6708519	test: 0.7295380	best: 0.7295349 (399)	total: 15.2s	remaining: 22.6s
# 450:	learn: 0.6671446	test: 0.7284104	best: 0.7284104 (450)	total: 16.9s	remaining: 20.5s
# 500:	learn: 0.6637490	test: 0.7276630	best: 0.7276630 (500)	total: 18.5s	remaining: 18.5s
# 550:	learn: 0.6609515	test: 0.7270843	best: 0.7270843 (550)	total: 20.2s	remaining: 16.4s
# 600:	learn: 0.6585120	test: 0.7264285	best: 0.7264285 (600)	total: 21.8s	remaining: 14.5s
# 650:	learn: 0.6568011	test: 0.7263938	best: 0.7263440 (635)	total: 23.4s	remaining: 12.5s
# 700:	learn: 0.6541432	test: 0.7260916	best: 0.7259847 (679)	total: 25s	remaining: 10.7s
# 750:	learn: 0.6521095	test: 0.7256260	best: 0.7255567 (742)	total: 26.8s	remaining: 8.87s
# 800:	learn: 0.6502544	test: 0.7253615	best: 0.7253475 (789)	total: 28.5s	remaining: 7.07s
# 850:	learn: 0.6483538	test: 0.7252429	best: 0.7252122 (845)	total: 30.2s	remaining: 5.28s
# 900:	learn: 0.6463149	test: 0.7250709	best: 0.7250155 (895)	total: 31.9s	remaining: 3.5s
# bestTest = 0.7250155269
# bestIteration = 895
# Shrink model to first 896 iterations.

# %% [markdown]
# ### Making predictions with LightGBM

# %%
non_tunable_lgb_params, tunable_lgb_params = get_hyper_parameters(get_lgb_params, n_trials=400)
dtrain_lgb, dvalid_lgb = get_lgb_dmatrices()
lgbm = lgb.train(
    params={**non_tunable_lgb_params, **tunable_lgb_params},
    train_set=dtrain_lgb,
    valid_sets=dvalid_lgb,
    verbose_eval=False
)
# Out:
# [I 2022-11-13 00:31:28,510] A new study created in memory with name: hyperparam-tuning
# [I 2022-11-13 00:31:30,357] Trial 0 finished with value: 0.8048056826739513 and parameters: {'lambda_l1': 2.0367176512099482e-05, 'lambda_l2': 2.6313306813428173e-08, 'num_leaves': 170, 'feature_fraction': 0.907779689214821, 'min_child_samples': 10, 'boosting_type': 'goss'}. Best is trial 0 with value: 0.8048056826739513.
# [I 2022-11-13 00:31:30,614] Trial 1 finished with value: 0.7484584093373747 and parameters: {'lambda_l1': 0.0031154507362927586, 'lambda_l2': 1.3930591156383421e-08, 'num_leaves': 12, 'feature_fraction': 0.8008504298187424, 'min_child_samples': 51, 'boosting_type': 'dart'}. Best is trial 1 with value: 0.7484584093373747.
# [I 2022-11-13 00:31:30,977] Trial 2 finished with value: 0.7497006929311827 and parameters: {'lambda_l1': 8.97604657679639e-06, 'lambda_l2': 4.156419701539116e-06, 'num_leaves': 55, 'feature_fraction': 0.8446952926779483, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.7484584093373747.
# [I 2022-11-13 00:31:31,199] Trial 3 finished with value: 0.7482167054920974 and parameters: {'lambda_l1': 0.05067222804434501, 'lambda_l2': 1.1161876683099007e-05, 'num_leaves': 143, 'feature_fraction': 0.6964720666991417, 'min_child_samples': 89, 'boosting_type': 'goss'}. Best is trial 3 with value: 0.7482167054920974.
# [I 2022-11-13 00:31:31,476] Trial 4 finished with value: 0.7494302415955142 and parameters: {'lambda_l1': 3.2835546387626794e-07, 'lambda_l2': 6.569303607323757e-06, 'num_leaves': 32, 'feature_fraction': 0.8060373392311722, 'min_child_samples': 77, 'boosting_type': 'goss'}. Best is trial 3 with value: 0.7482167054920974.
# [I 2022-11-13 00:31:31,709] Trial 5 finished with value: 0.7412438343184209 and parameters: {'lambda_l1': 0.022671990468591613, 'lambda_l2': 1.7040020668678882e-05, 'num_leaves': 43, 'feature_fraction': 0.5363570575250927, 'min_child_samples': 95, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:32,722] Trial 6 finished with value: 0.7509241624509596 and parameters: {'lambda_l1': 0.3110159431998167, 'lambda_l2': 0.03775365346485815, 'num_leaves': 152, 'feature_fraction': 0.6378871150513648, 'min_child_samples': 73, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:32,985] Trial 7 finished with value: 0.7661784440410612 and parameters: {'lambda_l1': 1.2014221590528887e-05, 'lambda_l2': 7.506049538739987e-08, 'num_leaves': 111, 'feature_fraction': 0.6972231968862068, 'min_child_samples': 35, 'boosting_type': 'goss'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:33,613] Trial 8 finished with value: 0.7561886611304856 and parameters: {'lambda_l1': 0.44154886338801236, 'lambda_l2': 4.45979009150516e-08, 'num_leaves': 189, 'feature_fraction': 0.46383273699235916, 'min_child_samples': 46, 'boosting_type': 'dart'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:33,777] Trial 9 finished with value: 0.7523621403754059 and parameters: {'lambda_l1': 0.002731591272819453, 'lambda_l2': 1.6255715173607873e-07, 'num_leaves': 88, 'feature_fraction': 0.5956228378767426, 'min_child_samples': 94, 'boosting_type': 'goss'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:34,922] Trial 10 finished with value: 0.7415089249251166 and parameters: {'lambda_l1': 6.088663345100454, 'lambda_l2': 6.066943039034244, 'num_leaves': 237, 'feature_fraction': 0.41821160771286053, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:35,481] Trial 11 finished with value: 0.7468682079309562 and parameters: {'lambda_l1': 2.474344672383236, 'lambda_l2': 3.449365808229024, 'num_leaves': 238, 'feature_fraction': 0.40308635503134715, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 5 with value: 0.7412438343184209.
# [I 2022-11-13 00:31:35,773] Trial 12 finished with value: 0.7407779326684805 and parameters: {'lambda_l1': 8.12255692358361, 'lambda_l2': 0.001981633134057145, 'num_leaves': 254, 'feature_fraction': 0.5225412535894718, 'min_child_samples': 63, 'boosting_type': 'gbdt'}. Best is trial 12 with value: 0.7407779326684805.
# [I 2022-11-13 00:31:36,044] Trial 13 finished with value: 0.7486252317211158 and parameters: {'lambda_l1': 0.0128083113386049, 'lambda_l2': 0.0016172627893001198, 'num_leaves': 76, 'feature_fraction': 0.5348863731422296, 'min_child_samples': 29, 'boosting_type': 'gbdt'}. Best is trial 12 with value: 0.7407779326684805.
# [I 2022-11-13 00:31:36,342] Trial 14 finished with value: 0.7524429143482139 and parameters: {'lambda_l1': 0.000183196587577548, 'lambda_l2': 0.0007992140070801236, 'num_leaves': 214, 'feature_fraction': 0.5121108451601037, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 12 with value: 0.7407779326684805.
# [I 2022-11-13 00:31:36,672] Trial 15 finished with value: 0.7593747649246755 and parameters: {'lambda_l1': 1.3976141418393488e-08, 'lambda_l2': 0.13308407702557795, 'num_leaves': 111, 'feature_fraction': 0.5762819581118634, 'min_child_samples': 58, 'boosting_type': 'gbdt'}. Best is trial 12 with value: 0.7407779326684805.
# [I 2022-11-13 00:31:37,088] Trial 16 finished with value: 0.7579658220297819 and parameters: {'lambda_l1': 0.12335127659102552, 'lambda_l2': 5.6031658122399845e-05, 'num_leaves': 253, 'feature_fraction': 0.49802078307584796, 'min_child_samples': 61, 'boosting_type': 'gbdt'}. Best is trial 12 with value: 0.7407779326684805.
# [I 2022-11-13 00:31:37,541] Trial 17 finished with value: 0.7484472313727724 and parameters: {'lambda_l1': 9.561560268108348, 'lambda_l2': 0.013477482255905934, 'num_leaves': 197, 'feature_fraction': 0.6207061361826851, 'min_child_samples': 9, 'boosting_type': 'gbdt'}. Best is trial 12 with value: 0.7407779326684805.
# [I 2022-11-13 00:31:37,623] Trial 18 finished with value: 0.7383991503767485 and parameters: {'lambda_l1': 0.0004663503167786507, 'lambda_l2': 8.325865792169466e-05, 'num_leaves': 4, 'feature_fraction': 0.5452422576240165, 'min_child_samples': 39, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:38,107] Trial 19 finished with value: 0.7684537542141144 and parameters: {'lambda_l1': 0.0006156993651525132, 'lambda_l2': 0.0001440833573700262, 'num_leaves': 124, 'feature_fraction': 0.9881401444933557, 'min_child_samples': 33, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:38,243] Trial 20 finished with value: 0.751174274130362 and parameters: {'lambda_l1': 5.194892274845177e-07, 'lambda_l2': 1.1300733501273125e-06, 'num_leaves': 8, 'feature_fraction': 0.6644098658370576, 'min_child_samples': 21, 'boosting_type': 'dart'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:38,426] Trial 21 finished with value: 0.7414124238094919 and parameters: {'lambda_l1': 0.00046475846152637236, 'lambda_l2': 0.0025395419035681927, 'num_leaves': 39, 'feature_fraction': 0.5549940723140314, 'min_child_samples': 44, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:38,491] Trial 22 finished with value: 0.7475863566122892 and parameters: {'lambda_l1': 0.01335462340764262, 'lambda_l2': 8.321535432303156e-05, 'num_leaves': 2, 'feature_fraction': 0.4824777216907917, 'min_child_samples': 41, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:38,710] Trial 23 finished with value: 0.7452713682898234 and parameters: {'lambda_l1': 8.385313417032634e-05, 'lambda_l2': 2.5720436995926357e-05, 'num_leaves': 59, 'feature_fraction': 0.44997342916955424, 'min_child_samples': 61, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:38,885] Trial 24 finished with value: 0.7393518052482777 and parameters: {'lambda_l1': 0.025540714770642348, 'lambda_l2': 6.519172131284051e-07, 'num_leaves': 34, 'feature_fraction': 0.5520075191998174, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:39,225] Trial 25 finished with value: 0.753569786066193 and parameters: {'lambda_l1': 1.8059228264586658, 'lambda_l2': 5.516138234379723e-07, 'num_leaves': 84, 'feature_fraction': 0.7500148252699088, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:39,361] Trial 26 finished with value: 0.7395330773187826 and parameters: {'lambda_l1': 0.0025024747650656035, 'lambda_l2': 0.4798530285671923, 'num_leaves': 21, 'feature_fraction': 0.595544829779878, 'min_child_samples': 22, 'boosting_type': 'gbdt'}. Best is trial 18 with value: 0.7383991503767485.
# [I 2022-11-13 00:31:39,504] Trial 27 finished with value: 0.7376895917047066 and parameters: {'lambda_l1': 0.002207085246155012, 'lambda_l2': 0.7918429535995253, 'num_leaves': 23, 'feature_fraction': 0.5963427451167197, 'min_child_samples': 23, 'boosting_type': 'gbdt'}. Best is trial 27 with value: 0.7376895917047066.
# [I 2022-11-13 00:31:39,754] Trial 28 finished with value: 0.7485317624647343 and parameters: {'lambda_l1': 4.332876353169256e-05, 'lambda_l2': 1.100424016907007e-06, 'num_leaves': 63, 'feature_fraction': 0.6554459060863446, 'min_child_samples': 15, 'boosting_type': 'gbdt'}. Best is trial 27 with value: 0.7376895917047066.
# [I 2022-11-13 00:31:39,974] Trial 29 finished with value: 0.7480175506961924 and parameters: {'lambda_l1': 3.288907388208931e-06, 'lambda_l2': 0.00030858617678366677, 'num_leaves': 26, 'feature_fraction': 0.7507087944948735, 'min_child_samples': 5, 'boosting_type': 'dart'}. Best is trial 27 with value: 0.7376895917047066.
# [I 2022-11-13 00:31:40,220] Trial 30 finished with value: 0.7625764709144427 and parameters: {'lambda_l1': 0.0011272732585594085, 'lambda_l2': 0.013016213301694156, 'num_leaves': 44, 'feature_fraction': 0.5641248933359283, 'min_child_samples': 29, 'boosting_type': 'goss'}. Best is trial 27 with value: 0.7376895917047066.
# [I 2022-11-13 00:31:40,360] Trial 31 finished with value: 0.7397298912073064 and parameters: {'lambda_l1': 0.003641086168970285, 'lambda_l2': 1.444718502063163, 'num_leaves': 23, 'feature_fraction': 0.602020412775009, 'min_child_samples': 24, 'boosting_type': 'gbdt'}. Best is trial 27 with value: 0.7376895917047066.
# [I 2022-11-13 00:31:40,611] Trial 32 finished with value: 0.7373925122187103 and parameters: {'lambda_l1': 0.003304734446367697, 'lambda_l2': 0.5781558879131035, 'num_leaves': 18, 'feature_fraction': 0.5900572654313513, 'min_child_samples': 15, 'boosting_type': 'gbdt'}. Best is trial 32 with value: 0.7373925122187103.
# [I 2022-11-13 00:31:40,695] Trial 33 finished with value: 0.7469174107098848 and parameters: {'lambda_l1': 0.008224225491923622, 'lambda_l2': 0.4445519164644082, 'num_leaves': 2, 'feature_fraction': 0.632899475209422, 'min_child_samples': 14, 'boosting_type': 'gbdt'}. Best is trial 32 with value: 0.7373925122187103.
# [I 2022-11-13 00:31:40,824] Trial 34 finished with value: 0.7390411879273042 and parameters: {'lambda_l1': 0.10925878871834009, 'lambda_l2': 0.05452534137091609, 'num_leaves': 18, 'feature_fraction': 0.6695489370699775, 'min_child_samples': 36, 'boosting_type': 'gbdt'}. Best is trial 32 with value: 0.7373925122187103.
# [I 2022-11-13 00:31:41,029] Trial 35 finished with value: 0.7368665413399558 and parameters: {'lambda_l1': 0.09076163842760356, 'lambda_l2': 0.07220837450362888, 'num_leaves': 19, 'feature_fraction': 0.7369292999886601, 'min_child_samples': 51, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:41,328] Trial 36 finished with value: 0.7477415506511939 and parameters: {'lambda_l1': 0.00020119930166285596, 'lambda_l2': 0.34458548027516167, 'num_leaves': 55, 'feature_fraction': 0.7404334777432198, 'min_child_samples': 54, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:41,789] Trial 37 finished with value: 0.7513336687371308 and parameters: {'lambda_l1': 0.0008483445266630567, 'lambda_l2': 0.9713135321057671, 'num_leaves': 71, 'feature_fraction': 0.8925878253642645, 'min_child_samples': 51, 'boosting_type': 'dart'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:42,070] Trial 38 finished with value: 0.7629297960665863 and parameters: {'lambda_l1': 0.07320485437090452, 'lambda_l2': 0.008414212938009634, 'num_leaves': 44, 'feature_fraction': 0.7992666635018456, 'min_child_samples': 28, 'boosting_type': 'goss'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:42,203] Trial 39 finished with value: 0.7370030146664325 and parameters: {'lambda_l1': 0.4748594879217876, 'lambda_l2': 0.09111344703795368, 'num_leaves': 14, 'feature_fraction': 0.7171147511423867, 'min_child_samples': 41, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:42,465] Trial 40 finished with value: 0.7569028969853115 and parameters: {'lambda_l1': 0.50106826055117, 'lambda_l2': 0.1512762797579386, 'num_leaves': 92, 'feature_fraction': 0.7184128501523106, 'min_child_samples': 48, 'boosting_type': 'goss'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:42,728] Trial 41 finished with value: 0.7369041122659437 and parameters: {'lambda_l1': 0.8443742100919395, 'lambda_l2': 2.2166875060009774, 'num_leaves': 17, 'feature_fraction': 0.7954250853879485, 'min_child_samples': 42, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:42,962] Trial 42 finished with value: 0.7381068427159463 and parameters: {'lambda_l1': 1.1309181599248024, 'lambda_l2': 2.2822252819168747, 'num_leaves': 18, 'feature_fraction': 0.7923175736582889, 'min_child_samples': 42, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:43,286] Trial 43 finished with value: 0.7409802570965709 and parameters: {'lambda_l1': 0.045781032767546706, 'lambda_l2': 0.0920784062221263, 'num_leaves': 31, 'feature_fraction': 0.8739810968888465, 'min_child_samples': 56, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:43,751] Trial 44 finished with value: 0.7471138861538732 and parameters: {'lambda_l1': 0.24747324420471978, 'lambda_l2': 9.52990091555594, 'num_leaves': 45, 'feature_fraction': 0.8415036089554963, 'min_child_samples': 48, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:44,062] Trial 45 finished with value: 0.7437303638730371 and parameters: {'lambda_l1': 0.7927974864183805, 'lambda_l2': 0.818907948771258, 'num_leaves': 54, 'feature_fraction': 0.7719227088765306, 'min_child_samples': 33, 'boosting_type': 'gbdt'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:44,701] Trial 46 finished with value: 0.7559481901743175 and parameters: {'lambda_l1': 3.044844103390075, 'lambda_l2': 3.750031717299233, 'num_leaves': 160, 'feature_fraction': 0.7041927527196605, 'min_child_samples': 12, 'boosting_type': 'dart'}. Best is trial 35 with value: 0.7368665413399558.
# [I 2022-11-13 00:31:44,833] Trial 47 finished with value: 0.7360585130341577 and parameters: {'lambda_l1': 0.006084312522962791, 'lambda_l2': 0.030554739369325786, 'num_leaves': 13, 'feature_fraction': 0.6893204852586231, 'min_child_samples': 26, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:44,969] Trial 48 finished with value: 0.7379410835413596 and parameters: {'lambda_l1': 0.20014434714409143, 'lambda_l2': 0.044683646851492884, 'num_leaves': 12, 'feature_fraction': 0.8363262270690048, 'min_child_samples': 37, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:45,141] Trial 49 finished with value: 0.750248798668899 and parameters: {'lambda_l1': 0.026617572525546515, 'lambda_l2': 0.006509966993351464, 'num_leaves': 14, 'feature_fraction': 0.6776181424032005, 'min_child_samples': 28, 'boosting_type': 'goss'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:45,356] Trial 50 finished with value: 0.7454907314792347 and parameters: {'lambda_l1': 0.006285326181968023, 'lambda_l2': 0.22211971394286759, 'num_leaves': 34, 'feature_fraction': 0.8184428632214231, 'min_child_samples': 17, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:45,548] Trial 51 finished with value: 0.7414098656522219 and parameters: {'lambda_l1': 0.0019078119795614904, 'lambda_l2': 0.04310442872114579, 'num_leaves': 27, 'feature_fraction': 0.7276402051242478, 'min_child_samples': 8, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:45,681] Trial 52 finished with value: 0.737073523013564 and parameters: {'lambda_l1': 0.04030733703272646, 'lambda_l2': 0.02546055787737981, 'num_leaves': 12, 'feature_fraction': 0.6929941842691897, 'min_child_samples': 25, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:45,830] Trial 53 finished with value: 0.7388183559004331 and parameters: {'lambda_l1': 0.03781994109675947, 'lambda_l2': 0.020181724627819763, 'num_leaves': 13, 'feature_fraction': 0.771493302146718, 'min_child_samples': 46, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:46,079] Trial 54 finished with value: 0.7487694798432283 and parameters: {'lambda_l1': 0.1494117806915112, 'lambda_l2': 0.0046940039288105315, 'num_leaves': 48, 'feature_fraction': 0.690534583813519, 'min_child_samples': 34, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:46,707] Trial 55 finished with value: 0.7451648136230535 and parameters: {'lambda_l1': 0.5398763950625658, 'lambda_l2': 0.09444313777862197, 'num_leaves': 35, 'feature_fraction': 0.7710551689102888, 'min_child_samples': 26, 'boosting_type': 'gbdt'}. Best is trial 47 with value: 0.7360585130341577.
# [I 2022-11-13 00:31:46,851] Trial 56 finished with value: 0.7360173907098693 and parameters: {'lambda_l1': 0.009332565689933268, 'lambda_l2': 0.01934771076000386, 'num_leaves': 9, 'feature_fraction': 0.7265550165333623, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 56 with value: 0.7360173907098693.
# [I 2022-11-13 00:31:46,999] Trial 57 finished with value: 0.7360038852965842 and parameters: {'lambda_l1': 3.4806330933593213, 'lambda_l2': 0.0011508631146800855, 'num_leaves': 8, 'feature_fraction': 0.7131026776210535, 'min_child_samples': 39, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:47,145] Trial 58 finished with value: 0.7555842305098465 and parameters: {'lambda_l1': 4.040806638245775, 'lambda_l2': 0.001099378277348227, 'num_leaves': 5, 'feature_fraction': 0.7263166925007924, 'min_child_samples': 40, 'boosting_type': 'dart'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:47,237] Trial 59 finished with value: 0.7471933005686535 and parameters: {'lambda_l1': 1.637250179058747, 'lambda_l2': 0.00033070751890028246, 'num_leaves': 2, 'feature_fraction': 0.6443653186419721, 'min_child_samples': 44, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:47,637] Trial 60 finished with value: 0.7590911143730548 and parameters: {'lambda_l1': 0.28524871431928533, 'lambda_l2': 0.0028122497024630974, 'num_leaves': 135, 'feature_fraction': 0.942540551742196, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:47,794] Trial 61 finished with value: 0.7364532623026611 and parameters: {'lambda_l1': 0.08235554763953097, 'lambda_l2': 0.021117554429338065, 'num_leaves': 13, 'feature_fraction': 0.7051165123163459, 'min_child_samples': 32, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:47,997] Trial 62 finished with value: 0.7442186152733709 and parameters: {'lambda_l1': 0.01225056603523161, 'lambda_l2': 0.0004971869026786313, 'num_leaves': 31, 'feature_fraction': 0.751617036561604, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:48,149] Trial 63 finished with value: 0.7368378102840565 and parameters: {'lambda_l1': 0.0832346997435271, 'lambda_l2': 0.014481717307152711, 'num_leaves': 9, 'feature_fraction': 0.7103228606447849, 'min_child_samples': 37, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:48,338] Trial 64 finished with value: 0.7401941370358037 and parameters: {'lambda_l1': 0.1146136680976016, 'lambda_l2': 0.0035184419167195355, 'num_leaves': 25, 'feature_fraction': 0.6837775244125376, 'min_child_samples': 37, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:48,552] Trial 65 finished with value: 0.7421700128770141 and parameters: {'lambda_l1': 0.07309488749407135, 'lambda_l2': 0.009876303657628104, 'num_leaves': 37, 'feature_fraction': 0.7079586716391915, 'min_child_samples': 49, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:48,667] Trial 66 finished with value: 0.7386983577393162 and parameters: {'lambda_l1': 1.0688471332861986, 'lambda_l2': 0.02036795354518404, 'num_leaves': 9, 'feature_fraction': 0.7800828495590195, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:48,947] Trial 67 finished with value: 0.7415227429307131 and parameters: {'lambda_l1': 6.340944607335801, 'lambda_l2': 0.0010662902765638572, 'num_leaves': 50, 'feature_fraction': 0.6203728399825481, 'min_child_samples': 38, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:49,251] Trial 68 finished with value: 0.748559797480605 and parameters: {'lambda_l1': 0.020193558312277118, 'lambda_l2': 0.027579138824960287, 'num_leaves': 63, 'feature_fraction': 0.8122542252991173, 'min_child_samples': 52, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:49,553] Trial 69 finished with value: 0.7599188528204615 and parameters: {'lambda_l1': 0.005555359568292164, 'lambda_l2': 0.23168437257563085, 'num_leaves': 175, 'feature_fraction': 0.7566273145620735, 'min_child_samples': 44, 'boosting_type': 'goss'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:49,721] Trial 70 finished with value: 0.7420071859176182 and parameters: {'lambda_l1': 0.015019125498895869, 'lambda_l2': 0.001748507095530945, 'num_leaves': 23, 'feature_fraction': 0.7369676481021714, 'min_child_samples': 34, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:49,862] Trial 71 finished with value: 0.7372070133659011 and parameters: {'lambda_l1': 0.29934936077892227, 'lambda_l2': 0.005681863650783184, 'num_leaves': 11, 'feature_fraction': 0.7155161853570321, 'min_child_samples': 42, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:50,036] Trial 72 finished with value: 0.7366848234346458 and parameters: {'lambda_l1': 2.3141260464846796, 'lambda_l2': 0.04760664691883897, 'num_leaves': 18, 'feature_fraction': 0.662254725089052, 'min_child_samples': 40, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:50,154] Trial 73 finished with value: 0.7470729808770558 and parameters: {'lambda_l1': 2.2053481147957026, 'lambda_l2': 0.012021432783150918, 'num_leaves': 2, 'feature_fraction': 0.6565292952914479, 'min_child_samples': 31, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:50,389] Trial 74 finished with value: 0.7436102743792777 and parameters: {'lambda_l1': 4.4495780795082185, 'lambda_l2': 0.07088534741980293, 'num_leaves': 39, 'feature_fraction': 0.6690103769911081, 'min_child_samples': 38, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:50,585] Trial 75 finished with value: 0.7374589576744336 and parameters: {'lambda_l1': 0.08832298837187884, 'lambda_l2': 0.030681951215291825, 'num_leaves': 19, 'feature_fraction': 0.620804913094841, 'min_child_samples': 19, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:50,851] Trial 76 finished with value: 0.748552835985198 and parameters: {'lambda_l1': 0.9874071157597138, 'lambda_l2': 0.16067622361132303, 'num_leaves': 27, 'feature_fraction': 0.6386067541362723, 'min_child_samples': 58, 'boosting_type': 'dart'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:51,254] Trial 77 finished with value: 0.7438464430193513 and parameters: {'lambda_l1': 8.867339665832244, 'lambda_l2': 0.016622101436629254, 'num_leaves': 108, 'feature_fraction': 0.6883165245109438, 'min_child_samples': 35, 'boosting_type': 'gbdt'}. Best is trial 57 with value: 0.7360038852965842.
# [I 2022-11-13 00:31:51,389] Trial 78 finished with value: 0.7353612233659138 and parameters: {'lambda_l1': 1.6340014952917392, 'lambda_l2': 0.05492556511369189, 'num_leaves': 9, 'feature_fraction': 0.6994959847873751, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 78 with value: 0.7353612233659138.
# [I 2022-11-13 00:31:51,508] Trial 79 finished with value: 0.7361624719283313 and parameters: {'lambda_l1': 2.509793010528525, 'lambda_l2': 0.28038815697720854, 'num_leaves': 8, 'feature_fraction': 0.7011440551086603, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 78 with value: 0.7353612233659138.
# [I 2022-11-13 00:31:51,659] Trial 80 finished with value: 0.7357155908248962 and parameters: {'lambda_l1': 1.6491388477118851, 'lambda_l2': 0.21858440565775883, 'num_leaves': 9, 'feature_fraction': 0.6984919833042053, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 78 with value: 0.7353612233659138.
# [I 2022-11-13 00:31:51,805] Trial 81 finished with value: 0.736528180762133 and parameters: {'lambda_l1': 3.8426066046246996, 'lambda_l2': 1.6353265355376166e-08, 'num_leaves': 8, 'feature_fraction': 0.7008162425663148, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 78 with value: 0.7353612233659138.
# [I 2022-11-13 00:31:51,921] Trial 82 finished with value: 0.7350908313233484 and parameters: {'lambda_l1': 3.1870567433663206, 'lambda_l2': 0.2792603849564684, 'num_leaves': 8, 'feature_fraction': 0.6638175643452584, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:52,040] Trial 83 finished with value: 0.735334724293198 and parameters: {'lambda_l1': 4.477449356174436, 'lambda_l2': 8.527556192911777e-08, 'num_leaves': 8, 'feature_fraction': 0.6994552459972819, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:52,245] Trial 84 finished with value: 0.7400355383603243 and parameters: {'lambda_l1': 1.7624567483488403, 'lambda_l2': 0.2795949184110199, 'num_leaves': 30, 'feature_fraction': 0.6808527538743495, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:52,390] Trial 85 finished with value: 0.7360655641069329 and parameters: {'lambda_l1': 9.62600324539295, 'lambda_l2': 1.3509924694956652, 'num_leaves': 8, 'feature_fraction': 0.7348649133169087, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:52,471] Trial 86 finished with value: 0.7474251109539001 and parameters: {'lambda_l1': 7.048548834776705, 'lambda_l2': 5.328276635681851e-06, 'num_leaves': 2, 'feature_fraction': 0.6502733714198273, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:52,594] Trial 87 finished with value: 0.7494257714883521 and parameters: {'lambda_l1': 9.991593693797938, 'lambda_l2': 1.166231650710421, 'num_leaves': 7, 'feature_fraction': 0.7286406859838194, 'min_child_samples': 80, 'boosting_type': 'goss'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:52,890] Trial 88 finished with value: 0.7452951846830823 and parameters: {'lambda_l1': 4.1307281556063735, 'lambda_l2': 6.066536306719902e-08, 'num_leaves': 225, 'feature_fraction': 0.7592027305739154, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:53,051] Trial 89 finished with value: 0.7385730200777608 and parameters: {'lambda_l1': 4.688414957175516e-06, 'lambda_l2': 0.4633586053475499, 'num_leaves': 23, 'feature_fraction': 0.6715553634895928, 'min_child_samples': 99, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:53,290] Trial 90 finished with value: 0.7443967205724268 and parameters: {'lambda_l1': 1.628538773876974, 'lambda_l2': 0.1439301978054686, 'num_leaves': 41, 'feature_fraction': 0.741164327090339, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:53,465] Trial 91 finished with value: 0.7374423573593823 and parameters: {'lambda_l1': 0.5259107683442832, 'lambda_l2': 1.0879184103123568e-05, 'num_leaves': 16, 'feature_fraction': 0.6942699487124495, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:53,593] Trial 92 finished with value: 0.7352437670977461 and parameters: {'lambda_l1': 5.3028649782972535, 'lambda_l2': 1.6029455109188685e-07, 'num_leaves': 8, 'feature_fraction': 0.7205895145351332, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:53,743] Trial 93 finished with value: 0.7361956416111227 and parameters: {'lambda_l1': 4.684429011860572, 'lambda_l2': 3.31034387069153e-05, 'num_leaves': 9, 'feature_fraction': 0.7246008785246272, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:53,925] Trial 94 finished with value: 0.7369398848274112 and parameters: {'lambda_l1': 3.0392791994707946, 'lambda_l2': 1.376409273220457e-07, 'num_leaves': 23, 'feature_fraction': 0.7420091304367709, 'min_child_samples': 91, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,038] Trial 95 finished with value: 0.7358924648681616 and parameters: {'lambda_l1': 6.209164988034389, 'lambda_l2': 2.3339844097096487e-07, 'num_leaves': 5, 'feature_fraction': 0.6242706383776357, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,141] Trial 96 finished with value: 0.7832228239927926 and parameters: {'lambda_l1': 6.262498673578558, 'lambda_l2': 1.1971383289882685e-07, 'num_leaves': 2, 'feature_fraction': 0.6218831231916377, 'min_child_samples': 81, 'boosting_type': 'dart'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,342] Trial 97 finished with value: 0.7393332218804773 and parameters: {'lambda_l1': 1.3316063140065155, 'lambda_l2': 2.6738605323876174e-07, 'num_leaves': 31, 'feature_fraction': 0.5764154688446154, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,490] Trial 98 finished with value: 0.736719481827887 and parameters: {'lambda_l1': 3.313689332384939e-05, 'lambda_l2': 2.9443417890925017e-06, 'num_leaves': 15, 'feature_fraction': 0.6771030012362341, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,659] Trial 99 finished with value: 0.7383580368255328 and parameters: {'lambda_l1': 5.867454607442118, 'lambda_l2': 3.949842641474938e-08, 'num_leaves': 20, 'feature_fraction': 0.6380468079753344, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,845] Trial 100 finished with value: 0.7372069126122798 and parameters: {'lambda_l1': 4.0813580354213114e-08, 'lambda_l2': 3.5353899883412723e-07, 'num_leaves': 29, 'feature_fraction': 0.6040747735991393, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:54,989] Trial 101 finished with value: 0.7354716503075106 and parameters: {'lambda_l1': 2.5402782389984124, 'lambda_l2': 1.8600746997249202, 'num_leaves': 9, 'feature_fraction': 0.7021774154052323, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:55,109] Trial 102 finished with value: 0.7360202559329887 and parameters: {'lambda_l1': 3.180350058262503, 'lambda_l2': 1.7130891360275549, 'num_leaves': 7, 'feature_fraction': 0.6549967864145739, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:55,267] Trial 103 finished with value: 0.7360422002265938 and parameters: {'lambda_l1': 0.8160089196266788, 'lambda_l2': 3.2083814451285826, 'num_leaves': 16, 'feature_fraction': 0.6628269350145993, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:55,409] Trial 104 finished with value: 0.7362972286137242 and parameters: {'lambda_l1': 0.7473067729206492, 'lambda_l2': 7.215808346694873, 'num_leaves': 15, 'feature_fraction': 0.6563026933250983, 'min_child_samples': 93, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:55,524] Trial 105 finished with value: 0.7370948932347434 and parameters: {'lambda_l1': 0.6693822990194782, 'lambda_l2': 3.2526099836460607, 'num_leaves': 5, 'feature_fraction': 0.7147840708504712, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:55,708] Trial 106 finished with value: 0.7379068448618255 and parameters: {'lambda_l1': 2.889316089417339, 'lambda_l2': 2.0626259256166537, 'num_leaves': 25, 'feature_fraction': 0.6660171660861081, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:55,876] Trial 107 finished with value: 0.7361203213919035 and parameters: {'lambda_l1': 1.2009279035478586, 'lambda_l2': 0.7549103141504607, 'num_leaves': 19, 'feature_fraction': 0.6107181833261862, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,043] Trial 108 finished with value: 0.7540252295933667 and parameters: {'lambda_l1': 0.17394054815579368, 'lambda_l2': 9.042946289702157e-08, 'num_leaves': 35, 'feature_fraction': 0.6327866820028067, 'min_child_samples': 85, 'boosting_type': 'goss'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,153] Trial 109 finished with value: 0.7360851876814719 and parameters: {'lambda_l1': 0.3681124567823242, 'lambda_l2': 4.406155019331521, 'num_leaves': 6, 'feature_fraction': 0.649270767948377, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,309] Trial 110 finished with value: 0.735678257390775 and parameters: {'lambda_l1': 2.188501164630179, 'lambda_l2': 2.474243069297639e-08, 'num_leaves': 13, 'feature_fraction': 0.6812675268846606, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,426] Trial 111 finished with value: 0.7366638553840068 and parameters: {'lambda_l1': 2.072784473186126, 'lambda_l2': 2.0440718823214216e-08, 'num_leaves': 11, 'feature_fraction': 0.6800591696962995, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,575] Trial 112 finished with value: 0.7363678034328451 and parameters: {'lambda_l1': 3.1524072251943616, 'lambda_l2': 2.895464410163124e-08, 'num_leaves': 15, 'feature_fraction': 0.6954825031761244, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,746] Trial 113 finished with value: 0.738029950565574 and parameters: {'lambda_l1': 5.137497112766153, 'lambda_l2': 2.627191265221043e-07, 'num_leaves': 21, 'feature_fraction': 0.7174116219458563, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:56,824] Trial 114 finished with value: 0.7471054779641405 and parameters: {'lambda_l1': 1.5441066014359917, 'lambda_l2': 5.729717073198304e-08, 'num_leaves': 2, 'feature_fraction': 0.5820113775137231, 'min_child_samples': 83, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,006] Trial 115 finished with value: 0.7391815038203029 and parameters: {'lambda_l1': 0.9293187261613873, 'lambda_l2': 1.388668749730646e-08, 'num_leaves': 26, 'feature_fraction': 0.6617474820783213, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,275] Trial 116 finished with value: 0.7496773713017953 and parameters: {'lambda_l1': 3.299756903382223, 'lambda_l2': 1.1659968383126931e-06, 'num_leaves': 202, 'feature_fraction': 0.7065892442272537, 'min_child_samples': 89, 'boosting_type': 'dart'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,414] Trial 117 finished with value: 0.7351988322981673 and parameters: {'lambda_l1': 5.74642671791644, 'lambda_l2': 0.00013836507226740443, 'num_leaves': 11, 'feature_fraction': 0.6839723379628939, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,543] Trial 118 finished with value: 0.7371201202406737 and parameters: {'lambda_l1': 6.402146331893089, 'lambda_l2': 9.052548360567577e-08, 'num_leaves': 11, 'feature_fraction': 0.684778587155421, 'min_child_samples': 67, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,657] Trial 119 finished with value: 0.7360052442941118 and parameters: {'lambda_l1': 1.9623839478391483, 'lambda_l2': 2.1251185212849083e-07, 'num_leaves': 7, 'feature_fraction': 0.6336834866512664, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,828] Trial 120 finished with value: 0.7381238975086686 and parameters: {'lambda_l1': 2.0258372467390338, 'lambda_l2': 2.073406517310032e-07, 'num_leaves': 21, 'feature_fraction': 0.6290235047240318, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:57,941] Trial 121 finished with value: 0.7366938367798431 and parameters: {'lambda_l1': 4.563834182449682, 'lambda_l2': 3.2512555901867017e-08, 'num_leaves': 6, 'feature_fraction': 0.6454652365973442, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:58,081] Trial 122 finished with value: 0.7353154757792763 and parameters: {'lambda_l1': 9.982235148862081, 'lambda_l2': 6.024985959487009e-07, 'num_leaves': 10, 'feature_fraction': 0.6751506358789605, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:58,279] Trial 123 finished with value: 0.7358220114874613 and parameters: {'lambda_l1': 6.877950257492504, 'lambda_l2': 4.880479388865492e-07, 'num_leaves': 11, 'feature_fraction': 0.6990875742565855, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:58,405] Trial 124 finished with value: 0.7358733938554198 and parameters: {'lambda_l1': 8.635525979426818, 'lambda_l2': 6.063505533323141e-07, 'num_leaves': 12, 'feature_fraction': 0.6736564968757548, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:58,539] Trial 125 finished with value: 0.7379432057230818 and parameters: {'lambda_l1': 9.243850949562257, 'lambda_l2': 5.905427119317817e-07, 'num_leaves': 13, 'feature_fraction': 0.6740256057791985, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:58,744] Trial 126 finished with value: 0.7396537885188952 and parameters: {'lambda_l1': 6.531045723604818, 'lambda_l2': 2.4252620549359702e-06, 'num_leaves': 28, 'feature_fraction': 0.6964441025942542, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:58,905] Trial 127 finished with value: 0.737952407175689 and parameters: {'lambda_l1': 4.515098975807442, 'lambda_l2': 1.0309217865529213e-08, 'num_leaves': 19, 'feature_fraction': 0.7087514917903786, 'min_child_samples': 87, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:59,043] Trial 128 finished with value: 0.7369532498643567 and parameters: {'lambda_l1': 9.350120006176589, 'lambda_l2': 4.2017594646084983e-07, 'num_leaves': 12, 'feature_fraction': 0.6899639630866257, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:59,261] Trial 129 finished with value: 0.7533912361624502 and parameters: {'lambda_l1': 1.38287262169205, 'lambda_l2': 1.0591621160270493e-06, 'num_leaves': 101, 'feature_fraction': 0.6742221772917953, 'min_child_samples': 76, 'boosting_type': 'goss'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:59,544] Trial 130 finished with value: 0.7425166723054026 and parameters: {'lambda_l1': 6.271104151994635, 'lambda_l2': 8.947519909059896e-07, 'num_leaves': 148, 'feature_fraction': 0.7212935075766258, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:59,638] Trial 131 finished with value: 0.746980000810527 and parameters: {'lambda_l1': 2.1846035815660736, 'lambda_l2': 0.00015940677847679609, 'num_leaves': 2, 'feature_fraction': 0.6123458342308743, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:31:59,963] Trial 132 finished with value: 0.7468560828304662 and parameters: {'lambda_l1': 2.863880655133544, 'lambda_l2': 1.6286974695403352e-07, 'num_leaves': 126, 'feature_fraction': 0.6850535867978406, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,094] Trial 133 finished with value: 0.7365507225501646 and parameters: {'lambda_l1': 4.143665629191999, 'lambda_l2': 4.306640409475879e-07, 'num_leaves': 8, 'feature_fraction': 0.6996121910668618, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,246] Trial 134 finished with value: 0.7366996725396648 and parameters: {'lambda_l1': 1.412113145086374, 'lambda_l2': 1.9368797439436184e-06, 'num_leaves': 17, 'feature_fraction': 0.6391037449755449, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,363] Trial 135 finished with value: 0.7476338573051712 and parameters: {'lambda_l1': 9.908911707370368, 'lambda_l2': 1.8703949219764047e-07, 'num_leaves': 2, 'feature_fraction': 0.669502711010088, 'min_child_samples': 82, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,496] Trial 136 finished with value: 0.7368725401345877 and parameters: {'lambda_l1': 2.2095815393188887, 'lambda_l2': 5.984570650105403e-08, 'num_leaves': 11, 'feature_fraction': 0.7327689123300892, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,690] Trial 137 finished with value: 0.7389411867057402 and parameters: {'lambda_l1': 5.487252461669447, 'lambda_l2': 7.291668643705883e-07, 'num_leaves': 25, 'feature_fraction': 0.7498180138585475, 'min_child_samples': 84, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,805] Trial 138 finished with value: 0.7352765017594074 and parameters: {'lambda_l1': 3.530570434076622, 'lambda_l2': 8.275407201290771e-08, 'num_leaves': 7, 'feature_fraction': 0.709885601096582, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:00,995] Trial 139 finished with value: 0.7494785729107897 and parameters: {'lambda_l1': 3.0501681338124365, 'lambda_l2': 1.578624590033232e-06, 'num_leaves': 15, 'feature_fraction': 0.714292744400124, 'min_child_samples': 95, 'boosting_type': 'dart'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,192] Trial 140 finished with value: 0.7403789608739714 and parameters: {'lambda_l1': 6.069704932449602, 'lambda_l2': 1.1666082018309983e-07, 'num_leaves': 32, 'feature_fraction': 0.698210814087354, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,301] Trial 141 finished with value: 0.735557711887806 and parameters: {'lambda_l1': 3.961773315692282, 'lambda_l2': 3.391104053717244e-07, 'num_leaves': 7, 'feature_fraction': 0.682086082968998, 'min_child_samples': 81, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,461] Trial 142 finished with value: 0.7383991205383164 and parameters: {'lambda_l1': 3.6565775123516517, 'lambda_l2': 3.2212299428867135e-07, 'num_leaves': 21, 'feature_fraction': 0.6818559182746626, 'min_child_samples': 86, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,573] Trial 143 finished with value: 0.7358858628139602 and parameters: {'lambda_l1': 7.405913319416183, 'lambda_l2': 4.131875538797817e-08, 'num_leaves': 6, 'feature_fraction': 0.7085099078961179, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,707] Trial 144 finished with value: 0.7371682425460013 and parameters: {'lambda_l1': 6.550647299084724, 'lambda_l2': 4.240325542715506e-08, 'num_leaves': 11, 'feature_fraction': 0.7058648517183208, 'min_child_samples': 100, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,811] Trial 145 finished with value: 0.7474578322741487 and parameters: {'lambda_l1': 9.662592044927885, 'lambda_l2': 8.59703190914176e-08, 'num_leaves': 2, 'feature_fraction': 0.6877998670942591, 'min_child_samples': 97, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:01,952] Trial 146 finished with value: 0.7359427038823942 and parameters: {'lambda_l1': 1.1475745260388954, 'lambda_l2': 1.3168904227268175e-07, 'num_leaves': 16, 'feature_fraction': 0.7256666409537529, 'min_child_samples': 96, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:02,062] Trial 147 finished with value: 0.7360186762198189 and parameters: {'lambda_l1': 4.54040181981423, 'lambda_l2': 5.215880019384265e-07, 'num_leaves': 8, 'feature_fraction': 0.6553590564030857, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# [I 2022-11-13 00:32:02,238] Trial 148 finished with value: 0.7399326264351856 and parameters: {'lambda_l1': 2.490441665810605, 'lambda_l2': 2.8672388172958117e-08, 'num_leaves': 22, 'feature_fraction': 0.6719478274862746, 'min_child_samples': 80, 'boosting_type': 'gbdt'}. Best is trial 82 with value: 0.7350908313233484.
# ...
# [I 2022-11-13 00:32:32,675] Trial 352 finished with value: 0.7361195064466318 and parameters: {'lambda_l1': 3.470794581325262, 'lambda_l2': 0.00028654963802886546, 'num_leaves': 18, 'feature_fraction': 0.7382470432837819, 'min_child_samples': 88, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:32,786] Trial 353 finished with value: 0.7505096680029137 and parameters: {'lambda_l1': 1.9002721979926518, 'lambda_l2': 1.2707600287833881e-05, 'num_leaves': 6, 'feature_fraction': 0.5475870020802726, 'min_child_samples': 97, 'boosting_type': 'goss'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:32,926] Trial 354 finished with value: 0.7362103703084569 and parameters: {'lambda_l1': 5.703492804980133, 'lambda_l2': 0.0001163786451508187, 'num_leaves': 10, 'feature_fraction': 0.6730977723192372, 'min_child_samples': 92, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:33,070] Trial 355 finished with value: 0.7382025590011011 and parameters: {'lambda_l1': 2.6768958100699676, 'lambda_l2': 2.5950723840497815e-05, 'num_leaves': 16, 'feature_fraction': 0.7163463637607222, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:33,373] Trial 356 finished with value: 0.7470367076109682 and parameters: {'lambda_l1': 8.477173814321397e-05, 'lambda_l2': 0.00016673715353437255, 'num_leaves': 164, 'feature_fraction': 0.43235318368200565, 'min_child_samples': 94, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:33,488] Trial 357 finished with value: 0.736935842436525 and parameters: {'lambda_l1': 4.136123037886541, 'lambda_l2': 1.2519154591755619e-07, 'num_leaves': 5, 'feature_fraction': 0.5543048635002661, 'min_child_samples': 90, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:33,627] Trial 358 finished with value: 0.7350452605382259 and parameters: {'lambda_l1': 1.1490602780871129, 'lambda_l2': 2.2793457674659187e-07, 'num_leaves': 12, 'feature_fraction': 0.630955794993713, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:34,018] Trial 359 finished with value: 0.749558184005564 and parameters: {'lambda_l1': 0.5240003968717254, 'lambda_l2': 2.4229165258558526e-07, 'num_leaves': 219, 'feature_fraction': 0.6373464928933844, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:34,200] Trial 360 finished with value: 0.7354380613506142 and parameters: {'lambda_l1': 0.8750189441353361, 'lambda_l2': 2.540285547891229e-07, 'num_leaves': 21, 'feature_fraction': 0.6247029702245699, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:34,354] Trial 361 finished with value: 0.737093065971312 and parameters: {'lambda_l1': 1.2830414833856274, 'lambda_l2': 3.776571359393402e-07, 'num_leaves': 13, 'feature_fraction': 0.6226861655536642, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:34,537] Trial 362 finished with value: 0.7402109079012846 and parameters: {'lambda_l1': 0.654074588479579, 'lambda_l2': 0.0003762852704911332, 'num_leaves': 26, 'feature_fraction': 0.6421903190360301, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:34,754] Trial 363 finished with value: 0.7493237033395979 and parameters: {'lambda_l1': 1.2188537442485372, 'lambda_l2': 0.0002011190232932823, 'num_leaves': 18, 'feature_fraction': 0.6543079044613812, 'min_child_samples': 76, 'boosting_type': 'dart'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:34,902] Trial 364 finished with value: 0.7372108997648801 and parameters: {'lambda_l1': 1.7719185448700105, 'lambda_l2': 6.945952139990119e-05, 'num_leaves': 11, 'feature_fraction': 0.6107822161615682, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:35,013] Trial 365 finished with value: 0.7355421344892743 and parameters: {'lambda_l1': 2.06699881198762, 'lambda_l2': 1.79377819740056e-07, 'num_leaves': 7, 'feature_fraction': 0.6345579411218052, 'min_child_samples': 85, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:35,158] Trial 366 finished with value: 0.7352070826021135 and parameters: {'lambda_l1': 7.096975382327542, 'lambda_l2': 1.4319970293470545e-06, 'num_leaves': 14, 'feature_fraction': 0.6255356300115424, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:35,438] Trial 367 finished with value: 0.7369778908404938 and parameters: {'lambda_l1': 7.348971089545518, 'lambda_l2': 1.1261386841006108e-06, 'num_leaves': 19, 'feature_fraction': 0.6067618064126512, 'min_child_samples': 78, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:35,647] Trial 368 finished with value: 0.7397098049880644 and parameters: {'lambda_l1': 1.0543014415725411, 'lambda_l2': 4.539537345572492e-07, 'num_leaves': 33, 'feature_fraction': 0.6255067370244928, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:35,834] Trial 369 finished with value: 0.7394343269020848 and parameters: {'lambda_l1': 2.643723902245761, 'lambda_l2': 8.257213080509282e-07, 'num_leaves': 24, 'feature_fraction': 0.6582774337214253, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:36,146] Trial 370 finished with value: 0.7480025322558504 and parameters: {'lambda_l1': 3.8227252171008157, 'lambda_l2': 1.3321450137166213e-06, 'num_leaves': 117, 'feature_fraction': 0.5947054328018333, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:36,285] Trial 371 finished with value: 0.7377314461459146 and parameters: {'lambda_l1': 1.442912351562761, 'lambda_l2': 2.8553838203175125e-07, 'num_leaves': 13, 'feature_fraction': 0.5041872631486728, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:36,435] Trial 372 finished with value: 0.7374051597300676 and parameters: {'lambda_l1': 9.85116470306574, 'lambda_l2': 7.132814530138081e-06, 'num_leaves': 16, 'feature_fraction': 0.6298000071056724, 'min_child_samples': 68, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:36,590] Trial 373 finished with value: 0.737013070989372 and parameters: {'lambda_l1': 4.654894873863737, 'lambda_l2': 5.2429416869931004e-06, 'num_leaves': 14, 'feature_fraction': 0.6143899585855641, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:36,682] Trial 374 finished with value: 0.7472845720809159 and parameters: {'lambda_l1': 2.6592024365247418, 'lambda_l2': 2.3621138788780076e-06, 'num_leaves': 2, 'feature_fraction': 0.645246482061801, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:36,839] Trial 375 finished with value: 0.7349869734732201 and parameters: {'lambda_l1': 5.111298813266904e-06, 'lambda_l2': 6.966483832281126e-07, 'num_leaves': 20, 'feature_fraction': 0.57376056268674, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:37,160] Trial 376 finished with value: 0.7485980588401966 and parameters: {'lambda_l1': 3.939754885659608e-07, 'lambda_l2': 6.246492316261818e-07, 'num_leaves': 82, 'feature_fraction': 0.5980271365542625, 'min_child_samples': 68, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:37,351] Trial 377 finished with value: 0.7511983643699973 and parameters: {'lambda_l1': 1.739613210286291e-07, 'lambda_l2': 1.6535270411761855e-06, 'num_leaves': 25, 'feature_fraction': 0.9259250110572936, 'min_child_samples': 64, 'boosting_type': 'goss'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:37,524] Trial 378 finished with value: 0.7365210246351008 and parameters: {'lambda_l1': 0.6645326471479291, 'lambda_l2': 4.5401244371727554e-07, 'num_leaves': 20, 'feature_fraction': 0.5283546515993465, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:37,800] Trial 379 finished with value: 0.7389120961832815 and parameters: {'lambda_l1': 3.8124967499769046e-06, 'lambda_l2': 6.860214074694155e-07, 'num_leaves': 29, 'feature_fraction': 0.5774754866129568, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:37,963] Trial 380 finished with value: 0.7350549215868836 and parameters: {'lambda_l1': 1.7078093228452003, 'lambda_l2': 1.5600219257741804e-05, 'num_leaves': 21, 'feature_fraction': 0.5722349506644575, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:38,161] Trial 381 finished with value: 0.7391317821988487 and parameters: {'lambda_l1': 2.2085155820450025e-06, 'lambda_l2': 1.5081142399026539e-05, 'num_leaves': 30, 'feature_fraction': 0.5553146213582174, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:38,420] Trial 382 finished with value: 0.7423584575134005 and parameters: {'lambda_l1': 1.951400098068407, 'lambda_l2': 1.9386257994479188e-05, 'num_leaves': 48, 'feature_fraction': 0.5697428045773889, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:38,594] Trial 383 finished with value: 0.7382182631011164 and parameters: {'lambda_l1': 1.768568819906027e-08, 'lambda_l2': 1.1766802615359476e-05, 'num_leaves': 23, 'feature_fraction': 0.585687378509646, 'min_child_samples': 73, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:38,778] Trial 384 finished with value: 0.7365020758622156 and parameters: {'lambda_l1': 1.0223428015967244, 'lambda_l2': 3.58767599650452e-05, 'num_leaves': 21, 'feature_fraction': 0.5790736229435325, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:39,039] Trial 385 finished with value: 0.7397759623087117 and parameters: {'lambda_l1': 0.0005836828718573406, 'lambda_l2': 2.2338110433899044e-05, 'num_leaves': 34, 'feature_fraction': 0.5419079115652006, 'min_child_samples': 67, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:39,195] Trial 386 finished with value: 0.7368447944660564 and parameters: {'lambda_l1': 3.2023410646510815, 'lambda_l2': 8.679983129809399e-07, 'num_leaves': 19, 'feature_fraction': 0.5653004340583201, 'min_child_samples': 76, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:39,438] Trial 387 finished with value: 0.7484454639914147 and parameters: {'lambda_l1': 1.8182644007877362, 'lambda_l2': 0.0007835110370844005, 'num_leaves': 26, 'feature_fraction': 0.5847831758215035, 'min_child_samples': 73, 'boosting_type': 'dart'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:39,598] Trial 388 finished with value: 0.7370892518359955 and parameters: {'lambda_l1': 6.094743876146201e-06, 'lambda_l2': 1.0082530847079306e-05, 'num_leaves': 16, 'feature_fraction': 0.5502041098924836, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:39,743] Trial 389 finished with value: 0.7365832114814483 and parameters: {'lambda_l1': 6.302548170250964, 'lambda_l2': 4.811623162928801e-07, 'num_leaves': 13, 'feature_fraction': 0.5569323127164497, 'min_child_samples': 50, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:39,975] Trial 390 finished with value: 0.7363668698966034 and parameters: {'lambda_l1': 4.5700451961038323e-05, 'lambda_l2': 0.0003921128394754402, 'num_leaves': 20, 'feature_fraction': 0.6048021340225268, 'min_child_samples': 69, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:40,128] Trial 391 finished with value: 0.7359587111981009 and parameters: {'lambda_l1': 2.9092328328004027, 'lambda_l2': 1.1039599861434548e-06, 'num_leaves': 15, 'feature_fraction': 0.5712028363966736, 'min_child_samples': 71, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:40,324] Trial 392 finished with value: 0.7387644724734922 and parameters: {'lambda_l1': 9.442543431864552e-08, 'lambda_l2': 0.0999333616766739, 'num_leaves': 27, 'feature_fraction': 0.6708425624030481, 'min_child_samples': 77, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:40,463] Trial 393 finished with value: 0.7361736557411587 and parameters: {'lambda_l1': 4.108028447337529, 'lambda_l2': 7.037565394783494, 'num_leaves': 11, 'feature_fraction': 0.6185925658887077, 'min_child_samples': 74, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:40,635] Trial 394 finished with value: 0.73578234076015 and parameters: {'lambda_l1': 1.3729517903215864, 'lambda_l2': 2.9340676321470823e-07, 'num_leaves': 19, 'feature_fraction': 0.5913910605306387, 'min_child_samples': 68, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:41,032] Trial 395 finished with value: 0.7457368351476091 and parameters: {'lambda_l1': 0.057585229199199055, 'lambda_l2': 0.00031544795245977615, 'num_leaves': 192, 'feature_fraction': 0.6480192962573077, 'min_child_samples': 79, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:41,172] Trial 396 finished with value: 0.7360064186922535 and parameters: {'lambda_l1': 7.261256610346094, 'lambda_l2': 0.001808824526683202, 'num_leaves': 10, 'feature_fraction': 0.6013531180292618, 'min_child_samples': 70, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:41,376] Trial 397 finished with value: 0.738860371205387 and parameters: {'lambda_l1': 2.3646440281981125, 'lambda_l2': 0.0006647015286855001, 'num_leaves': 24, 'feature_fraction': 0.6626793576422322, 'min_child_samples': 72, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:41,536] Trial 398 finished with value: 0.7362446488311879 and parameters: {'lambda_l1': 0.00014547880911181462, 'lambda_l2': 2.8408423209349933e-05, 'num_leaves': 16, 'feature_fraction': 0.6817246866363158, 'min_child_samples': 66, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# [I 2022-11-13 00:32:41,680] Trial 399 finished with value: 0.7346595045057266 and parameters: {'lambda_l1': 0.8154126272553753, 'lambda_l2': 3.88040370745587e-06, 'num_leaves': 9, 'feature_fraction': 0.6139331706524099, 'min_child_samples': 75, 'boosting_type': 'gbdt'}. Best is trial 176 with value: 0.734141392247469.
# Number of finished trials: 400
# Best trial (176):
# Value: 0.734141392247469
# Params:
# {'lambda_l1': 3.529032521658295, 'lambda_l2': 0.00012549631568416078, 'num_leaves': 20, 'feature_fraction': 0.6267092028144358, 'min_child_samples': 80, 'boosting_type': 'gbdt'}

# %%
# Catboost validation prediction
y_pred_val_cb = np.expm1(cbm.predict(X_val_cb))
print('Catboost validation score:', rmsle(np.expm1(y_val), y_pred_val_cb))

# LightGBM validation prediction
y_val_pred_lgb = np.expm1(lgbm.predict(X_val_lgb))
print('LightGBM validation score:', rmsle(np.expm1(y_val), y_val_pred_lgb))
# Out:
# Catboost validation score: 0.725015482983491
# LightGBM validation score: 0.734141392247469

# %%
y_pred_test_cb = np.expm1(cbm.predict(X_test_cb))
y_pred_test_lgb = np.expm1(lgbm.predict(X_test_lgb))

test_stack = np.array([y_pred_test_cb, y_pred_test_lgb])
stack_test_avg = np.mean(test_stack, axis=0)

submission = pd.read_csv('data/sample_submission.csv')
submission['predicted'] = stack_test_avg
submission.to_csv('submissions/cb_lgb_lordag_natt_clean.csv', index=False)
